# %% [markdown]
#  # AWS ML Services Overview
#
#  Amazon AWS has a multitude of prebuilt AI services which are prepackaged to be integrated into any orgainisations workflow. Each service is custom built for the task and ease of use and in some cases only needs the required data and no prior machine learning knowledge to be implemented. These services range from creating image recognition applications, text to speech, text extraction to a fully comphrehensive machine learning suite Amazon SageMaker. Below you will see many of the machine learning services offered by AWS with a description and use cases for each. Addtional services can be explored through the [AWS management console](https://aws.amazon.com/console/).

# %% [markdown]
# <style type="text/css">
# .tg  {border-collapse:collapse;border-color:#aaa;border-spacing:0;}
# .tg td{background-color:#fff;border-color:#aaa;border-style:solid;border-width:1px;color:#333;
#   font-family:Arial, sans-serif;font-size:14px;overflow:hidden;padding:10px 5px;word-break:normal;}
# .tg th{background-color:#f38630;border-color:#aaa;border-style:solid;border-width:1px;color:#fff;
#   font-family:Arial, sans-serif;font-size:14px;font-weight:normal;overflow:hidden;padding:10px 5px;word-break:normal;}
# .tg .tg-c3ow{border-color:inherit;text-align:center;vertical-align:center}
# .tg .tg-0pky{width: 800px; border-color:inherit;text-align:left;vertical-align:top}
# .tg .tg-d3ow{width: 500px;border-color:inherit;text-align:center;vertical-align:center}
# .tg li {
#   list-style-type: disc;
#   list-style-position: inside;
#   text-indent: -1em;
#   padding-left: 1em;
# }
# </style>
# <table class="tg">
# <thead>
#   <tr>
#     <th class="tg-c3ow">AWS Service</th>
#     <th class="tg-d3ow">Description</th>
#     <th class="tg-c3ow">Use case</th>
#   </tr>
# </thead>
# <tbody>
#   <tr>
#     <td class="tg-c3ow"><a href="https://aws.amazon.com/sagemaker/" target="_blank" rel="noopener noreferrer">Amazon SageMaker</a></td>
#     <td class="tg-d3ow">Comprehensive service which allows users to prepare, train, build and deploy high quality machine learning models using purpose built tools.</td>
#     <td class="tg-0pky"><li>Label your data using SageMaker Ground Truth and process it with in-built Python, R/Spark capabilities then store it in SageMakers feature store.</li><br><li>You can then either use SageMakers prebuilt and optimised algorithms and models or develop your own.</li><br><li>Use one-click model training and tune your model using automatic hyperparameter tuning.</li><br><li>Deploy your model in one-click and monitor the accuracy with SageMakers inbuilt Model Monitor.</li></td>
#   </tr>
#   <tr>
#     <td class="tg-c3ow"><a href="https://aws.amazon.com/comprehend/" target="_blank" rel="noopener noreferrer">Amazon Comprehend</a></td>
#     <td class="tg-d3ow">A NLP (Natural Language Processing) service simplifying the process of uncovering critical information in unstructured data.   </td>
#     <td class="tg-0pky"><li>Feed product reviews to Comprehend and have it extract product attributes, location, opinions.</li><br><li>Analyse news articles to identify the main topics and recommend these to your readers based on content they have previously viewed.</li></td>
#   </tr>
#   <tr>
#     <td class="tg-c3ow"><a href="https://aws.amazon.com/forecast/" target="_blank" rel="noopener noreferrer">Amazon Forecast</a></td>
#     <td class="tg-d3ow">A fully managed service which combines time series data with other variables to produce highly accurate forecasting.</td>
#     <td class="tg-0pky"><li>Build a product demand forecasting model with will forecast the required inventory levels for your store locations.</li><br><li>Use Forecast for financial planning like sales revenue predictions, revenue and expenses.</li></td>
#   </tr>
#   <tr>
#     <td class="tg-c3ow"><a href="https://aws.amazon.com/fraud-detector/" target="_blank" rel="noopener noreferrer">Amazon Fraud Detector</a></td>
#     <td class="tg-d3ow">A managed service which combines machine learning and 20 years of fraud detection expertise from Amazon to identify potentially fraudulent activity.</td>
#     <td class="tg-0pky"><li>Reduce online payment fraud flagging suspicious transactions before they are processed.</li><br><li>Identify accounts which are likely to abuse online services or loyalty and 'try before you buy schemes'.</li></td>
#   </tr>
#   <tr>
#     <td class="tg-c3ow"><a href="https://aws.amazon.com/kendra/" target="_blank" rel="noopener noreferrer">Amazon Kendra</a></td>
#     <td class="tg-d3ow">An intelligent search service powered by machine learning. Using this service customers and employees can search across multiple locations across the orgainisation to find the right answers when they're needed.</td>
#     <td class="tg-0pky"><li>Improve customer experience by implementing Kendra to improve your customers web search getting them the relevant answers quicker.</li><br><li>Allow your researches to get access quickly to the information needed in your corporate data stores allowing them innovate quicker.</li></td>
#   </tr>
#   <tr>
#     <td class="tg-c3ow"><a href="https://aws.amazon.com/lex/" target="_blank" rel="noopener noreferrer">Amazon Lex</a></td>
#     <td class="tg-d3ow">Allows you to build conversational interfaces into any application using voice and text. It uses the same advanced deep learning technologies as Amazon Alexa to build highly engaging lifelike conversational interactions.</td>
#     <td class="tg-0pky"><li>Serving an interactive chatbot to customers which allows them to converse with the bot to solve their query creating a highly engaging customer experience.</li><br><li>Develop a bot for your call centre which can automate changing a customers password, scheduling an appointment or requesting balance on an account.</li></td>
#   </tr>
#   <tr>
#     <td class="tg-c3ow"><a href="https://aws.amazon.com/personalize/" target="_blank" rel="noopener noreferrer">Amazon Personalize</a></td>
#     <td class="tg-d3ow">Uses same technology as Amazon.com to offer your users real-time personalised recommendations without the need for ML expertise.</td>
#     <td class="tg-0pky"><li>Implement the same recommendation system used by Amazon.com to deliver high quality recommendations to your customers in real-time.</li></td>
#   </tr>
#   <tr>
#     <td class="tg-c3ow"><a href="https://aws.amazon.com/polly/" target="_blank" rel="noopener noreferrer">Amazon Polly</a></td>
#     <td class="tg-d3ow">A service which turns text into lifelike speech allowing you to create applications that talk and to build speech-enabled products.</td>
#     <td class="tg-0pky"><li>Create a real-time traffic update system, send the traffic update to Polly which converts it into speech and then can be outputted to a customers device.</li><br><li>Use Polly to covert your e-learning language lessons into speech so that users can work on their pronunciation.</li></td>
#   </tr>
#   <tr>
#     <td class="tg-c3ow"><a href="https://aws.amazon.com/rekognition/" target="_blank" rel="noopener noreferrer">Amazon Rekognition</a></td>
#     <td class="tg-d3ow">Makes it easy to add image and video analysis to your applications using highly scalable deep learning technology with no machine learning expertise. You can identify, objects, people, text, scenes and activities in images and video as well as inappropriate content.</td>
#     <td class="tg-0pky"><li>Create medical recognition software to support clinicians in their decision making process by identifying abnormalities.</li><br><li>Monitor potentially unsafe or inappropriate content across both image and video.</li></td>
#   </tr>
#   <tr>
#     <td class="tg-c3ow"><a href="https://aws.amazon.com/textract/" target="_blank" rel="noopener noreferrer">Amazon Textract</a></td>
#     <td class="tg-d3ow">Machine learning service which can automatically extract text, handwriting and data from scanned documents which goes beyond the simple optical character recognition (OCR).</td>
#     <td class="tg-0pky"><li>Process thousands of healthcare and insurance forms extracting patient and insurers information for store on your organisations database.</li><br><li>Extract data from mortgage applications, invoices allowing them to be processed and stores in minutes.</li></td>
#   </tr>
#   <tr>
#     <td class="tg-c3ow"><a href="https://aws.amazon.com/transcribe/" target="_blank" rel="noopener noreferrer">Amazon Transcribe</a></td>
#     <td class="tg-d3ow">Allows developers to add speech and text capabilities to applications. Since audio data difficult to analyse and search Transcribe uses an automatic deep learning process to convert audio to text from use in applications.</td>
#     <td class="tg-0pky"><li>Develop a system for media creators to transcribe their assets into fully searchable archives for moderation and monetization.</li><br><li>Implement transcribe in your call centre to identify actionable insights from customer conversations.</li></td>
#   </tr>
# </tbody>
# </table>
