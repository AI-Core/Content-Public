# %% [markdown]
# ## Which of the following code snippets should be used to read data from a JSON file and store it in a pandas dataframe?
#
# - This code
# ``` python
# import pandas as pd
# df = pd.read_csv('data.json')
# ```
#
# - This code ***
# ``` python
# import pandas as pd
# df = pd.read_json('data.json')
# ```
#
# - This code
# ``` python
# import pandas as pd
# import json
# with open('data.json') as f:
#     data = json.load(f)
# df = pd.DataFrame(data)
# ```
#
# - This code
# ``` python
# import pandas as pd
# df = pd.read_excel('data.json')
# ```

# %% [markdown]
# ## What is the purpose of the `json_normalize()` method in Pandas, and what is an example use case?
#
# - The `json_normalize()` method is used to convert a Pandas dataframe to a JSON string. An example use case would be to send the JSON string as a request payload in an HTTP request.
# - The `json_normalize()` method is used to normalize semi-structured JSON data into a flat table. An example use case would be to extract nested data from a JSON file and store it in a Pandas dataframe. ***
# - The `json_normalize()` method is used to merge multiple JSON files into a single Pandas dataframe. An example use case would be to combine data from multiple sources for analysis.
# - The `json_normalize()` method is used to convert JSON data into a hierarchical Pandas dataframe. An example use case would be to store data in a tree-like structure for efficient searching and indexing.

# %% [markdown]
# ## Which of the following code snippets can be used to normalize a JSON object containing nested data into a Pandas dataframe?
#
# - This code ***
# ``` python
# import pandas as pd
# data = {
#     "name": "John",
#     "age": 30,
#     "address": {
#         "city": "New York",
#         "state": "NY"
#     }
# }
# df = pd.json_normalize(data)
# ```
#
# - This code
# ``` python
# import pandas as pd
# import json
# with open('data.json') as f:
#     data = json.load(f)
# df = pd.json_normalize(data)
# ```
#
# - This code
# ``` python
# import pandas as pd
# data = {
#     "name": "John",
#     "age": 30,
#     "address": {
#         "city": "New York",
#         "state": "NY"
#     }
# }
# df = pd.DataFrame(data)
# ```
#
# - This code
# ``` python
# import pandas as pd
# data = {
#     "name": "John",
#     "age": 30,
#     "address": {
#         "city": "New York",
#         "state": "NY"
#     }
# }
# df = pd.read_json(data)
# ```

# %% [markdown]
# ## Which of the following code snippets can be used to read data from a YAML file into a Pandas dataframe in Python?
#
# - This code ***
# ``` python
# import yaml
# import pandas as pd
# with open('data.yaml') as f:
#     data = yaml.safe_load(f)
# df = pd.DataFrame.from_dict(data)
# ```
#
# - This code
# ``` python
# import yaml
# import pandas as pd
# with open('data.yaml') as f:
#     data = yaml.safe_load(f)
# df = pd.read_csv(data)
#
# ```
#
# - This code
# ``` python
# import pandas as pd
# import yaml
# with open('data.yaml') as f:
#     data = yaml.load(f, Loader=yaml.FullLoader)
# df = pd.json_normalize(data)
# ```
#
# - This code
# ``` python
#
# import pandas as pd
# df = pd.read_yaml('data.yaml')
# ```

# %% [markdown]
# ## Which of the following code snippets correctly writes a Pandas dataframe to a JSON file?
#
# - This code ***
# ``` python
# import pandas as pd
# df = pd.DataFrame({'Name': ['Alice', 'Bob'], 'Age': [25, 30]})
# df.to_json('data.json')
# ```
#
# - This code
# ``` python
# import pandas as pd
# df = pd.DataFrame({'Name': ['Alice', 'Bob'], 'Age': [25, 30]})
# json_data = df.to_json()
# with open('data.json', 'w') as f:
#     f.write(json_data)
# ```
#
# - This code
# ``` python
# import pandas as pd
# df = pd.DataFrame({'Name': ['Alice', 'Bob'], 'Age': [25, 30]})
# df.to_csv('data.json', orient='index')
# ```

# %% [markdown]
# ## Which of the following code snippets correctly writes data from a Pandas dataframe to a YAML file?
#
# - This code
# ``` python
# import pandas as pd
# import yaml
# df = pd.read_csv('data.csv')
# with open('data.yaml', 'w') as f:
#     yaml.dump(df, f)
# ```
#
# - This code
# ``` python
# import pandas as pd
# import yaml
# df = pd.DataFrame({'Name': ['Alice', 'Bob'], 'Age': [25, 30]})
# yaml_data = yaml.dump(df)
# with open('data.yaml', 'w') as f:
#     f.write(yaml_data)
# ```
#
# - This code
# ``` python
# import pandas as pd
# import yaml
# df = pd.read_csv('data.csv')
# df.to_yaml('data.yaml')
# ```
#
# - This code ***
# ```python
# import pandas as pd
# import yaml
# df = pd.DataFrame({'Name': ['Alice', 'Bob'], 'Age': [25, 30]})
# with open('data.yaml', 'w') as f:
#     yaml.dump(df.to_dict(), f)
# ```
