# %%
import pandas as pd

# %%
df = pd.read_csv('data.csv')
print(type(df))
df[['Id', 'EmployeeName', 'JobTitle']]
df.set_index('Id', inplace=True)
df
# Out:
# <class 'pandas.core.frame.DataFrame'>
#                 EmployeeName                                        JobTitle  \
# Id
# AA            NATHANIEL FORD  GENERAL MANAGER-METROPOLITAN TRANSIT AUTHORITY
# AB              GARY JIMENEZ                 CAPTAIN III (POLICE DEPARTMENT)
# AC            ALBERT PARDINI                 CAPTAIN III (POLICE DEPARTMENT)
# AD         CHRISTOPHER CHONG            WIRE ROPE CABLE MAINTENANCE MECHANIC
# AE           PATRICK GARDNER    DEPUTY CHIEF OF DEPARTMENT,(FIRE DEPARTMENT)
# ..                       ...                                             ...
# ZV              CHERYL ADAMS               HEAD ATTORNEY, CIVIL AND CRIMINAL
# ZW            LOUISE SIMPSON               HEAD ATTORNEY, CIVIL AND CRIMINAL
# ZX               BLAKE LOEBS               HEAD ATTORNEY, CIVIL AND CRIMINAL
# ZY  ELIZABETH AGUILAR-TARCHI               HEAD ATTORNEY, CIVIL AND CRIMINAL
# ZZ                 JULIAN NG                SERGEANT III (POLICE DEPARTMENT)
#
# ...

# %%
df.loc['ZW']
# Out:
# EmployeeName                           LOUISE SIMPSON
# JobTitle            HEAD ATTORNEY, CIVIL AND CRIMINAL
# BasePay                                     176856.18
# OvertimePay                                       0.0
# OtherPay                                       3537.8
# Benefits                                          NaN
# TotalPay                                    180393.98
# TotalPayBenefits                            180393.98
# Year                                             2011
# Notes                                             NaN
# Agency                                  San Francisco
# Status                                            NaN
# Name: ZW, dtype: object

# %%
df.loc['ZW', :]
# Out:
# EmployeeName                           LOUISE SIMPSON
# JobTitle            HEAD ATTORNEY, CIVIL AND CRIMINAL
# BasePay                                     176856.18
# OvertimePay                                       0.0
# OtherPay                                       3537.8
# Benefits                                          NaN
# TotalPay                                    180393.98
# TotalPayBenefits                            180393.98
# Year                                             2011
# Notes                                             NaN
# Agency                                  San Francisco
# Status                                            NaN
# Name: ZW, dtype: object

# %%
df.iloc[3, 5]
# Out:
# nan

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 676 entries, AA to ZZ
# Data columns (total 12 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   EmployeeName      676 non-null    object
#  1   JobTitle          676 non-null    object
#  2   BasePay           676 non-null    float64
#  3   OvertimePay       676 non-null    float64
#  4   OtherPay          676 non-null    float64
#  5   Benefits          0 non-null      float64
#  6   TotalPay          676 non-null    float64
#  7   TotalPayBenefits  676 non-null    float64
#  8   Year              676 non-null    int64
#  9   Notes             0 non-null      float64
#  10  Agency            676 non-null    object
#  11  Status            0 non-null      float64
# dtypes: float64(8), int64(1), object(3)
# memory usage: 84.8+ KB

# %%
df.describe()
# Out:
#              BasePay    OvertimePay       OtherPay  Benefits       TotalPay  \
# count     676.000000     676.000000     676.000000       0.0     676.000000
# mean   149900.019867   30577.231657   23448.147426       NaN  203925.398950
# std     41837.736210   35124.001536   30720.629073       NaN   31798.561906
# min     25400.000000       0.000000       0.000000       NaN  180312.670000
# 25%    117268.875000       0.000000    7006.317500       NaN  185695.470000
# 50%    144042.160000   16664.630000   16491.805000       NaN  194842.065000
# 75%    184727.132500   57995.962500   27305.230000       NaN  209450.040000
# max    294580.020000  245131.880000  400184.250000       NaN  567595.430000
#
#        TotalPayBenefits    Year  Notes  Status
# count        676.000000   676.0    0.0     0.0
# mean      203925.398950  2011.0    NaN     NaN
# std        31798.561906     0.0    NaN     NaN
# min       180312.670000  2011.0    NaN     NaN
# ...

# %%
df.head()
# Out:
#          EmployeeName                                        JobTitle  \
# Id
# AA     NATHANIEL FORD  GENERAL MANAGER-METROPOLITAN TRANSIT AUTHORITY
# AB       GARY JIMENEZ                 CAPTAIN III (POLICE DEPARTMENT)
# AC     ALBERT PARDINI                 CAPTAIN III (POLICE DEPARTMENT)
# AD  CHRISTOPHER CHONG            WIRE ROPE CABLE MAINTENANCE MECHANIC
# AE    PATRICK GARDNER    DEPUTY CHIEF OF DEPARTMENT,(FIRE DEPARTMENT)
#
#       BasePay  OvertimePay   OtherPay  Benefits   TotalPay  TotalPayBenefits  \
# Id
# AA  167411.18         0.00  400184.25       NaN  567595.43         567595.43
# AB  155966.02    245131.88  137811.38       NaN  538909.28         538909.28
# AC  212739.13    106088.18   16452.60       NaN  335279.91         335279.91
# AD   77916.00     56120.71  198306.90       NaN  332343.61         332343.61
# AE  134401.60      9737.00  182234.59       NaN  326373.19         326373.19
#
#     Year  Notes         Agency  Status
# Id
# ...

# %%
df.tail()
# Out:
#                 EmployeeName                           JobTitle    BasePay  \
# Id
# ZV              CHERYL ADAMS  HEAD ATTORNEY, CIVIL AND CRIMINAL  176856.18
# ZW            LOUISE SIMPSON  HEAD ATTORNEY, CIVIL AND CRIMINAL  176856.18
# ZX               BLAKE LOEBS  HEAD ATTORNEY, CIVIL AND CRIMINAL  176856.19
# ZY  ELIZABETH AGUILAR-TARCHI  HEAD ATTORNEY, CIVIL AND CRIMINAL  176856.17
# ZZ                 JULIAN NG   SERGEANT III (POLICE DEPARTMENT)  130457.76
#
#     OvertimePay  OtherPay  Benefits   TotalPay  TotalPayBenefits  Year  Notes  \
# Id
# ZV         0.00   3537.89       NaN  180394.07         180394.07  2011    NaN
# ZW         0.00   3537.80       NaN  180393.98         180393.98  2011    NaN
# ZX         0.00   3537.75       NaN  180393.94         180393.94  2011    NaN
# ZY         0.00   3537.11       NaN  180393.28         180393.28  2011    NaN
# ZZ     43793.11   6061.80       NaN  180312.67         180312.67  2011    NaN
#
#            Agency  Status
# Id
# ...

# %%
def get_first_name_from_full_name(name):
    return name.split()[0]

df['EmployeeName'].apply(get_first_name_from_full_name)
df
# Out:
#                 EmployeeName                                        JobTitle  \
# Id
# AA            NATHANIEL FORD  GENERAL MANAGER-METROPOLITAN TRANSIT AUTHORITY
# AB              GARY JIMENEZ                 CAPTAIN III (POLICE DEPARTMENT)
# AC            ALBERT PARDINI                 CAPTAIN III (POLICE DEPARTMENT)
# AD         CHRISTOPHER CHONG            WIRE ROPE CABLE MAINTENANCE MECHANIC
# AE           PATRICK GARDNER    DEPUTY CHIEF OF DEPARTMENT,(FIRE DEPARTMENT)
# ..                       ...                                             ...
# ZV              CHERYL ADAMS               HEAD ATTORNEY, CIVIL AND CRIMINAL
# ZW            LOUISE SIMPSON               HEAD ATTORNEY, CIVIL AND CRIMINAL
# ZX               BLAKE LOEBS               HEAD ATTORNEY, CIVIL AND CRIMINAL
# ZY  ELIZABETH AGUILAR-TARCHI               HEAD ATTORNEY, CIVIL AND CRIMINAL
# ZZ                 JULIAN NG                SERGEANT III (POLICE DEPARTMENT)
#
# ...

# %%
df.drop(['AA', 'AB'], inplace=True)
df
# Out:
#                 EmployeeName                                      JobTitle  \
# Id
# AC            ALBERT PARDINI               CAPTAIN III (POLICE DEPARTMENT)
# AD         CHRISTOPHER CHONG          WIRE ROPE CABLE MAINTENANCE MECHANIC
# AE           PATRICK GARDNER  DEPUTY CHIEF OF DEPARTMENT,(FIRE DEPARTMENT)
# AF            DAVID SULLIVAN                     ASSISTANT DEPUTY CHIEF II
# AG                 ALSON LEE            BATTALION CHIEF, (FIRE DEPARTMENT)
# ..                       ...                                           ...
# ZV              CHERYL ADAMS             HEAD ATTORNEY, CIVIL AND CRIMINAL
# ZW            LOUISE SIMPSON             HEAD ATTORNEY, CIVIL AND CRIMINAL
# ZX               BLAKE LOEBS             HEAD ATTORNEY, CIVIL AND CRIMINAL
# ZY  ELIZABETH AGUILAR-TARCHI             HEAD ATTORNEY, CIVIL AND CRIMINAL
# ZZ                 JULIAN NG              SERGEANT III (POLICE DEPARTMENT)
#
# ...

# %%
df.drop('OtherPay', axis=1, inplace=True)
df
# Out:
#                 EmployeeName                                      JobTitle  \
# Id
# AC            ALBERT PARDINI               CAPTAIN III (POLICE DEPARTMENT)
# AD         CHRISTOPHER CHONG          WIRE ROPE CABLE MAINTENANCE MECHANIC
# AE           PATRICK GARDNER  DEPUTY CHIEF OF DEPARTMENT,(FIRE DEPARTMENT)
# AF            DAVID SULLIVAN                     ASSISTANT DEPUTY CHIEF II
# AG                 ALSON LEE            BATTALION CHIEF, (FIRE DEPARTMENT)
# ..                       ...                                           ...
# ZV              CHERYL ADAMS             HEAD ATTORNEY, CIVIL AND CRIMINAL
# ZW            LOUISE SIMPSON             HEAD ATTORNEY, CIVIL AND CRIMINAL
# ZX               BLAKE LOEBS             HEAD ATTORNEY, CIVIL AND CRIMINAL
# ZY  ELIZABETH AGUILAR-TARCHI             HEAD ATTORNEY, CIVIL AND CRIMINAL
# ZZ                 JULIAN NG              SERGEANT III (POLICE DEPARTMENT)
#
# ...

# %%
high_earners = df[df['BasePay'] > 100000]
high_earners
# Out:
#                 EmployeeName                                      JobTitle  \
# Id
# AC            ALBERT PARDINI               CAPTAIN III (POLICE DEPARTMENT)
# AE           PATRICK GARDNER  DEPUTY CHIEF OF DEPARTMENT,(FIRE DEPARTMENT)
# AF            DAVID SULLIVAN                     ASSISTANT DEPUTY CHIEF II
# AH             DAVID KUSHNER                DEPUTY DIRECTOR OF INVESTMENTS
# AI            MICHAEL MORRIS            BATTALION CHIEF, (FIRE DEPARTMENT)
# ..                       ...                                           ...
# ZV              CHERYL ADAMS             HEAD ATTORNEY, CIVIL AND CRIMINAL
# ZW            LOUISE SIMPSON             HEAD ATTORNEY, CIVIL AND CRIMINAL
# ZX               BLAKE LOEBS             HEAD ATTORNEY, CIVIL AND CRIMINAL
# ZY  ELIZABETH AGUILAR-TARCHI             HEAD ATTORNEY, CIVIL AND CRIMINAL
# ZZ                 JULIAN NG              SERGEANT III (POLICE DEPARTMENT)
#
# ...
