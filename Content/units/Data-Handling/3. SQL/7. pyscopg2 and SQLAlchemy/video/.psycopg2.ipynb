# %% [markdown]
# # psycopg2 and SQLAlchemy

# %%
import psycopg2
HOST = 'localhost'
USER = 'postgres'
DATABASE = 'pagila'
PORT = 5432
PASSWORD = #'password'
# Out:
# <class 'psycopg2.extensions.cursor'>

# %%
with psycopg2.connect(host=HOST, user=USER, password=PASSWORD, dbname=DATABASE, port=PORT) as conn:
    with conn.cursor() as cur:
        cur.execute('''SELECT first_name, last_name FROM customer
                       WHERE first_name LIKE 'A%';
                    ''')
        records = cur.fetchall()
        print(records)
# Out:
# [('ANGELA', 'HERNANDEZ'), ('AMY', 'LOPEZ'), ('ANNA', 'HILL'), ('AMANDA', 'CARTER'), ('ANN', 'EVANS'), ('ALICE', 'STEWART'), ('ASHLEY', 'RICHARDSON'), ('ANDREA', 'HENDERSON'), ('ANNE', 'POWELL'), ('ANNIE', 'RUSSELL'), ('ANITA', 'MORALES'), ('AMBER', 'DIXON'), ('APRIL', 'BURNS'), ('ALICIA', 'MILLS'), ('AUDREY', 'RAY'), ('ANNETTE', 'OLSON'), ('ANA', 'BRADLEY'), ('ALMA', 'AUSTIN'), ('AGNES', 'BISHOP'), ('ARLENE', 'HARVEY'), ('ALLISON', 'STANLEY'), ('ANTHONY', 'SCHWAB'), ('ANDREW', 'PURDY'), ('ARTHUR', 'SIMPKINS'), ('ALBERT', 'CROUSE'), ('ADAM', 'GOOCH'), ('AARON', 'SELBY'), ('ALAN', 'KAHN'), ('ANTONIO', 'MEEK'), ('ALLEN', 'BUTTERFIELD'), ('ALFRED', 'CASILLAS'), ('ALEXANDER', 'FENNELL'), ('ALEX', 'GRESHAM'), ('ALVIN', 'DELOACH'), ('ANGEL', 'BARCLAY'), ('ANDRE', 'RAPP'), ('ARNOLD', 'HAVENS'), ('ADRIAN', 'CLARY'), ('ALLAN', 'CORNISH'), ('ARMANDO', 'GRUBER'), ('ALFREDO', 'MCADAMS'), ('ALBERTO', 'HENNING'), ('ANDY', 'VANHORN'), ('AUSTIN', 'CINTRON')]

# %%
with psycopg2.connect(host=HOST, user=USER, password=PASSWORD, dbname=DATABASE, port=PORT) as conn:
    with conn.cursor() as cur:
        cur.execute('''CREATE TABLE customers_a AS (
                        SELECT first_name, last_name FROM customer
                            WHERE first_name LIKE 'A%'
                        );
                    ''')

# %%
print(type(records))
# Out:
# <class 'list'>

# %% [markdown]
# ## SQLAlchemy

# %%
from sqlalchemy import create_engine
from sqlalchemy import inspect
import sqlalchemy
DATABASE_TYPE = 'postgresql'
DBAPI = 'psycopg2'
HOST = 'localhost'
USER = 'postgres'
DATABASE = 'pagila'
PORT = 5432
PASSWORD = 'Cosamona94'

# %%
engine = create_engine(f"{DATABASE_TYPE}+{DBAPI}://{USER}:{PASSWORD}@{HOST}:{PORT}/{DATABASE}")
engine.connect()

# %%
insp = inspect(engine)
insp.get_table_names()
# Out:
# ['actor', 'film', 'payment_p2007_02', 'payment_p2007_03', 'payment_p2007_04', 'payment_p2007_05', 'payment_p2007_06', 'payment_p2007_01', 'address', 'category', 'city', 'country', 'customer', 'film_actor', 'film_category', 'inventory', 'language', 'rental', 'staff', 'store', 'payment', 'employee_details', 'actor_2', 'customers_a']

# %%
query = '''
        SELECT first_name, last_name FROM customer
        WHERE first_name LIKE 'A%';
        '''
# query = sqlalchemy.text(query)
engine.execute(query).fetchall()
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-13-3d73e0c26c9d> in <module>
#       4         '''
#       5 # query = sqlalchemy.text(query)
# ----> 6 engine.execute(query).fetchall()
#
# <string> in execute(self, statement, *multiparams, **params)
#
# ~/miniconda3/lib/python3.9/site-packages/sqlalchemy/util/deprecations.py in warned(fn, *args, **kwargs)
#     399         if not skip_warning:
#     400             _warn_with_version(message, version, wtype, stacklevel=3)
# --> 401         return fn(*args, **kwargs)
#     402
#     403     doc = func.__doc__ is not None and func.__doc__ or ""
#
# ~/miniconda3/lib/python3.9/site-packages/sqlalchemy/engine/base.py in execute(self, statement, *multiparams, **params)
#    3144         """
#    3145         connection = self.connect(close_with_result=True)
# ...

# %%
query = '''
        SELECT first_name, last_name FROM customer
        WHERE first_name LIKE 'A%';
        '''
query = sqlalchemy.text(query)
engine.execute(query).fetchall()
# Out:
# [('ANGELA', 'HERNANDEZ'),
#  ('AMY', 'LOPEZ'),
#  ('ANNA', 'HILL'),
#  ('AMANDA', 'CARTER'),
#  ('ANN', 'EVANS'),
#  ('ALICE', 'STEWART'),
#  ('ASHLEY', 'RICHARDSON'),
#  ('ANDREA', 'HENDERSON'),
#  ('ANNE', 'POWELL'),
#  ('ANNIE', 'RUSSELL'),
#  ('ANITA', 'MORALES'),
#  ('AMBER', 'DIXON'),
#  ('APRIL', 'BURNS'),
#  ('ALICIA', 'MILLS'),
#  ('AUDREY', 'RAY'),
#  ('ANNETTE', 'OLSON'),
#  ('ANA', 'BRADLEY'),
#  ('ALMA', 'AUSTIN'),
#  ('AGNES', 'BISHOP'),
#  ('ARLENE', 'HARVEY'),
#  ('ALLISON', 'STANLEY'),
#  ('ANTHONY', 'SCHWAB'),
#  ('ANDREW', 'PURDY'),
#  ('ARTHUR', 'SIMPKINS'),
#  ('ALBERT', 'CROUSE'),
#  ('ADAM', 'GOOCH'),
#  ('AARON', 'SELBY'),
#  ('ALAN', 'KAHN'),
#  ('ANTONIO', 'MEEK'),
#  ('ALLEN', 'BUTTERFIELD'),
#  ('ALFRED', 'CASILLAS'),
#  ('ALEXANDER', 'FENNELL'),
#  ('ALEX', 'GRESHAM'),
#  ('ALVIN', 'DELOACH'),
#  ('ANGEL', 'BARCLAY'),
#  ('ANDRE', 'RAPP'),
#  ('ARNOLD', 'HAVENS'),
#  ('ADRIAN', 'CLARY'),
#  ('ALLAN', 'CORNISH'),
#  ('ARMANDO', 'GRUBER'),
# ...

# %%
import pandas as pd

customer_a = pd.read_sql(query, engine)
customer_a
# Out:
#    first_name    last_name
# 0      ANGELA    HERNANDEZ
# 1         AMY        LOPEZ
# 2        ANNA         HILL
# 3      AMANDA       CARTER
# 4         ANN        EVANS
# 5       ALICE      STEWART
# 6      ASHLEY   RICHARDSON
# 7      ANDREA    HENDERSON
# 8        ANNE       POWELL
# 9       ANNIE      RUSSELL
# 10      ANITA      MORALES
# 11      AMBER        DIXON
# 12      APRIL        BURNS
# 13     ALICIA        MILLS
# 14     AUDREY          RAY
# 15    ANNETTE        OLSON
# 16        ANA      BRADLEY
# 17       ALMA       AUSTIN
# 18      AGNES       BISHOP
# 19     ARLENE       HARVEY
# 20    ALLISON      STANLEY
# 21    ANTHONY       SCHWAB
# 22     ANDREW        PURDY
# 23     ARTHUR     SIMPKINS
# 24     ALBERT       CROUSE
# 25       ADAM        GOOCH
# 26      AARON        SELBY
# 27       ALAN         KAHN
# 28    ANTONIO         MEEK
# 29      ALLEN  BUTTERFIELD
# 30     ALFRED     CASILLAS
# 31  ALEXANDER      FENNELL
# 32       ALEX      GRESHAM
# ...

# %%
customers = pd.read_sql('customer', engine)
customers
# Out:
#      customer_id  store_id first_name  last_name  \
# 0              1         1       MARY      SMITH
# 1              2         1   PATRICIA    JOHNSON
# 2              3         1      LINDA   WILLIAMS
# 3              4         2    BARBARA      JONES
# 4              5         1  ELIZABETH      BROWN
# ..           ...       ...        ...        ...
# 594          595         1   TERRENCE  GUNDERSON
# 595          596         1    ENRIQUE   FORSYTHE
# 596          597         1    FREDDIE     DUGGAN
# 597          598         1       WADE   DELVALLE
# 598          599         2     AUSTIN    CINTRON
#
#                                      email  address_id  activebool  \
# 0            MARY.SMITH@sakilacustomer.org           5        True
# 1      PATRICIA.JOHNSON@sakilacustomer.org           6        True
# 2        LINDA.WILLIAMS@sakilacustomer.org           7        True
# 3         BARBARA.JONES@sakilacustomer.org           8        True
# ...

# %%
customers = pd.read_sql_table(query, engine)
customers
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-24-64b9a33ee991> in <module>
# ----> 1 customers = pd.read_sql_table(query, engine)
#       2 customers
#
# ~/miniconda3/lib/python3.9/site-packages/pandas/io/sql.py in read_sql_table(table_name, con, schema, index_col, coerce_float, parse_dates, columns, chunksize)
#     318     meta = MetaData(con, schema=schema)
#     319     try:
# --> 320         meta.reflect(only=[table_name], views=True)
#     321     except sqlalchemy.exc.InvalidRequestError as err:
#     322         raise ValueError(f"Table {table_name} not found") from err
#
# ~/miniconda3/lib/python3.9/site-packages/sqlalchemy/sql/schema.py in reflect(self, bind, schema, views, only, extend_existing, autoload_replace, resolve_fks, **dialect_kwargs)
#    4744                     raise exc.InvalidRequestError(
# ...

# %%
customers = pd.read_sql_table('customer', engine)
customers
# Out:
#      customer_id  store_id first_name  last_name  \
# 0              1         1       MARY      SMITH
# 1              2         1   PATRICIA    JOHNSON
# 2              3         1      LINDA   WILLIAMS
# 3              4         2    BARBARA      JONES
# 4              5         1  ELIZABETH      BROWN
# ..           ...       ...        ...        ...
# 594          595         1   TERRENCE  GUNDERSON
# 595          596         1    ENRIQUE   FORSYTHE
# 596          597         1    FREDDIE     DUGGAN
# 597          598         1       WADE   DELVALLE
# 598          599         2     AUSTIN    CINTRON
#
#                                      email  address_id  activebool  \
# 0            MARY.SMITH@sakilacustomer.org           5        True
# 1      PATRICIA.JOHNSON@sakilacustomer.org           6        True
# 2        LINDA.WILLIAMS@sakilacustomer.org           7        True
# 3         BARBARA.JONES@sakilacustomer.org           8        True
# ...

# %%
customer_a = pd.read_sql_query(query, engine)
customer_a
# Out:
#    first_name    last_name
# 0      ANGELA    HERNANDEZ
# 1         AMY        LOPEZ
# 2        ANNA         HILL
# 3      AMANDA       CARTER
# 4         ANN        EVANS
# 5       ALICE      STEWART
# 6      ASHLEY   RICHARDSON
# 7      ANDREA    HENDERSON
# 8        ANNE       POWELL
# 9       ANNIE      RUSSELL
# 10      ANITA      MORALES
# 11      AMBER        DIXON
# 12      APRIL        BURNS
# 13     ALICIA        MILLS
# 14     AUDREY          RAY
# 15    ANNETTE        OLSON
# 16        ANA      BRADLEY
# 17       ALMA       AUSTIN
# 18      AGNES       BISHOP
# 19     ARLENE       HARVEY
# 20    ALLISON      STANLEY
# 21    ANTHONY       SCHWAB
# 22     ANDREW        PURDY
# 23     ARTHUR     SIMPKINS
# 24     ALBERT       CROUSE
# 25       ADAM        GOOCH
# 26      AARON        SELBY
# 27       ALAN         KAHN
# 28    ANTONIO         MEEK
# 29      ALLEN  BUTTERFIELD
# 30     ALFRED     CASILLAS
# 31  ALEXANDER      FENNELL
# 32       ALEX      GRESHAM
# ...

# %%
cars = pd.read_csv('https://aicore-files.s3.amazonaws.com/Data-Eng/Cars_Dataset.csv')
cars
# Out:
#       Unnamed: 0  price      brand    model  year   title_status   mileage  \
# 0              0   6300     toyota  cruiser  2008  clean vehicle  274117.0
# 1              1   2899       ford       se  2011  clean vehicle  190552.0
# 2              2   5350      dodge      mpv  2018  clean vehicle   39590.0
# 3              3  25000       ford     door  2014  clean vehicle   64146.0
# 4              4  27700  chevrolet     1500  2018  clean vehicle    6654.0
# ...          ...    ...        ...      ...   ...            ...       ...
# 2494        2494   7800     nissan    versa  2019  clean vehicle   23609.0
# 2495        2495   9200     nissan    versa  2018  clean vehicle   34553.0
# 2496        2496   9200     nissan    versa  2018  clean vehicle   31594.0
# 2497        2497   9200     nissan    versa  2018  clean vehicle   32557.0
# 2498        2498   9200     nissan    versa  2018  clean vehicle   31371.0
#
#        color                  vin        lot       state country  \
# ...

# %%
cars.to_sql('cars', engine, if_exists='replace')
