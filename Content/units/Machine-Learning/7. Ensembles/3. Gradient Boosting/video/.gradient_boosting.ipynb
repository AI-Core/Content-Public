# %%
from sklearn.tree import DecisionTreeRegressor
import numpy as np
def plot_predictions(regressors, X, y, axes, label=None, style="r-", data_style="b.", data_label=None):
    x1 = np.linspace(axes[0], axes[1], 500)
    y_pred = sum(regressor.predict(x1.reshape(-1, 1)) for regressor in regressors)
    plt.plot(X[:, 0], y, data_style, label=data_label)
    plt.plot(x1, y_pred, style, linewidth=2, label=label)
    if label or data_label:
        plt.legend(loc="upper center", fontsize=16)
    plt.axis(axes)

np.random.seed(42)
X = np.random.rand(100, 1) - 0.5
y = 5 * X[:, 0] ** 2 + 0.05 * np.random.randn(100)
import matplotlib.pyplot as plt
plt.scatter(X, y)

# %%
tree_reg1 = DecisionTreeRegressor(max_depth=2)
tree_reg1.fit(X, y)
plot_predictions([tree_reg1], X, y, axes=[-0.5, 0.5, -0.1, 1.5], label="$h(x_1) = h_1(x_1)$", data_label="Training set")
plt.ylabel("$y$", fontsize=16, rotation=0)
plt.title("First Prediction", fontsize=16)
# Out:
# Text(0.5, 1.0, 'First Prediction')

# %%
y2 = y - tree_reg1.predict(X)
tree_reg2 = DecisionTreeRegressor(max_depth=2)
tree_reg2.fit(X, y2)
plot_predictions([tree_reg2], X, y2, axes=[-0.5, 0.5, -0.5, 0.5], label="$h_2(x_1)$", style="g-", data_style="k+", data_label="Residuals")
plt.ylabel("$y - h_1(x_1)$", fontsize=16)
# Out:
# Text(0, 0.5, '$y - h_1(x_1)$')

# %%
plot_predictions([tree_reg1, tree_reg2], X, y, axes=[-0.5, 0.5, -0.1, 1.5], label="$h(x_1) = h_1(x_1) + h_2(x_1)$")
plt.ylabel("$y$", fontsize=16, rotation=0)
# Out:
# Text(0, 0.5, '$y$')

# %%
y3 = y2 - tree_reg2.predict(X)
tree_reg3 = DecisionTreeRegressor(max_depth=2)
tree_reg3.fit(X, y3)
plot_predictions([tree_reg3], X, y3, axes=[-0.5, 0.5, -0.5, 0.5], label="$h_3(x_1)$", style="g-", data_style="k+")
plt.ylabel("$y - h_1(x_1) - h_2(x_1)$", fontsize=16)
plt.xlabel("$x_1$", fontsize=16)
# Out:
# Text(0.5, 0, '$x_1$')

# %%
plot_predictions([tree_reg1, tree_reg2, tree_reg3], X, y, axes=[-0.5, 0.5, -0.1, 1.5], label="$h(x_1) = h_1(x_1) + h_2(x_1) + h_3(x_1)$")
plt.xlabel("$x_1$", fontsize=16)
plt.ylabel("$y$", fontsize=16, rotation=0)
# Out:
# Text(0, 0.5, '$y$')

# %% [markdown]
# ## Using Gradient Boosting with sklearn

# %%
import numpy as np
from sklearn.model_selection import train_test_split
from sklearn.ensemble import GradientBoostingRegressor

gradient_boosting = GradientBoostingRegressor(max_depth=2, n_estimators=3, random_state=42, learning_rate=1)
gradient_boosting.fit(X, y)
plot_predictions([gradient_boosting], X, y, axes=[-0.5, 0.5, -0.1, 1.5], label="$Prediction$")

# %%
gradient_boosting = GradientBoostingRegressor(learning_rate=0.1, max_depth=2, n_estimators=3, random_state=42, )
gradient_boosting.fit(X, y)
plot_predictions([gradient_boosting], X, y, axes=[-0.5, 0.5, -0.1, 1.5], label="$Prediction$")

# %%
gradient_boosting = GradientBoostingRegressor(learning_rate=2, max_depth=2, n_estimators=3, random_state=42, )
gradient_boosting.fit(X, y)
plot_predictions([gradient_boosting], X, y, axes=[-0.5, 0.5, -0.1, 1.5], label="$Prediction$")

# %%
gradient_boosting = GradientBoostingRegressor(learning_rate=1, max_depth=2, n_estimators=100, random_state=42, )
gradient_boosting.fit(X, y)
plot_predictions([gradient_boosting], X, y, axes=[-0.5, 0.5, -0.1, 1.5], label="$Prediction$")

# %%
gradient_boosting = GradientBoostingRegressor(learning_rate=1, max_depth=4, n_estimators=3, random_state=42, )
gradient_boosting.fit(X, y)
plot_predictions([gradient_boosting], X, y, axes=[-0.5, 0.5, -0.1, 1.5], label="$Prediction$")
