# %% [markdown]
# # APIs and requests
#
# > APIs are computer programs that know what to do and how to respond to requests sent to them over the internet
#
# You will see lots of far more complicated definitions online, but it's really as simple as that. We'll talk about what API stands for later.
#
# Before we get into it, here's a taster. Below, we make a request to the Pokemon API to get information about Pikachu.

# %%
import requests

response = requests.get('https://pokeapi.co/api/v2/pokemon/pikachu')

# %% [markdown]
# We'll come back to this later

# %% [markdown]
# ## Communication Protocols
#
# A protocol is a predefined set of rules for communicating. The protocol tells computers how to format the message when sending it and how to interpret the raw data when recieving it.
#
# Here are some common computer protocols which you might have heard of.
#
# - __HTTP__ (HyperText Transfer Protocol) is one of the most common protocols
# - __HTTPS__ is a secure implementation of HTTP. It encrypts messages using a protocol called TLS (Transport Layer Security). When you see a padlock next to the URL in your browser, you're recieving data from that website via HTTPS. When your browser gives you a scary warning, you're probably connecting over HTTP. The security provided by TLS was formerly implemented by another protocol called SSL (Secure Sockets Layer).
# - __SSH__ (Secure SHell) is a protocol that allows secure communication over an insecure network (where other devices may see your messages), like the internet. It does this by encrypting messages using a public and private key, where both are required to decrypt the message.
# - __IP__ (Internet Protocol) is a protocol which ensures that packets (basically chunks) of a message get sent to the correct computer
# - __DNS__ (Domain Name Server) is a protocol that maps human readable urls like `https://www.theaicore.com` to their IP address, such as `192.0.2.1`
#
# ## Requests
#
# A __request__ is a message sent from one computer to another. Typically a __response__ is returned in the opposite direction. A request must be sent using a protocol, which tells both computers the rules for how to send and interpret messages.
#
# In this notebook, we will be making HTTP requests to existing APIs.

# %% [markdown]
# ## Client vs server
#
# You will commonly hear about the __client__, which is the computer initiating the request (asking for the Pokemon), and the __server__ which is the computer handling the request (returning the Pokemon info).
#
# In reality, there is no difference in the two computers. The server and the client just represent two different software programs. They could be running on the exact same hardware. In fact, they could be running on the exact same computer! This is commonly the case when developing an API or web application locally.

# %% [markdown]
# ## Making HTTP requests
#
# We can make requests to an API from the terminal using the `curl` (Client URL) command.

# %%
# !curl https://pokeapi.co/api/v2/pokemon/pikachu

# %% [markdown]
# We can use the python library `requests` to send messages to an API.

# %%
import requests

response = requests.get('https://pokeapi.co/api/v2/pokemon/pikachu')

# %% [markdown]
# The response variable has the information of the received object. However, the variable itself doesn't reflect the information, but the status of the request. We will get to that shortly. For now, remember that you can read the content of a request using the `.json()` method, or the `.text()` attribute.

# %%
response.json()
# Out:
# {'abilities': [{'ability': {'name': 'static',
#     'url': 'https://pokeapi.co/api/v2/ability/9/'},
#    'is_hidden': False,
#    'slot': 1},
#   {'ability': {'name': 'lightning-rod',
#     'url': 'https://pokeapi.co/api/v2/ability/31/'},
#    'is_hidden': True,
#    'slot': 3}],
#  'base_experience': 112,
#  'forms': [{'name': 'pikachu',
#    'url': 'https://pokeapi.co/api/v2/pokemon-form/25/'}],
#  'game_indices': [{'game_index': 84,
#    'version': {'name': 'red', 'url': 'https://pokeapi.co/api/v2/version/1/'}},
#   {'game_index': 84,
#    'version': {'name': 'blue', 'url': 'https://pokeapi.co/api/v2/version/2/'}},
#   {'game_index': 84,
#    'version': {'name': 'yellow',
#     'url': 'https://pokeapi.co/api/v2/version/3/'}},
#   {'game_index': 25,
#    'version': {'name': 'gold', 'url': 'https://pokeapi.co/api/v2/version/4/'}},
#   {'game_index': 25,
#    'version': {'name': 'silver',
#     'url': 'https://pokeapi.co/api/v2/version/5/'}},
#   {'game_index': 25,
#    'version': {'name': 'crystal',
#     'url': 'https://pokeapi.co/api/v2/version/6/'}},
#   {'game_index': 25,
#    'version': {'name': 'ruby', 'url': 'https://pokeapi.co/api/v2/version/7/'}},
#   {'game_index': 25,
#    'version': {'name': 'sapphire',
#     'url': 'https://pokeapi.co/api/v2/version/8/'}},
#   {'game_index': 25,
#    'version': {'name': 'emerald',
#     'url': 'https://pokeapi.co/api/v2/version/9/'}},
#   {'game_index': 25,
#    'version': {'name': 'firered',
#     'url': 'https://pokeapi.co/api/v2/version/10/'}},
#   {'game_index': 25,
#    'version': {'name': 'leafgreen',
#     'url': 'https://pokeapi.co/api/v2/version/11/'}},
#   {'game_index': 25,
#    'version': {'name': 'diamond',
#     'url': 'https://pokeapi.co/api/v2/version/12/'}},
#   {'game_index': 25,
#    'version': {'name': 'pearl',
#     'url': 'https://pokeapi.co/api/v2/version/13/'}},
#   {'game_index': 25,
#    'version': {'name': 'platinum',
#     'url': 'https://pokeapi.co/api/v2/version/14/'}},
#   {'game_index': 25,
#    'version': {'name': 'heartgold',
#     'url': 'https://pokeapi.co/api/v2/version/15/'}},
#   {'game_index': 25,
#    'version': {'name': 'soulsilver',
#     'url': 'https://pokeapi.co/api/v2/version/16/'}},
#   {'game_index': 25,
#    'version': {'name': 'black',
#     'url': 'https://pokeapi.co/api/v2/version/17/'}},
#   {'game_index': 25,
#    'version': {'name': 'white',
#     'url': 'https://pokeapi.co/api/v2/version/18/'}},
#   {'game_index': 25,
#    'version': {'name': 'black-2',
#     'url': 'https://pokeapi.co/api/v2/version/21/'}},
#   {'game_index': 25,
#    'version': {'name': 'white-2',
#     'url': 'https://pokeapi.co/api/v2/version/22/'}}],
#  'height': 4,
#  'held_items': [{'item': {'name': 'oran-berry',
#     'url': 'https://pokeapi.co/api/v2/item/132/'},
#    'version_details': [{'rarity': 50,
#      'version': {'name': 'ruby',
#       'url': 'https://pokeapi.co/api/v2/version/7/'}},
#     {'rarity': 50,
#      'version': {'name': 'sapphire',
#       'url': 'https://pokeapi.co/api/v2/version/8/'}},
#     {'rarity': 50,
#      'version': {'name': 'emerald',
#       'url': 'https://pokeapi.co/api/v2/version/9/'}},
#     {'rarity': 50,
#      'version': {'name': 'diamond',
#       'url': 'https://pokeapi.co/api/v2/version/12/'}},
#     {'rarity': 50,
#      'version': {'name': 'pearl',
#       'url': 'https://pokeapi.co/api/v2/version/13/'}},
#     {'rarity': 50,
#      'version': {'name': 'platinum',
#       'url': 'https://pokeapi.co/api/v2/version/14/'}},
#     {'rarity': 50,
#      'version': {'name': 'heartgold',
#       'url': 'https://pokeapi.co/api/v2/version/15/'}},
#     {'rarity': 50,
#      'version': {'name': 'soulsilver',
#       'url': 'https://pokeapi.co/api/v2/version/16/'}},
#     {'rarity': 50,
#      'version': {'name': 'black',
#       'url': 'https://pokeapi.co/api/v2/version/17/'}},
#     {'rarity': 50,
#      'version': {'name': 'white',
#       'url': 'https://pokeapi.co/api/v2/version/18/'}}]},
#   {'item': {'name': 'light-ball',
#     'url': 'https://pokeapi.co/api/v2/item/213/'},
#    'version_details': [{'rarity': 5,
#      'version': {'name': 'ruby',
#       'url': 'https://pokeapi.co/api/v2/version/7/'}},
#     {'rarity': 5,
#      'version': {'name': 'sapphire',
#       'url': 'https://pokeapi.co/api/v2/version/8/'}},
#     {'rarity': 5,
#      'version': {'name': 'emerald',
#       'url': 'https://pokeapi.co/api/v2/version/9/'}},
#     {'rarity': 5,
#      'version': {'name': 'diamond',
#       'url': 'https://pokeapi.co/api/v2/version/12/'}},
#     {'rarity': 5,
#      'version': {'name': 'pearl',
#       'url': 'https://pokeapi.co/api/v2/version/13/'}},
#     {'rarity': 5,
#      'version': {'name': 'platinum',
#       'url': 'https://pokeapi.co/api/v2/version/14/'}},
#     {'rarity': 5,
#      'version': {'name': 'heartgold',
#       'url': 'https://pokeapi.co/api/v2/version/15/'}},
#     {'rarity': 5,
#      'version': {'name': 'soulsilver',
#       'url': 'https://pokeapi.co/api/v2/version/16/'}},
#     {'rarity': 1,
#      'version': {'name': 'black',
#       'url': 'https://pokeapi.co/api/v2/version/17/'}},
#     {'rarity': 1,
#      'version': {'name': 'white',
#       'url': 'https://pokeapi.co/api/v2/version/18/'}},
#     {'rarity': 5,
#      'version': {'name': 'black-2',
#       'url': 'https://pokeapi.co/api/v2/version/21/'}},
#     {'rarity': 5,
#      'version': {'name': 'white-2',
#       'url': 'https://pokeapi.co/api/v2/version/22/'}},
#     {'rarity': 5,
#      'version': {'name': 'x', 'url': 'https://pokeapi.co/api/v2/version/23/'}},
#     {'rarity': 5,
#      'version': {'name': 'y', 'url': 'https://pokeapi.co/api/v2/version/24/'}},
#     {'rarity': 5,
#      'version': {'name': 'omega-ruby',
#       'url': 'https://pokeapi.co/api/v2/version/25/'}},
#     {'rarity': 5,
#      'version': {'name': 'alpha-sapphire',
#       'url': 'https://pokeapi.co/api/v2/version/26/'}},
#     {'rarity': 5,
#      'version': {'name': 'sun',
#       'url': 'https://pokeapi.co/api/v2/version/27/'}},
#     {'rarity': 5,
#      'version': {'name': 'moon',
#       'url': 'https://pokeapi.co/api/v2/version/28/'}},
#     {'rarity': 5,
#      'version': {'name': 'ultra-sun',
#       'url': 'https://pokeapi.co/api/v2/version/29/'}},
#     {'rarity': 5,
#      'version': {'name': 'ultra-moon',
#       'url': 'https://pokeapi.co/api/v2/version/30/'}}]}],
#  'id': 25,
#  'is_default': True,
#  'location_area_encounters': 'https://pokeapi.co/api/v2/pokemon/25/encounters',
#  'moves': [{'move': {'name': 'mega-punch',
#     'url': 'https://pokeapi.co/api/v2/move/5/'},
#    'version_group_details': [{'level_learned_at': 0,
#      'move_learn_method': {'name': 'machine',
#       'url': 'https://pokeapi.co/api/v2/move-learn-method/4/'},
#      'version_group': {'name': 'red-blue',
#       'url': 'https://pokeapi.co/api/v2/version-group/1/'}},
#     {'level_learned_at': 0,
#      'move_learn_method': {'name': 'machine',
#       'url': 'https://pokeapi.co/api/v2/move-learn-method/4/'},
#      'version_group': {'name': 'yellow',
#       'url': 'https://pokeapi.co/api/v2/version-group/2/'}},
#     {'level_learned_at': 0,
#      'move_learn_method': {'name': 'tutor',
#       'url': 'https://pokeapi.co/api/v2/move-learn-method/3/'},
#      'version_group': {'name': 'emerald',
#       'url': 'https://pokeapi.co/api/v2/version-group/6/'}},
#     {'level_learned_at': 0,
#      'move_learn_method': {'name': 'tutor',
#       'url': 'https://pokeapi.co/api/v2/move-learn-method/3/'},
#      'version_group': {'name': 'firered-leafgreen',
#       'url': 'https://pokeapi.co/api/v2/version-group/7/'}},
#     {'level_learned_at': 0,
#      'move_learn_method': {'name': 'machine',
#       'url': 'https://pokeapi.co/api/v2/move-learn-method/4/'},
#      'version_group': {'name': 'sword-shield',
#       'url': 'https://pokeapi.co/api/v2/version-group/20/'}}]},
#   {'move': {'name': 'pay-day', 'url': 'https://pokeapi.co/api/v2/move/6/'},
#    'version_group_details': [{'level_learned_at': 0,
#      'move_learn_method': {'name': 'machine',
#       'url': 'https://pokeapi.co/api/v2/move-learn-method/4/'},
#      'version_group': {'name': 'red-blue',
#       'url': 'https://pokeapi.co/api/v2/version-group/1/'}},
#     {'level_learned_at': 0,
#      'move_learn_method': {'name': 'machine',
#       'url': 'https://pokeapi.co/api/v2/move-learn-method/4/'},
#      'version_group': {'name': 'yellow',
#       'url': 'https://pokeapi.co/api/v2/version-group/2/'}},
#     {'level_learned_at': 0,
#      'move_learn_method': {'name': 'machine',
#       'url': 'https://pokeapi.co/api/v2/move-learn-method/4/'},
#      'version_group': {'name': 'lets-go-pikachu-lets-go-eevee',
#       'url': 'https://pokeapi.co/api/v2/version-group/19/'}},
#     {'level_learned_at': 0,
#      'move_learn_method': {'name': 'machine',
#       'url': 'https://pokeapi.co/api/v2/move-learn-method/4/'},
#      'version_group': {'name': 'sword-shield',
#       'url': 'https://pokeapi.co/api/v2/version-group/20/'}}]},
#   {'move': {'name': 'thunder-punch',
#     'url': 'https://pokeapi.co/api/v2/move/9/'},
#    'version_group_details': [{'level_learned_at': 0,
#      'move_learn_method': {'name': 'machine',
#       'url': 'https://pokeapi.co/api/v2/move-learn-method/4/'},
#      'version_group': {'name': 'gold-silver',
#       'url': 'https://pokeapi.co/api/v2/version-group/3/'}},
#     {'level_learned_at': 0,
#      'move_learn_method': {'name': 'machine',
#       'url': 'https://pokeapi.co/api/v2/move-learn-method/4/'},
#      'version_group': {'name': 'crystal',
#       'url': 'https://pokeapi.co/api/v2/version-group/4/'}},
#     {'level_learned_at': 0,
#      'move_learn_method': {'name': 'tutor',
#       'url': 'https://pokeapi.co/api/v2/move-learn-method/3/'},
#      'version_group': {'name': 'emerald',
#       'url': 'https://pokeapi.co/api/v2/version-group/6/'}},
#     {'level_learned_at': 0,
#      'move_learn_method': {'name': 'tutor',
#       'url': 'https://pokeapi.co/api/v2/move-learn-method/3/'},
#      'version_group': {'name': 'platinum',
#       'url': 'https://pokeapi.co/api/v2/version-group/9/'}},
#     {'level_learned_at': 0,
#      'move_learn_method': {'name': 'tutor',
#       'url': 'https://pokeapi.co/api/v2/move-learn-method/3/'},
#      'version_group': {'name': 'heartgold-soulsilver',
#       'url': 'https://pokeapi.co/api/v2/version-group/10/'}},
#     {'level_learned_at': 0,
#      'move_learn_method': {'name': 'tutor',
#       'url': 'https://pokeapi.co/api/v2/move-learn-method/3/'},
#      'version_group': {'name': 'black-2-white-2',
#       'url': 'https://pokeapi.co/api/v2/version-group/14/'}},
#     {'level_learned_at': 0,
#      'move_learn_method': {'name': 'tutor',
#       'url': 'https://pokeapi.co/api/v2/move-learn-method/3/'},
#      'version_group': {'name': 'omega-ruby-alpha-sapphire',
#       'url': 'https://pokeapi.co/api/v2/version-group/16/'}},
#     {'level_learned_at': 0,
#      'move_learn_method': {'name': 'tutor',
#       'url': 'https://pokeapi.co/api/v2/move-learn-method/3/'},
#      'version_group': {'name': 'ultra-sun-ultra-moon',
#       'url': 'https://pokeapi.co/api/v2/version-group/18/'}},
#     {'level_learned_at': 0,
#      'move_learn_method': {'name': 'machine',
#       'url': 'https://pokeapi.co/api/v2/move-learn-method/4/'},
#      'version_group': {'name': 'lets-go-pikachu-lets-go-eevee',
#       'url': 'https://pokeapi.co/api/v2/version-group/19/'}},
#     {'level_learned_at': 0,
#      'move_learn_method': {'name': 'machine',
#       'url': 'https://pokeapi.co/api/v2/move-learn-method/4/'},
#      'version_group': {'name': 'sword-shield',
#       'url': 'https://pokeapi.co/api/v2/version-group/20/'}}]},
#   {'move': {'name': 'slam', 'url': 'https://pokeapi.co/api/v2/move/21/'},
#    'version_group_details': [{'level_learned_at': 20,
#      'move_learn_method': {'name': 'level-up',
#       'url': 'https://pokeapi.co/api/v2/move-learn-method/1/'},
#      'version_group': {'name': 'yellow',
#       'url': 'https://pokeapi.co/api/v2/version-group/2/'}},
#     {'level_learned_at': 20,
#      'move_learn_method': {'name': 'level-up',
#       'url': 'https://pokeapi.co/api/v2/move-learn-method/1/'},
#      'version_group': {'name': 'gold-silver',
#       'url': 'https://pokeapi.co/api/v2/version-group/3/'}},
#     {'level_learned_at': 20,
#      'move_learn_method': {'name': 'level-up',
#       'url': 'https://pokeapi.co/api/v2/move-learn-method/1/'},
#      'version_group': {'name': 'crystal',
#       'url': 'https://pokeapi.co/api/v2/version-group/4/'}},
#     {'level_learned_at': 20,
#      'move_learn_method': {'name': 'level-up',
#       'url': 'https://pokeapi.co/api/v2/move-learn-method/1/'},
#      'version_group': {'name': 'ruby-sapphire',
#       'url': 'https://pokeapi.co/api/v2/version-group/5/'}},
#     {'level_learned_at': 20,
#      'move_learn_method': {'name': 'level-up',
#       'url': 'https://pokeapi.co/api/v2/move-learn-method/1/'},
#      'version_group': {'name': 'emerald',
#       'url': 'https://pokeapi.co/api/v2/version-group/6/'}},
#     {'level_learned_at': 20,
#      'move_learn_method': {'name': 'level-up',
#       'url': 'https://pokeapi.co/api/v2/move-learn-method/1/'},
#      'version_group': {'name': 'firered-leafgreen',
#       'url': 'https://pokeapi.co/api/v2/version-group/7/'}},
#     {'level_learned_at': 21,
#      'move_learn_method': {'name': 'level-up',
#       'url': 'https://pokeapi.co/api/v2/move-learn-method/1/'},
#      'version_group': {'name': 'diamond-pearl',
#       'url': 'https://pokeapi.co/api/v2/version-group/8/'}},
#     {'level_learned_at': 21,
#      'move_learn_method': {'name': 'level-up',
#       'url': 'https://pokeapi.co/api/v2/move-learn-method/1/'},
#      'version_group': {'name': 'platinum',
#       'url': 'https://pokeapi.co/api/v2/version-group/9/'}},
#     {'level_learned_at': 21,
#      'move_learn_method': {'name': 'level-up',
#       'url': 'https://pokeapi.co/api/v2/move-learn-method/1/'},
#      'version_group': {'name': 'heartgold-soulsilver',
#       'url': 'https://pokeapi.co/api/v2/version-group/10/'}},
#     {'level_learned_at': 26,
#      'move_learn_method': {'name': 'level-up',
#       'url': 'https://pokeapi.co/api/v2/move-learn-method/1/'},
#      'version_group': {'name': 'black-white',
#       'url': 'https://pokeapi.co/api/v2/version-group/11/'}},
#     {'level_learned_at': 20,
#      'move_learn_method': {'name': 'level-up',
#       'url': 'https://pokeapi.co/api/v2/move-learn-method/1/'},
#      'version_group': {'name': 'colosseum',
#       'url': 'https://pokeapi.co/api/v2/version-group/12/'}},
#     {'level_learned_at': 20,
#      'move_learn_method': {'name': 'level-up',
#       'url': 'https://pokeapi.co/api/v2/move-learn-method/1/'},
#      'version_group': {'name': 'xd',
#       'url': 'https://pokeapi.co/api/v2/version-group/13/'}},
#     {'level_learned_at': 26,
#      'move_learn_method': {'name': 'level-up',
#       'url': 'https://pokeapi.co/api/v2/move-learn-method/1/'},
#      'version_group': {'name': 'black-2-white-2',
#       'url': 'https://pokeapi.co/api/v2/version-group/14/'}},
#     {'level_learned_at': 26,
#      'move_learn_method': {'name': 'level-up',
#       'url': 'https://pokeapi.co/api/v2/move-learn-method/1/'},
#      'version_group': {'name': 'x-y',
#       'url': 'https://pokeapi.co/api/v2/version-group/15/'}},
#     {'level_learned_at': 37,
#      'move_learn_method': {'name': 'level-up',
#       'url': 'https://pokeapi.co/api/v2/move-learn-method/1/'},
#      'version_group': {'name': 'omega-ruby-alpha-sapphire',
#       'url': 'https://pokeapi.co/api/v2/version-group/16/'}},
#     {'level_learned_at': 37,
#      'move_learn_method': {'name': 'level-up',
#       'url': 'https://pokeapi.co/api/v2/move-learn-method/1/'},
#      'version_group': {'name': 'sun-moon',
#       'url': 'https://pokeapi.co/api/v2/version-group/17/'}},
#     {'level_learned_at': 37,
#      'move_learn_method': {'name': 'level-up',
#       'url': 'https://pokeapi.co/api/v2/move-learn-method/1/'},
#      'version_group': {'name': 'ultra-sun-ultra-moon',
#       'url': 'https://pokeapi.co/api/v2/version-group/18/'}},
#     {'level_learned_at': 24,
#      'move_learn_method': {'name': 'level-up',
#       'url': 'https://pokeapi.co/api/v2/move-learn-method/1/'},
#      'version_group': {'name': 'lets-go-pikachu-lets-go-eevee',
#       'url': 'https://pokeapi.co/api/v2/version-group/19/'}},
#     {'level_learned_at': 28,
#      'move_learn_method': {'name': 'level-up',
#       'url': 'https://pokeapi.co/api/v2/move-learn-method/1/'},
#      'version_group': {'name': 'sword-shield',
#       'url': 'https://pokeapi.co/api/v2/version-group/20/'}}]},
#   {'move': {'name': 'double-kick',
#     'url': 'https://pokeapi.co/api/v2/move/24/'},
#    'version_group_details': [{'level_learned_at': 9,
#      'move_learn_method': {'name': 'level-up',
#       'url': 'https://pokeapi.co/api/v2/move-learn-method/1/'},
#      'version_group': {'name': 'lets-go-pikachu-lets-go-eevee',
#       'url': 'https://pokeapi.co/api/v2/version-group/19/'}}]},
#   {'move': {'name': 'mega-kick', 'url': 'https://pokeapi.co/api/v2/move/25/'},
#    'version_group_details': [{'level_learned_at': 0,
#      'move_learn_method': {'name': 'machine',
#       'url': 'https://pokeapi.co/api/v2/move-learn-method/4/'},
#      'version_group': {'name': 'red-blue',
#       'url': 'https://pokeapi.co/api/v2/version-group/1/'}},
#     {'level_learned_at': 0,
#      'move_learn_method': {'name': 'machine',
#       'url': 'https://pokeapi.co/api/v2/move-learn-method/4/'},
#      'version_group': {'name': 'yellow',
#       'url': 'https://pokeapi.co/api/v2/version-group/2/'}},
#     {'level_learned_at': 0,
#      'move_learn_method': {'name': 'tutor',
#       'url': 'https://pokeapi.co/api/v2/move-learn-method/3/'},
#      'version_group': {'name': 'emerald',
#       'url': 'https://pokeapi.co/api/v2/version-group/6/'}},
#     {'level_learned_at': 0,
#      'move_learn_method': {'name': 'tutor',
#       'url': 'https://pokeapi.co/api/v2/move-learn-method/3/'},
#      'version_group': {'name': 'firered-leafgreen',
#       'url': 'https://pokeapi.co/api/v2/version-group/7/'}},
#     {'level_learned_at': 0,
#      'move_learn_method': {'name': 'machine',
#       'url': 'https://pokeapi.co/api/v2/move-learn-method/4/'},
#      'version_group': {'name': 'sword-shield',
#       'url': 'https://pokeapi.co/api/v2/version-group/20/'}}]},
#   {'move': {'name': 'headbutt', 'url': 'https://pokeapi.co/api/v2/move/29/'},
#    'version_group_details': [{'level_learned_at': 0,
#      'move_learn_method': {'name': 'machine',
#       'url': 'https://pokeapi.co/api/v2/move-learn-method/4/'},
#      'version_group': {'name': 'gold-silver',
#       'url': 'https://pokeapi.co/api/v2/version-group/3/'}},
#     {'level_learned_at': 0,
#      'move_learn_method': {'name': 'machine',
#       'url': 'https://pokeapi.co/api/v2/move-learn-method/4/'},
#      'version_group': {'name': 'crystal',
#       'url': 'https://pokeapi.co/api/v2/version-group/4/'}},
#     {'level_learned_at': 0,
#      'move_learn_method': {'name': 'tutor',
#       'url': 'https://pokeapi.co/api/v2/move-learn-method/3/'},
#      'version_group': {'name': 'heartgold-soulsilver',
#       'url': 'https://pokeapi.co/api/v2/version-group/10/'}},
#     {'level_learned_at': 0,
#      'move_learn_method': {'name': 'machine',
#       'url': 'https://pokeapi.co/api/v2/move-learn-method/4/'},
#      'version_group': {'name': 'lets-go-pikachu-lets-go-eevee',
#       'url': 'https://pokeapi.co/api/v2/version-group/19/'}}]},
#   {'move': {'name': 'body-slam', 'url': 'https://pokeapi.co/api/v2/move/34/'},
#    'version_group_details': [{'level_learned_at': 0,
#      'move_learn_method': {'name': 'machine',
#       'url': 'https://pokeapi.co/api/v2/move-learn-method/4/'},
#      'version_group': {'name': 'red-blue',
#       'url': 'https://pokeapi.co/api/v2/version-group/1/'}},
#     {'level_learned_at': 0,
#      'move_learn_method': {'name': 'machine',
#       'url': 'https://pokeapi.co/api/v2/move-learn-method/4/'},
#      'version_group': {'name': 'yellow',
#       'url': 'https://pokeapi.co/api/v2/version-group/2/'}},
#     {'level_learned_at': 0,
#      'move_learn_method': {'name': 'tutor',
#       'url': 'https://pokeapi.co/api/v2/move-learn-method/3/'},
#      'version_group': {'name': 'emerald',
#       'url': 'https://pokeapi.co/api/v2/version-group/6/'}},
#     {'level_learned_at': 0,
#      'move_learn_method': {'name': 'tutor',
#       'url': 'https://pokeapi.co/api/v2/move-learn-method/3/'},
#      'version_group': {'name': 'firered-leafgreen',
#       'url': 'https://pokeapi.co/api/v2/version-group/7/'}},
#     {'level_learned_at': 0,
#      'move_learn_method': {'name': 'tutor',
#       'url': 'https://pokeapi.co/api/v2/move-learn-method/3/'},
#      'version_group': {'name': 'xd',
#       'url': 'https://pokeapi.co/api/v2/version-group/13/'}},
#     {'level_learned_at': 0,
#      'move_learn_method': {'name': 'machine',
#       'url': 'https://pokeapi.co/api/v2/move-learn-method/4/'},
#      'version_group': {'name': 'sword-shield',
#       'url': 'https://pokeapi.co/api/v2/version-group/20/'}}]},
#   {'move': {'name': 'take-down', 'url': 'https://pokeapi.co/api/v2/move/36/'},
#    'version_group_details': [{'level_learned_at': 0,
#      'move_learn_method': {'name': 'machine',
#       'url': 'https://pokeapi.co/api/v2/move-learn-method/4/'},
#      'version_group': {'name': 'red-blue',
#       'url': 'https://pokeapi.co/api/v2/version-group/1/'}},
#     {'level_learned_at': 0,
#      'move_learn_method': {'name': 'machine',
#       'url': 'https://pokeapi.co/api/v2/move-learn-method/4/'},
#      'version_group': {'name': 'yellow',
#       'url': 'https://pokeapi.co/api/v2/version-group/2/'}}]},
#   {'move': {'name': 'double-edge',
#     'url': 'https://pokeapi.co/api/v2/move/38/'},
#    'version_group_details': [{'level_learned_at': 0,
#      'move_learn_method': {'name': 'machine',
#       'url': 'https://pokeapi.co/api/v2/move-learn-method/4/'},
#      'version_group': {'name': 'red-blue',
#       'url': 'https://pokeapi.co/api/v2/version-group/1/'}},
#     {'level_learned_at': 0,
#      'move_learn_method': {'name': 'machine',
#       'url': 'https://pokeapi.co/api/v2/move-learn-method/4/'},
#      'version_group': {'name': 'yellow',
#       'url': 'https://pokeapi.co/api/v2/version-group/2/'}},
#     {'level_learned_at': 0,
#      'move_learn_method': {'name': 'tutor',
#       'url': 'https://pokeapi.co/api/v2/move-learn-method/3/'},
#      'version_group': {'name': 'emerald',
#       'url': 'https://pokeapi.co/api/v2/version-group/6/'}},
#     {'level_learned_at': 0,
#      'move_learn_method': {'name': 'tutor',
#       'url': 'https://pokeapi.co/api/v2/move-learn-method/3/'},
#      'version_group': {'name': 'firered-leafgreen',
#       'url': 'https://pokeapi.co/api/v2/version-group/7/'}},
#     {'level_learned_at': 0,
#      'move_learn_method': {'name': 'tutor',
#       'url': 'https://pokeapi.co/api/v2/move-learn-method/3/'},
#      'version_group': {'name': 'xd',
#       'url': 'https://pokeapi.co/api/v2/version-group/13/'}}]},
#   {'move': {'name': 'tail-whip', 'url': 'https://pokeapi.co/api/v2/move/39/'},
#    'version_group_details': [{'level_learned_at': 6,
#      'move_learn_method': {'name': 'level-up',
#       'url': 'https://pokeapi.co/api/v2/move-learn-method/1/'},
#      'version_group': {'name': 'yellow',
#       'url': 'https://pokeapi.co/api/v2/version-group/2/'}},
#     {'level_learned_at': 6,
#      'move_learn_method': {'name': 'level-up',
#       'url': 'https://pokeapi.co/api/v2/move-learn-method/1/'},
#      'version_group': {'name': 'gold-silver',
#       'url': 'https://pokeapi.co/api/v2/version-group/3/'}},
#     {'level_learned_at': 6,
#      'move_learn_method': {'name': 'level-up',
#       'url': 'https://pokeapi.co/api/v2/move-learn-method/1/'},
#      'version_group': {'name': 'crystal',
#       'url': 'https://pokeapi.co/api/v2/version-group/4/'}},
#     {'level_learned_at': 6,
#      'move_learn_method': {'name': 'level-up',
#       'url': 'https://pokeapi.co/api/v2/move-learn-method/1/'},
#      'version_group': {'name': 'ruby-sapphire',
#       'url': 'https://pokeapi.co/api/v2/version-group/5/'}},
#     {'level_learned_at': 6,
#      'move_learn_method': {'name': 'level-up',
#       'url': 'https://pokeapi.co/api/v2/move-learn-method/1/'},
#      'version_group': {'name': 'emerald',
#       'url': 'https://pokeapi.co/api/v2/version-group/6/'}},
#     {'level_learned_at': 6,
#      'move_learn_method': {'name': 'level-up',
#       'url': 'https://pokeapi.co/api/v2/move-learn-method/1/'},
#      'version_group': {'name': 'firered-leafgreen',
#       'url': 'https://pokeapi.co/api/v2/version-group/7/'}},
#     {'level_learned_at': 5,
#      'move_learn_method': {'name': 'level-up',
#       'url': 'https://pokeapi.co/api/v2/move-learn-method/1/'},
#      'version_group': {'name': 'diamond-pearl',
#       'url': 'https://pokeapi.co/api/v2/version-group/8/'}},
#     {'level_learned_at': 5,
#      'move_learn_method': {'name': 'level-up',
#       'url': 'https://pokeapi.co/api/v2/move-learn-method/1/'},
#      'version_group': {'name': 'platinum',
#       'url': 'https://pokeapi.co/api/v2/version-group/9/'}},
#     {'level_learned_at': 5,
#      'move_learn_method': {'name': 'level-up',
#       'url': 'https://pokeapi.co/api/v2/move-learn-method/1/'},
#      'version_group': {'name': 'heartgold-soulsilver',
#       'url': 'https://pokeapi.co/api/v2/version-group/10/'}},
#     {'level_learned_at': 5,
#      'move_learn_method': {'name': 'level-up',
#       'url': 'https://pokeapi.co/api/v2/move-learn-method/1/'},
#      'version_group': {'name': 'black-white',
#       'url': 'https://pokeapi.co/api/v2/version-group/11/'}},
#     {'level_learned_at': 6,
#      'move_learn_method': {'name': 'level-up',
#       'url': 'https://pokeapi.co/api/v2/move-learn-method/1/'},
#      'version_group': {'name': 'colosseum',
#       'url': 'https://pokeapi.co/api/v2/version-group/12/'}},
#     {'level_learned_at': 6,
#      'move_learn_method': {'name': 'level-up',
#       'url': 'https://pokeapi.co/api/v2/move-learn-method/1/'},
#      'version_group': {'name': 'xd',
#       'url': 'https://pokeapi.co/api/v2/version-group/13/'}},
#     {'level_learned_at': 5,
#      'move_learn_method': {'name': 'level-up',
#       'url': 'https://pokeapi.co/api/v2/move-learn-method/1/'},
#      'version_group': {'name': 'black-2-white-2',
#       'url': 'https://pokeapi.co/api/v2/version-group/14/'}},
#     {'level_learned_at': 1,
#      'move_learn_method': {'name': 'level-up',
#       'url': 'https://pokeapi.co/api/v2/move-learn-method/1/'},
#      'version_group': {'name': 'x-y',
#       'url': 'https://pokeapi.co/api/v2/version-group/15/'}},
#     {'level_learned_at': 1,
#      'move_learn_method': {'name': 'level-up',
#       'url': 'https://pokeapi.co/api/v2/move-learn-method/1/'},
#      'version_group': {'name': 'omega-ruby-alpha-sapphire',
#       'url': 'https://pokeapi.co/api/v2/version-group/16/'}},
#     {'level_learned_at': 1,
#      'move_learn_method': {'name': 'level-up',
#       'url': 'https://pokeapi.co/api/v2/move-learn-method/1/'},
#      'version_group': {'name': 'sun-moon',
#       'url': 'https://pokeapi.co/api/v2/version-group/17/'}},
#     {'level_learned_at': 1,
#      'move_learn_method': {'name': 'level-up',
#       'url': 'https://pokeapi.co/api/v2/move-learn-method/1/'},
#      'version_group': {'name': 'ultra-sun-ultra-moon',
#       'url': 'https://pokeapi.co/api/v2/version-group/18/'}},
#     {'level_learned_at': 3,
#      'move_learn_method': {'name': 'level-up',
#       'url': 'https://pokeapi.co/api/v2/move-learn-method/1/'},
#      'version_group': {'name': 'lets-go-pikachu-lets-go-eevee',
#       'url': 'https://pokeapi.co/api/v2/version-group/19/'}},
#     {'level_learned_at': 1,
#      'move_learn_method': {'name': 'level-up',
#       'url': 'https://pokeapi.co/api/v2/move-learn-method/1/'},
#      'version_group': {'name': 'sword-shield',
#       'url': 'https://pokeapi.co/api/v2/version-group/20/'}}]},
#   {'move': {'name': 'growl', 'url': 'https://pokeapi.co/api/v2/move/45/'},
#    'version_group_details': [{'level_learned_at': 1,
#      'move_learn_method': {'name': 'level-up',
#       'url': 'https://pokeapi.co/api/v2/move-learn-method/1/'},
#      'version_group': {'name': 'red-blue',
#       'url': 'https://pokeapi.co/api/v2/version-group/1/'}},
#     {'level_learned_at': 1,
#      'move_learn_method': {'name': 'level-up',
#       'url': 'https://pokeapi.co/api/v2/move-learn-method/1/'},
#      'version_group': {'name': 'yellow',
#       'url': 'https://pokeapi.co/api/v2/version-group/2/'}},
#     {'level_learned_at': 1,
#      'move_learn_method': {'name': 'level-up',
#       'url': 'https://pokeapi.co/api/v2/move-learn-method/1/'},
#      'version_group': {'name': 'gold-silver',
#       'url': 'https://pokeapi.co/api/v2/version-group/3/'}},
#     {'level_learned_at': 1,
#      'move_learn_method': {'name': 'level-up',
#       'url': 'https://pokeapi.co/api/v2/move-learn-method/1/'},
#      'version_group': {'name': 'crystal',
#       'url': 'https://pokeapi.co/api/v2/version-group/4/'}},
#     {'level_learned_at': 1,
#      'move_learn_method': {'name': 'level-up',
#       'url': 'https://pokeapi.co/api/v2/move-learn-method/1/'},
#      'version_group': {'name': 'ruby-sapphire',
#       'url': 'https://pokeapi.co/api/v2/version-group/5/'}},
#     {'level_learned_at': 1,
#      'move_learn_method': {'name': 'level-up',
#       'url': 'https://pokeapi.co/api/v2/move-learn-method/1/'},
#      'version_group': {'name': 'emerald',
#       'url': 'https://pokeapi.co/api/v2/version-group/6/'}},
#     {'level_learned_at': 1,
#      'move_learn_method': {'name': 'level-up',
#       'url': 'https://pokeapi.co/api/v2/move-learn-method/1/'},
#      'version_group': {'name': 'firered-leafgreen',
#       'url': 'https://pokeapi.co/api/v2/version-group/7/'}},
#     {'level_learned_at': 1,
#      'move_learn_method': {'name': 'level-up',
#       'url': 'https://pokeapi.co/api/v2/move-learn-method/1/'},
#      'version_group': {'name': 'diamond-pearl',
#       'url': 'https://pokeapi.co/api/v2/version-group/8/'}},
#     {'level_learned_at': 1,
#      'move_learn_method': {'name': 'level-up',
#       'url': 'https://pokeapi.co/api/v2/move-learn-method/1/'},
#      'version_group': {'name': 'platinum',
#       'url': 'https://pokeapi.co/api/v2/version-group/9/'}},
#     {'level_learned_at': 1,
#      'move_learn_method': {'name': 'level-up',
#       'url': 'https://pokeapi.co/api/v2/move-learn-method/1/'},
#      'version_group': {'name': 'heartgold-soulsilver',
#       'url': 'https://pokeapi.co/api/v2/version-group/10/'}},
#     {'level_learned_at': 1,
#      'move_learn_method': {'name': 'level-up',
#       'url': 'https://pokeapi.co/api/v2/move-learn-method/1/'},
#      'version_group': {'name': 'black-white',
#       'url': 'https://pokeapi.co/api/v2/version-group/11/'}},
#     {'level_learned_at': 1,
#      'move_learn_method': {'name': 'level-up',
#       'url': 'https://pokeapi.co/api/v2/move-learn-method/1/'},
#      'version_group': {'name': 'colosseum',
#       'url': 'https://pokeapi.co/api/v2/version-group/12/'}},
#     {'level_learned_at': 1,
#      'move_learn_method': {'name': 'level-up',
#       'url': 'https://pokeapi.co/api/v2/move-learn-method/1/'},
#      'version_group': {'name': 'xd',
#       'url': 'https://pokeapi.co/api/v2/version-group/13/'}},
#     {'level_learned_at': 1,
#      'move_learn_method': {'name': 'level-up',
#       'url': 'https://pokeapi.co/api/v2/move-learn-method/1/'},
#      'version_group': {'name': 'black-2-white-2',
#       'url': 'https://pokeapi.co/api/v2/version-group/14/'}},
#     {'level_learned_at': 5,
#      'move_learn_method': {'name': 'level-up',
#       'url': 'https://pokeapi.co/api/v2/move-learn-method/1/'},
#      'version_group': {'name': 'x-y',
#       'url': 'https://pokeapi.co/api/v2/version-group/15/'}},
#     {'level_learned_at': 5,
#      'move_learn_method': {'name': 'level-up',
#       'url': 'https://pokeapi.co/api/v2/move-learn-method/1/'},
#      'version_group': {'name': 'omega-ruby-alpha-sapphire',
#       'url': 'https://pokeapi.co/api/v2/version-group/16/'}},
#     {'level_learned_at': 5,
#      'move_learn_method': {'name': 'level-up',
#       'url': 'https://pokeapi.co/api/v2/move-learn-method/1/'},
#      'version_group': {'name': 'sun-moon',
#       'url': 'https://pokeapi.co/api/v2/version-group/17/'}},
#     {'level_learned_at': 5,
#      'move_learn_method': {'name': 'level-up',
#       'url': 'https://pokeapi.co/api/v2/move-learn-method/1/'},
#      'version_group': {'name': 'ultra-sun-ultra-moon',
#       'url': 'https://pokeapi.co/api/v2/version-group/18/'}},
#     {'level_learned_at': 1,
#      'move_learn_method': {'name': 'level-up',
#       'url': 'https://pokeapi.co/api/v2/move-learn-method/1/'},
#      'version_group': {'name': 'lets-go-pikachu-lets-go-eevee',
#       'url': 'https://pokeapi.co/api/v2/version-group/19/'}},
#     {'level_learned_at': 1,
#      'move_learn_method': {'name': 'level-up',
#       'url': 'https://pokeapi.co/api/v2/move-learn-method/1/'},
#      'version_group': {'name': 'sword-shield',
#       'url': 'https://pokeapi.co/api/v2/version-group/20/'}}]},
#   {'move': {'name': 'surf', 'url': 'https://pokeapi.co/api/v2/move/57/'},
#    'version_group_details': [{'level_learned_at': 0,
#      'move_learn_method': {'name': 'stadium-surfing-pikachu',
#       'url': 'https://pokeapi.co/api/v2/move-learn-method/5/'},
#      'version_group': {'name': 'red-blue',
#       'url': 'https://pokeapi.co/api/v2/version-group/1/'}},
#     {'level_learned_at': 0,
#      'move_learn_method': {'name': 'stadium-surfing-pikachu',
#       'url': 'https://pokeapi.co/api/v2/move-learn-method/5/'},
#      'version_group': {'name': 'yellow',
#       'url': 'https://pokeapi.co/api/v2/version-group/2/'}},
#     {'level_learned_at': 0,
#      'move_learn_method': {'name': 'machine',
#       'url': 'https://pokeapi.co/api/v2/move-learn-method/4/'},
#      'version_group': {'name': 'sword-shield',
#       'url': 'https://pokeapi.co/api/v2/version-group/20/'}}]},
#   {'move': {'name': 'submission', 'url': 'https://pokeapi.co/api/v2/move/66/'},
#    'version_group_details': [{'level_learned_at': 0,
#      'move_learn_method': {'name': 'machine',
#       'url': 'https://pokeapi.co/api/v2/move-learn-method/4/'},
#      'version_group': {'name': 'red-blue',
#       'url': 'https://pokeapi.co/api/v2/version-group/1/'}},
#     {'level_learned_at': 0,
#      'move_learn_method': {'name': 'machine',
#       'url': 'https://pokeapi.co/api/v2/move-learn-method/4/'},
#      'version_group': {'name': 'yellow',
#       'url': 'https://pokeapi.co/api/v2/version-group/2/'}}]},
#   {'move': {'name': 'counter', 'url': 'https://pokeapi.co/api/v2/move/68/'},
#    'version_group_details': [{'level_learned_at': 0,
#      'move_learn_method': {'name': 'tutor',
#       'url': 'https://pokeapi.co/api/v2/move-learn-method/3/'},
#      'version_group': {'name': 'emerald',
#       'url': 'https://pokeapi.co/api/v2/version-group/6/'}},
#     {'level_learned_at': 0,
#      'move_learn_method': {'name': 'tutor',
#       'url': 'https://pokeapi.co/api/v2/move-learn-method/3/'},
#      'version_group': {'name': 'firered-leafgreen',
#       'url': 'https://pokeapi.co/api/v2/version-group/7/'}}]},
#   {'move': {'name': 'seismic-toss',
#     'url': 'https://pokeapi.co/api/v2/move/69/'},
#    'version_group_details': [{'level_learned_at': 0,
#      'move_learn_method': {'name': 'machine',
#       'url': 'https://pokeapi.co/api/v2/move-learn-method/4/'},
#      'version_group': {'name': 'red-blue',
#       'url': 'https://pokeapi.co/api/v2/version-group/1/'}},
#     {'level_learned_at': 0,
#      'move_learn_method': {'name': 'machine',
#       'url': 'https://pokeapi.co/api/v2/move-learn-method/4/'},
#      'version_group': {'name': 'yellow',
#       'url': 'https://pokeapi.co/api/v2/version-group/2/'}},
#     {'level_learned_at': 0,
#      'move_learn_method': {'name': 'tutor',
#       'url': 'https://pokeapi.co/api/v2/move-learn-method/3/'},
#      'version_group': {'name': 'emerald',
#       'url': 'https://pokeapi.co/api/v2/version-group/6/'}},
#     {'level_learned_at': 0,
#      'move_learn_method': {'name': 'tutor',
#       'url': 'https://pokeapi.co/api/v2/move-learn-method/3/'},
#      'version_group': {'name': 'firered-leafgreen',
#       'url': 'https://pokeapi.co/api/v2/version-group/7/'}},
#     {'level_learned_at': 0,
#      'move_learn_method': {'name': 'tutor',
#       'url': 'https://pokeapi.co/api/v2/move-learn-method/3/'},
#      'version_group': {'name': 'xd',
#       'url': 'https://pokeapi.co/api/v2/version-group/13/'}},
#     {'level_learned_at': 0,
#      'move_learn_method': {'name': 'machine',
#       'url': 'https://pokeapi.co/api/v2/move-learn-method/4/'},
#      'version_group': {'name': 'lets-go-pikachu-lets-go-eevee',
#       'url': 'https://pokeapi.co/api/v2/version-group/19/'}}]},
#   {'move': {'name': 'strength', 'url': 'https://pokeapi.co/api/v2/move/70/'},
#    'version_group_details': [{'level_learned_at': 0,
#      'move_learn_method': {'name': 'machine',
#       'url': 'https://pokeapi.co/api/v2/move-learn-method/4/'},
#      'version_group': {'name': 'gold-silver',
#       'url': 'https://pokeapi.co/api/v2/version-group/3/'}},
#     {'level_learned_at': 0,
#      'move_learn_method': {'name': 'machine',
#       'url': 'https://pokeapi.co/api/v2/move-learn-method/4/'},
#      'version_group': {'name': 'crystal',
#       'url': 'https://pokeapi.co/api/v2/version-group/4/'}},
#     {'level_learned_at': 0,
#      'move_learn_method': {'name': 'machine',
#       'url': 'https://pokeapi.co/api/v2/move-learn-method/4/'},
#      'version_group': {'name': 'ruby-sapphire',
#       'url': 'https://pokeapi.co/api/v2/version-group/5/'}},
#     {'level_learned_at': 0,
#      'move_learn_method': {'name': 'machine',
#       'url': 'https://pokeapi.co/api/v2/move-learn-method/4/'},
#      'version_group': {'name': 'emerald',
#       'url': 'https://pokeapi.co/api/v2/version-group/6/'}},
#     {'level_learned_at': 0,
#      'move_learn_method': {'name': 'machine',
#       'url': 'https://pokeapi.co/api/v2/move-learn-method/4/'},
#      'version_group': {'name': 'firered-leafgreen',
#       'url': 'https://pokeapi.co/api/v2/version-group/7/'}},
#     {'level_learned_at': 0,
#      'move_learn_method': {'name': 'machine',
#       'url': 'https://pokeapi.co/api/v2/move-learn-method/4/'},
#      'version_group': {'name': 'diamond-pearl',
#       'url': 'https://pokeapi.co/api/v2/version-group/8/'}},
#     {'level_learned_at': 0,
#      'move_learn_method': {'name': 'machine',
#       'url': 'https://pokeapi.co/api/v2/move-learn-method/4/'},
#      'version_group': {'name': 'platinum',
#       'url': 'https://pokeapi.co/api/v2/version-group/9/'}},
#     {'level_learned_at': 0,
#      'move_learn_method': {'name': 'machine',
#       'url': 'https://pokeapi.co/api/v2/move-learn-method/4/'},
#      'version_group': {'name': 'heartgold-soulsilver',
#       'url': 'https://pokeapi.co/api/v2/version-group/10/'}},
#     {'level_learned_at': 0,
#      'move_learn_method': {'name': 'machine',
#       'url': 'https://pokeapi.co/api/v2/move-learn-method/4/'},
#      'version_group': {'name': 'black-white',
#       'url': 'https://pokeapi.co/api/v2/version-group/11/'}},
#     {'level_learned_at': 0,
#      'move_learn_method': {'name': 'machine',
#       'url': 'https://pokeapi.co/api/v2/move-learn-method/4/'},
#      'version_group': {'name': 'colosseum',
#       'url': 'https://pokeapi.co/api/v2/version-group/12/'}},
#     {'level_learned_at': 0,
#      'move_learn_method': {'name': 'machine',
#       'url': 'https://pokeapi.co/api/v2/move-learn-method/4/'},
#      'version_group': {'name': 'xd',
#       'url': 'https://pokeapi.co/api/v2/version-group/13/'}},
#     {'level_learned_at': 0,
#      'move_learn_method': {'name': 'machine',
#       'url': 'https://pokeapi.co/api/v2/move-learn-method/4/'},
#      'version_group': {'name': 'black-2-white-2',
#       'url': 'https://pokeapi.co/api/v2/version-group/14/'}},
#     {'level_learned_at': 0,
#      'move_learn_method': {'name': 'machine',
#       'url': 'https://pokeapi.co/api/v2/move-learn-method/4/'},
#      'version_group': {'name': 'x-y',
#       'url': 'https://pokeapi.co/api/v2/version-group/15/'}},
#     {'level_learned_at': 0,
#      'move_learn_method': {'name': 'machine',
#       'url': 'https://pokeapi.co/api/v2/move-learn-method/4/'},
#      'version_group': {'name': 'omega-ruby-alpha-sapphire',
#       'url': 'https://pokeapi.co/api/v2/version-group/16/'}}]},
#   {'move': {'name': 'thunder-shock',
#     'url': 'https://pokeapi.co/api/v2/move/84/'},
#    'version_group_details': [{'level_learned_at': 1,
#      'move_learn_method': {'name': 'level-up',
#       'url': 'https://pokeapi.co/api/v2/move-learn-method/1/'},
#      'version_group': {'name': 'red-blue',
#       'url': 'https://pokeapi.co/api/v2/version-group/1/'}},
#     {'level_learned_at': 1,
#      'move_learn_method': {'name': 'level-up',
#       'url': 'https://pokeapi.co/api/v2/move-learn-method/1/'},
#      'version_group': {'name': 'yellow',
#       'url': 'https://pokeapi.co/api/v2/version-group/2/'}},
#     {'level_learned_at': 1,
#      'move_learn_method': {'name': 'level-up',
#       'url': 'https://pokeapi.co/api/v2/move-learn-method/1/'},
#      'version_group': {'name': 'gold-silver',
#       'url': 'https://pokeapi.co/api/v2/version-group/3/'}},
#     {'level_learned_at': 1,
#      'move_learn_method': {'name': 'level-up',
#       'url': 'https://pokeapi.co/api/v2/move-learn-method/1/'},
#      'version_group': {'name': 'crystal',
#       'url': 'https://pokeapi.co/api/v2/version-group/4/'}},
#     {'level_learned_at': 1,
#      'move_learn_method': {'name': 'level-up',
#       'url': 'https://pokeapi.co/api/v2/move-learn-method/1/'},
#      'version_group': {'name': 'ruby-sapphire',
#       'url': 'https://pokeapi.co/api/v2/version-group/5/'}},
#     {'level_learned_at': 1,
#      'move_learn_method': {'name': 'level-up',
#       'url': 'https://pokeapi.co/api/v2/move-learn-method/1/'},
#      'version_group': {'name': 'emerald',
#       'url': 'https://pokeapi.co/api/v2/version-group/6/'}},
#     {'level_learned_at': 1,
#      'move_learn_method': {'name': 'level-up',
#       'url': 'https://pokeapi.co/api/v2/move-learn-method/1/'},
#      'version_group': {'name': 'firered-leafgreen',
#       'url': 'https://pokeapi.co/api/v2/version-group/7/'}},
#     {'level_learned_at': 1,
#      'move_learn_method': {'name': 'level-up',
#       'url': 'https://pokeapi.co/api/v2/move-learn-method/1/'},
#      'version_group': {'name': 'diamond-pearl',
#       'url': 'https://pokeapi.co/api/v2/version-group/8/'}},
#     {'level_learned_at': 1,
#      'move_learn_method': {'name': 'level-up',
#       'url': 'https://pokeapi.co/api/v2/move-learn-method/1/'},
#      'version_group': {'name': 'platinum',
#       'url': 'https://pokeapi.co/api/v2/version-group/9/'}},
#     {'level_learned_at': 1,
#      'move_learn_method': {'name': 'level-up',
#       'url': 'https://pokeapi.co/api/v2/move-learn-method/1/'},
#      'version_group': {'name': 'heartgold-soulsilver',
#       'url': 'https://pokeapi.co/api/v2/version-group/10/'}},
#     {'level_learned_at': 1,
#      'move_learn_method': {'name': 'level-up',
#       'url': 'https://pokeapi.co/api/v2/move-learn-method/1/'},
#      'version_group': {'name': 'black-white',
#       'url': 'https://pokeapi.co/api/v2/version-group/11/'}},
#     {'level_learned_at': 1,
#      'move_learn_method': {'name': 'level-up',
#       'url': 'https://pokeapi.co/api/v2/move-learn-method/1/'},
#      'version_group': {'name': 'colosseum',
#       'url': 'https://pokeapi.co/api/v2/version-group/12/'}},
#     {'level_learned_at': 1,
#      'move_learn_method': {'name': 'level-up',
#       'url': 'https://pokeapi.co/api/v2/move-learn-method/1/'},
#      'version_group': {'name': 'xd',
#       'url': 'https://pokeapi.co/api/v2/version-group/13/'}},
#     {'level_learned_at': 1,
#      'move_learn_method': {'name': 'level-up',
#       'url': 'https://pokeapi.co/api/v2/move-learn-method/1/'},
#      'version_group': {'name': 'black-2-white-2',
#       'url': 'https://pokeapi.co/api/v2/version-group/14/'}},
#     {'level_learned_at': 1,
#      'move_learn_method': {'name': 'level-up',
#       'url': 'https://pokeapi.co/api/v2/move-learn-method/1/'},
#      'version_group': {'name': 'x-y',
#       'url': 'https://pokeapi.co/api/v2/version-group/15/'}},
#     {'level_learned_at': 1,
#      'move_learn_method': {'name': 'level-up',
#       'url': 'https://pokeapi.co/api/v2/move-learn-method/1/'},
#      'version_group': {'name': 'omega-ruby-alpha-sapphire',
#       'url': 'https://pokeapi.co/api/v2/version-group/16/'}},
#     {'level_learned_at': 1,
#      'move_learn_method': {'name': 'level-up',
#       'url': 'https://pokeapi.co/api/v2/move-learn-method/1/'},
#      'version_group': {'name': 'sun-moon',
#       'url': 'https://pokeapi.co/api/v2/version-group/17/'}},
#     {'level_learned_at': 1,
#      'move_learn_method': {'name': 'level-up',
#       'url': 'https://pokeapi.co/api/v2/move-learn-method/1/'},
#      'version_group': {'name': 'ultra-sun-ultra-moon',
#       'url': 'https://pokeapi.co/api/v2/version-group/18/'}},
#     {'level_learned_at': 1,
#      'move_learn_method': {'name': 'level-up',
#       'url': 'https://pokeapi.co/api/v2/move-learn-method/1/'},
#      'version_group': {'name': 'lets-go-pikachu-lets-go-eevee',
#       'url': 'https://pokeapi.co/api/v2/version-group/19/'}},
#     {'level_learned_at': 1,
#      'move_learn_method': {'name': 'level-up',
#       'url': 'https://pokeapi.co/api/v2/move-learn-method/1/'},
#      'version_group': {'name': 'sword-shield',
#       'url': 'https://pokeapi.co/api/v2/version-group/20/'}}]},
#   {'move': {'name': 'thunderbolt',
#     'url': 'https://pokeapi.co/api/v2/move/85/'},
#    'version_group_details': [{'level_learned_at': 0,
#      'move_learn_method': {'name': 'machine',
#       'url': 'https://pokeapi.co/api/v2/move-learn-method/4/'},
#      'version_group': {'name': 'red-blue',
#       'url': 'https://pokeapi.co/api/v2/version-group/1/'}},
#     {'level_learned_at': 26,
#      'move_learn_method': {'name': 'level-up',
#       'url': 'https://pokeapi.co/api/v2/move-learn-method/1/'},
#      'version_group': {'name': 'yellow',
#       'url': 'https://pokeapi.co/api/v2/version-group/2/'}},
#     {'level_learned_at': 0,
#      'move_learn_method': {'name': 'machine',
#       'url': 'https://pokeapi.co/api/v2/move-learn-method/4/'},
#      'version_group': {'name': 'yellow',
#       'url': 'https://pokeapi.co/api/v2/version-group/2/'}},
#     {'level_learned_at': 26,
#      'move_learn_method': {'name': 'level-up',
#       'url': 'https://pokeapi.co/api/v2/move-learn-method/1/'},
#      'version_group': {'name': 'gold-silver',
#       'url': 'https://pokeapi.co/api/v2/version-group/3/'}},
#     {'level_learned_at': 26,
#      'move_learn_method': {'name': 'level-up',
#       'url': 'https://pokeapi.co/api/v2/move-learn-method/1/'},
#      'version_group': {'name': 'crystal',
#       'url': 'https://pokeapi.co/api/v2/version-group/4/'}},
#     {'level_learned_at': 0,
#      'move_learn_method': {'name': 'tutor',
#       'url': 'https://pokeapi.co/api/v2/move-learn-method/3/'},
#      'version_group': {'name': 'crystal',
#       'url': 'https://pokeapi.co/api/v2/version-group/4/'}},
#     {'level_learned_at': 26,
#      'move_learn_method': {'name': 'level-up',
#       'url': 'https://pokeapi.co/api/v2/move-learn-method/1/'},
#      'version_group': {'name': 'ruby-sapphire',
#       'url': 'https://pokeapi.co/api/v2/version-group/5/'}},
#     {'level_learned_at': 0,
#      'move_learn_method': {'name': 'machine',
#       'url': 'https://pokeapi.co/api/v2/move-learn-method/4/'},
#      'version_group': {'name': 'ruby-sapphire',
#       'url': 'https://pokeapi.co/api/v2/version-group/5/'}},
#     {'level_learned_at': 26,
#      'move_learn_method': {'name': 'level-up',
#       'url': 'https://pokeapi.co/api/v2/move-learn-method/1/'},
#      'version_group': {'name': 'emerald',
#       'url': 'https://pokeapi.co/api/v2/version-group/6/'}},
#     {'level_learned_at': 0,
#      'move_learn_method': {'name': 'machine',
#       'url': 'https://pokeapi.co/api/v2/move-learn-method/4/'},
#      'version_group': {'name': 'emerald',
#       'url': 'https://pokeapi.co/api/v2/version-group/6/'}},
#     {'level_learned_at': 26,
#      'move_learn_method': {'name': 'level-up',
#       'url': 'https://pokeapi.co/api/v2/move-learn-method/1/'},
#      'version_group': {'name': 'firered-leafgreen',
#       'url': 'https://pokeapi.co/api/v2/version-group/7/'}},
#     {'level_learned_at': 0,
#      'move_learn_method': {'name': 'machine',
#       'url': 'https://pokeapi.co/api/v2/move-learn-method/4/'},
#      'version_group': {'name': 'firered-leafgreen',
#       'url': 'https://pokeapi.co/api/v2/version-group/7/'}},
#     {'level_learned_at': 26,
#      'move_learn_method': {'name': 'level-up',
#       'url': 'https://pokeapi.co/api/v2/move-learn-method/1/'},
#      'version_group': {'name': 'diamond-pearl',
#       'url': 'https://pokeapi.co/api/v2/version-group/8/'}},
#     {'level_learned_at': 0,
#      'move_learn_method': {'name': 'machine',
#       'url': 'https://pokeapi.co/api/v2/move-learn-method/4/'},
#      'version_group': {'name': 'diamond-pearl',
#       'url': 'https://pokeapi.co/api/v2/version-group/8/'}},
# ...
#     'front_female': 'https://raw.githubusercontent.com/PokeAPI/sprites/master/sprites/pokemon/other/home/female/25.png',
#     'front_shiny': 'https://raw.githubusercontent.com/PokeAPI/sprites/master/sprites/pokemon/other/home/shiny/25.png',
#     'front_shiny_female': 'https://raw.githubusercontent.com/PokeAPI/sprites/master/sprites/pokemon/other/home/shiny/female/25.png'},
#    'official-artwork': {'front_default': 'https://raw.githubusercontent.com/PokeAPI/sprites/master/sprites/pokemon/other/official-artwork/25.png'}},
#   'versions': {'generation-i': {'red-blue': {'back_default': 'https://raw.githubusercontent.com/PokeAPI/sprites/master/sprites/pokemon/versions/generation-i/red-blue/back/25.png',
#      'back_gray': 'https://raw.githubusercontent.com/PokeAPI/sprites/master/sprites/pokemon/versions/generation-i/red-blue/back/gray/25.png',
#      'back_transparent': 'https://raw.githubusercontent.com/PokeAPI/sprites/master/sprites/pokemon/versions/generation-i/red-blue/transparent/back/25.png',
#      'front_default': 'https://raw.githubusercontent.com/PokeAPI/sprites/master/sprites/pokemon/versions/generation-i/red-blue/25.png',
#      'front_gray': 'https://raw.githubusercontent.com/PokeAPI/sprites/master/sprites/pokemon/versions/generation-i/red-blue/gray/25.png',
#      'front_transparent': 'https://raw.githubusercontent.com/PokeAPI/sprites/master/sprites/pokemon/versions/generation-i/red-blue/transparent/25.png'},
#     'yellow': {'back_default': 'https://raw.githubusercontent.com/PokeAPI/sprites/master/sprites/pokemon/versions/generation-i/yellow/back/25.png',
#      'back_gray': 'https://raw.githubusercontent.com/PokeAPI/sprites/master/sprites/pokemon/versions/generation-i/yellow/back/gray/25.png',
#      'back_transparent': 'https://raw.githubusercontent.com/PokeAPI/sprites/master/sprites/pokemon/versions/generation-i/yellow/transparent/back/25.png',
#      'front_default': 'https://raw.githubusercontent.com/PokeAPI/sprites/master/sprites/pokemon/versions/generation-i/yellow/25.png',
#      'front_gray': 'https://raw.githubusercontent.com/PokeAPI/sprites/master/sprites/pokemon/versions/generation-i/yellow/gray/25.png',
#      'front_transparent': 'https://raw.githubusercontent.com/PokeAPI/sprites/master/sprites/pokemon/versions/generation-i/yellow/transparent/25.png'}},
#    'generation-ii': {'crystal': {'back_default': 'https://raw.githubusercontent.com/PokeAPI/sprites/master/sprites/pokemon/versions/generation-ii/crystal/back/25.png',
#      'back_shiny': 'https://raw.githubusercontent.com/PokeAPI/sprites/master/sprites/pokemon/versions/generation-ii/crystal/back/shiny/25.png',
#      'back_shiny_transparent': 'https://raw.githubusercontent.com/PokeAPI/sprites/master/sprites/pokemon/versions/generation-ii/crystal/transparent/back/shiny/25.png',
#      'back_transparent': 'https://raw.githubusercontent.com/PokeAPI/sprites/master/sprites/pokemon/versions/generation-ii/crystal/transparent/back/25.png',
#      'front_default': 'https://raw.githubusercontent.com/PokeAPI/sprites/master/sprites/pokemon/versions/generation-ii/crystal/25.png',
#      'front_shiny': 'https://raw.githubusercontent.com/PokeAPI/sprites/master/sprites/pokemon/versions/generation-ii/crystal/shiny/25.png',
#      'front_shiny_transparent': 'https://raw.githubusercontent.com/PokeAPI/sprites/master/sprites/pokemon/versions/generation-ii/crystal/transparent/shiny/25.png',
#      'front_transparent': 'https://raw.githubusercontent.com/PokeAPI/sprites/master/sprites/pokemon/versions/generation-ii/crystal/transparent/25.png'},
#     'gold': {'back_default': 'https://raw.githubusercontent.com/PokeAPI/sprites/master/sprites/pokemon/versions/generation-ii/gold/back/25.png',
#      'back_shiny': 'https://raw.githubusercontent.com/PokeAPI/sprites/master/sprites/pokemon/versions/generation-ii/gold/back/shiny/25.png',
#      'front_default': 'https://raw.githubusercontent.com/PokeAPI/sprites/master/sprites/pokemon/versions/generation-ii/gold/25.png',
#      'front_shiny': 'https://raw.githubusercontent.com/PokeAPI/sprites/master/sprites/pokemon/versions/generation-ii/gold/shiny/25.png',
#      'front_transparent': 'https://raw.githubusercontent.com/PokeAPI/sprites/master/sprites/pokemon/versions/generation-ii/gold/transparent/25.png'},
#     'silver': {'back_default': 'https://raw.githubusercontent.com/PokeAPI/sprites/master/sprites/pokemon/versions/generation-ii/silver/back/25.png',
#      'back_shiny': 'https://raw.githubusercontent.com/PokeAPI/sprites/master/sprites/pokemon/versions/generation-ii/silver/back/shiny/25.png',
#      'front_default': 'https://raw.githubusercontent.com/PokeAPI/sprites/master/sprites/pokemon/versions/generation-ii/silver/25.png',
#      'front_shiny': 'https://raw.githubusercontent.com/PokeAPI/sprites/master/sprites/pokemon/versions/generation-ii/silver/shiny/25.png',
#      'front_transparent': 'https://raw.githubusercontent.com/PokeAPI/sprites/master/sprites/pokemon/versions/generation-ii/silver/transparent/25.png'}},
#    'generation-iii': {'emerald': {'front_default': 'https://raw.githubusercontent.com/PokeAPI/sprites/master/sprites/pokemon/versions/generation-iii/emerald/25.png',
#      'front_shiny': 'https://raw.githubusercontent.com/PokeAPI/sprites/master/sprites/pokemon/versions/generation-iii/emerald/shiny/25.png'},
#     'firered-leafgreen': {'back_default': 'https://raw.githubusercontent.com/PokeAPI/sprites/master/sprites/pokemon/versions/generation-iii/firered-leafgreen/back/25.png',
#      'back_shiny': 'https://raw.githubusercontent.com/PokeAPI/sprites/master/sprites/pokemon/versions/generation-iii/firered-leafgreen/back/shiny/25.png',
#      'front_default': 'https://raw.githubusercontent.com/PokeAPI/sprites/master/sprites/pokemon/versions/generation-iii/firered-leafgreen/25.png',
#      'front_shiny': 'https://raw.githubusercontent.com/PokeAPI/sprites/master/sprites/pokemon/versions/generation-iii/firered-leafgreen/shiny/25.png'},
#     'ruby-sapphire': {'back_default': 'https://raw.githubusercontent.com/PokeAPI/sprites/master/sprites/pokemon/versions/generation-iii/ruby-sapphire/back/25.png',
#      'back_shiny': 'https://raw.githubusercontent.com/PokeAPI/sprites/master/sprites/pokemon/versions/generation-iii/ruby-sapphire/back/shiny/25.png',
#      'front_default': 'https://raw.githubusercontent.com/PokeAPI/sprites/master/sprites/pokemon/versions/generation-iii/ruby-sapphire/25.png',
#      'front_shiny': 'https://raw.githubusercontent.com/PokeAPI/sprites/master/sprites/pokemon/versions/generation-iii/ruby-sapphire/shiny/25.png'}},
#    'generation-iv': {'diamond-pearl': {'back_default': 'https://raw.githubusercontent.com/PokeAPI/sprites/master/sprites/pokemon/versions/generation-iv/diamond-pearl/back/25.png',
#      'back_female': 'https://raw.githubusercontent.com/PokeAPI/sprites/master/sprites/pokemon/versions/generation-iv/diamond-pearl/back/female/25.png',
#      'back_shiny': 'https://raw.githubusercontent.com/PokeAPI/sprites/master/sprites/pokemon/versions/generation-iv/diamond-pearl/back/shiny/25.png',
#      'back_shiny_female': 'https://raw.githubusercontent.com/PokeAPI/sprites/master/sprites/pokemon/versions/generation-iv/diamond-pearl/back/shiny/female/25.png',
#      'front_default': 'https://raw.githubusercontent.com/PokeAPI/sprites/master/sprites/pokemon/versions/generation-iv/diamond-pearl/25.png',
#      'front_female': 'https://raw.githubusercontent.com/PokeAPI/sprites/master/sprites/pokemon/versions/generation-iv/diamond-pearl/female/25.png',
#      'front_shiny': 'https://raw.githubusercontent.com/PokeAPI/sprites/master/sprites/pokemon/versions/generation-iv/diamond-pearl/shiny/25.png',
#      'front_shiny_female': 'https://raw.githubusercontent.com/PokeAPI/sprites/master/sprites/pokemon/versions/generation-iv/diamond-pearl/shiny/female/25.png'},
#     'heartgold-soulsilver': {'back_default': 'https://raw.githubusercontent.com/PokeAPI/sprites/master/sprites/pokemon/versions/generation-iv/heartgold-soulsilver/back/25.png',
#      'back_female': 'https://raw.githubusercontent.com/PokeAPI/sprites/master/sprites/pokemon/versions/generation-iv/heartgold-soulsilver/back/female/25.png',
#      'back_shiny': 'https://raw.githubusercontent.com/PokeAPI/sprites/master/sprites/pokemon/versions/generation-iv/heartgold-soulsilver/back/shiny/25.png',
#      'back_shiny_female': 'https://raw.githubusercontent.com/PokeAPI/sprites/master/sprites/pokemon/versions/generation-iv/heartgold-soulsilver/back/shiny/female/25.png',
#      'front_default': 'https://raw.githubusercontent.com/PokeAPI/sprites/master/sprites/pokemon/versions/generation-iv/heartgold-soulsilver/25.png',
#      'front_female': 'https://raw.githubusercontent.com/PokeAPI/sprites/master/sprites/pokemon/versions/generation-iv/heartgold-soulsilver/female/25.png',
#      'front_shiny': 'https://raw.githubusercontent.com/PokeAPI/sprites/master/sprites/pokemon/versions/generation-iv/heartgold-soulsilver/shiny/25.png',
#      'front_shiny_female': 'https://raw.githubusercontent.com/PokeAPI/sprites/master/sprites/pokemon/versions/generation-iv/heartgold-soulsilver/shiny/female/25.png'},
#     'platinum': {'back_default': 'https://raw.githubusercontent.com/PokeAPI/sprites/master/sprites/pokemon/versions/generation-iv/platinum/back/25.png',
#      'back_female': 'https://raw.githubusercontent.com/PokeAPI/sprites/master/sprites/pokemon/versions/generation-iv/platinum/back/female/25.png',
#      'back_shiny': 'https://raw.githubusercontent.com/PokeAPI/sprites/master/sprites/pokemon/versions/generation-iv/platinum/back/shiny/25.png',
#      'back_shiny_female': 'https://raw.githubusercontent.com/PokeAPI/sprites/master/sprites/pokemon/versions/generation-iv/platinum/back/shiny/female/25.png',
#      'front_default': 'https://raw.githubusercontent.com/PokeAPI/sprites/master/sprites/pokemon/versions/generation-iv/platinum/25.png',
#      'front_female': 'https://raw.githubusercontent.com/PokeAPI/sprites/master/sprites/pokemon/versions/generation-iv/platinum/female/25.png',
#      'front_shiny': 'https://raw.githubusercontent.com/PokeAPI/sprites/master/sprites/pokemon/versions/generation-iv/platinum/shiny/25.png',
#      'front_shiny_female': 'https://raw.githubusercontent.com/PokeAPI/sprites/master/sprites/pokemon/versions/generation-iv/platinum/shiny/female/25.png'}},
#    'generation-v': {'black-white': {'animated': {'back_default': 'https://raw.githubusercontent.com/PokeAPI/sprites/master/sprites/pokemon/versions/generation-v/black-white/animated/back/25.gif',
#       'back_female': 'https://raw.githubusercontent.com/PokeAPI/sprites/master/sprites/pokemon/versions/generation-v/black-white/animated/back/female/25.gif',
#       'back_shiny': 'https://raw.githubusercontent.com/PokeAPI/sprites/master/sprites/pokemon/versions/generation-v/black-white/animated/back/shiny/25.gif',
#       'back_shiny_female': 'https://raw.githubusercontent.com/PokeAPI/sprites/master/sprites/pokemon/versions/generation-v/black-white/animated/back/shiny/female/25.gif',
#       'front_default': 'https://raw.githubusercontent.com/PokeAPI/sprites/master/sprites/pokemon/versions/generation-v/black-white/animated/25.gif',
#       'front_female': 'https://raw.githubusercontent.com/PokeAPI/sprites/master/sprites/pokemon/versions/generation-v/black-white/animated/female/25.gif',
#       'front_shiny': 'https://raw.githubusercontent.com/PokeAPI/sprites/master/sprites/pokemon/versions/generation-v/black-white/animated/shiny/25.gif',
#       'front_shiny_female': 'https://raw.githubusercontent.com/PokeAPI/sprites/master/sprites/pokemon/versions/generation-v/black-white/animated/shiny/female/25.gif'},
#      'back_default': 'https://raw.githubusercontent.com/PokeAPI/sprites/master/sprites/pokemon/versions/generation-v/black-white/back/25.png',
#      'back_female': 'https://raw.githubusercontent.com/PokeAPI/sprites/master/sprites/pokemon/versions/generation-v/black-white/back/female/25.png',
#      'back_shiny': 'https://raw.githubusercontent.com/PokeAPI/sprites/master/sprites/pokemon/versions/generation-v/black-white/back/shiny/25.png',
#      'back_shiny_female': 'https://raw.githubusercontent.com/PokeAPI/sprites/master/sprites/pokemon/versions/generation-v/black-white/back/shiny/female/25.png',
#      'front_default': 'https://raw.githubusercontent.com/PokeAPI/sprites/master/sprites/pokemon/versions/generation-v/black-white/25.png',
#      'front_female': 'https://raw.githubusercontent.com/PokeAPI/sprites/master/sprites/pokemon/versions/generation-v/black-white/female/25.png',
#      'front_shiny': 'https://raw.githubusercontent.com/PokeAPI/sprites/master/sprites/pokemon/versions/generation-v/black-white/shiny/25.png',
#      'front_shiny_female': 'https://raw.githubusercontent.com/PokeAPI/sprites/master/sprites/pokemon/versions/generation-v/black-white/shiny/female/25.png'}},
#    'generation-vi': {'omegaruby-alphasapphire': {'front_default': 'https://raw.githubusercontent.com/PokeAPI/sprites/master/sprites/pokemon/versions/generation-vi/omegaruby-alphasapphire/25.png',
#      'front_female': 'https://raw.githubusercontent.com/PokeAPI/sprites/master/sprites/pokemon/versions/generation-vi/omegaruby-alphasapphire/female/25.png',
#      'front_shiny': 'https://raw.githubusercontent.com/PokeAPI/sprites/master/sprites/pokemon/versions/generation-vi/omegaruby-alphasapphire/shiny/25.png',
#      'front_shiny_female': 'https://raw.githubusercontent.com/PokeAPI/sprites/master/sprites/pokemon/versions/generation-vi/omegaruby-alphasapphire/shiny/female/25.png'},
#     'x-y': {'front_default': 'https://raw.githubusercontent.com/PokeAPI/sprites/master/sprites/pokemon/versions/generation-vi/x-y/25.png',
#      'front_female': 'https://raw.githubusercontent.com/PokeAPI/sprites/master/sprites/pokemon/versions/generation-vi/x-y/female/25.png',
#      'front_shiny': 'https://raw.githubusercontent.com/PokeAPI/sprites/master/sprites/pokemon/versions/generation-vi/x-y/shiny/25.png',
#      'front_shiny_female': 'https://raw.githubusercontent.com/PokeAPI/sprites/master/sprites/pokemon/versions/generation-vi/x-y/shiny/female/25.png'}},
#    'generation-vii': {'icons': {'front_default': 'https://raw.githubusercontent.com/PokeAPI/sprites/master/sprites/pokemon/versions/generation-vii/icons/25.png',
#      'front_female': None},
#     'ultra-sun-ultra-moon': {'front_default': 'https://raw.githubusercontent.com/PokeAPI/sprites/master/sprites/pokemon/versions/generation-vii/ultra-sun-ultra-moon/25.png',
#      'front_female': 'https://raw.githubusercontent.com/PokeAPI/sprites/master/sprites/pokemon/versions/generation-vii/ultra-sun-ultra-moon/female/25.png',
#      'front_shiny': 'https://raw.githubusercontent.com/PokeAPI/sprites/master/sprites/pokemon/versions/generation-vii/ultra-sun-ultra-moon/shiny/25.png',
#      'front_shiny_female': 'https://raw.githubusercontent.com/PokeAPI/sprites/master/sprites/pokemon/versions/generation-vii/ultra-sun-ultra-moon/shiny/female/25.png'}},
#    'generation-viii': {'icons': {'front_default': 'https://raw.githubusercontent.com/PokeAPI/sprites/master/sprites/pokemon/versions/generation-viii/icons/25.png',
#      'front_female': 'https://raw.githubusercontent.com/PokeAPI/sprites/master/sprites/pokemon/versions/generation-viii/icons/female/25.png'}}}},
#  'stats': [{'base_stat': 35,
#    'effort': 0,
#    'stat': {'name': 'hp', 'url': 'https://pokeapi.co/api/v2/stat/1/'}},
#   {'base_stat': 55,
#    'effort': 0,
#    'stat': {'name': 'attack', 'url': 'https://pokeapi.co/api/v2/stat/2/'}},
#   {'base_stat': 40,
#    'effort': 0,
#    'stat': {'name': 'defense', 'url': 'https://pokeapi.co/api/v2/stat/3/'}},
#   {'base_stat': 50,
#    'effort': 0,
#    'stat': {'name': 'special-attack',
#     'url': 'https://pokeapi.co/api/v2/stat/4/'}},
#   {'base_stat': 50,
#    'effort': 0,
#    'stat': {'name': 'special-defense',
#     'url': 'https://pokeapi.co/api/v2/stat/5/'}},
#   {'base_stat': 90,
#    'effort': 2,
#    'stat': {'name': 'speed', 'url': 'https://pokeapi.co/api/v2/stat/6/'}}],
#  'types': [{'slot': 1,
#    'type': {'name': 'electric', 'url': 'https://pokeapi.co/api/v2/type/13/'}}],
#  'weight': 60}

# %%
response.text
# Out:
# '{"abilities":[{"ability":{"name":"static","url":"https://pokeapi.co/api/v2/ability/9/"},"is_hidden":false,"slot":1},{"ability":{"name":"lightning-rod","url":"https://pokeapi.co/api/v2/ability/31/"},"is_hidden":true,"slot":3}],"base_experience":112,"forms":[{"name":"pikachu","url":"https://pokeapi.co/api/v2/pokemon-form/25/"}],"game_indices":[{"game_index":84,"version":{"name":"red","url":"https://pokeapi.co/api/v2/version/1/"}},{"game_index":84,"version":{"name":"blue","url":"https://pokeapi.co/api/v2/version/2/"}},{"game_index":84,"version":{"name":"yellow","url":"https://pokeapi.co/api/v2/version/3/"}},{"game_index":25,"version":{"name":"gold","url":"https://pokeapi.co/api/v2/version/4/"}},{"game_index":25,"version":{"name":"silver","url":"https://pokeapi.co/api/v2/version/5/"}},{"game_index":25,"version":{"name":"crystal","url":"https://pokeapi.co/api/v2/version/6/"}},{"game_index":25,"version":{"name":"ruby","url":"https://pokeapi.co/api/v2/version/7/"}},{"game_index":25,"version":{"name":"sapphire","url":"https://pokeapi.co/api/v2/version/8/"}},{"game_index":25,"version":{"name":"emerald","url":"https://pokeapi.co/api/v2/version/9/"}},{"game_index":25,"version":{"name":"firered","url":"https://pokeapi.co/api/v2/version/10/"}},{"game_index":25,"version":{"name":"leafgreen","url":"https://pokeapi.co/api/v2/version/11/"}},{"game_index":25,"version":{"name":"diamond","url":"https://pokeapi.co/api/v2/version/12/"}},{"game_index":25,"version":{"name":"pearl","url":"https://pokeapi.co/api/v2/version/13/"}},{"game_index":25,"version":{"name":"platinum","url":"https://pokeapi.co/api/v2/version/14/"}},{"game_index":25,"version":{"name":"heartgold","url":"https://pokeapi.co/api/v2/version/15/"}},{"game_index":25,"version":{"name":"soulsilver","url":"https://pokeapi.co/api/v2/version/16/"}},{"game_index":25,"version":{"name":"black","url":"https://pokeapi.co/api/v2/version/17/"}},{"game_index":25,"version":{"name":"white","url":"https://pokeapi.co/api/v2/version/18/"}},{"game_index":25,"version":{"name":"black-2","url":"https://pokeapi.co/api/v2/version/21/"}},{"game_index":25,"version":{"name":"white-2","url":"https://pokeapi.co/api/v2/version/22/"}}],"height":4,"held_items":[{"item":{"name":"oran-berry","url":"https://pokeapi.co/api/v2/item/132/"},"version_details":[{"rarity":50,"version":{"name":"ruby","url":"https://pokeapi.co/api/v2/version/7/"}},{"rarity":50,"version":{"name":"sapphire","url":"https://pokeapi.co/api/v2/version/8/"}},{"rarity":50,"version":{"name":"emerald","url":"https://pokeapi.co/api/v2/version/9/"}},{"rarity":50,"version":{"name":"diamond","url":"https://pokeapi.co/api/v2/version/12/"}},{"rarity":50,"version":{"name":"pearl","url":"https://pokeapi.co/api/v2/version/13/"}},{"rarity":50,"version":{"name":"platinum","url":"https://pokeapi.co/api/v2/version/14/"}},{"rarity":50,"version":{"name":"heartgold","url":"https://pokeapi.co/api/v2/version/15/"}},{"rarity":50,"version":{"name":"soulsilver","url":"https://pokeapi.co/api/v2/version/16/"}},{"rarity":50,"version":{"name":"black","url":"https://pokeapi.co/api/v2/version/17/"}},{"rarity":50,"version":{"name":"white","url":"https://pokeapi.co/api/v2/version/18/"}}]},{"item":{"name":"light-ball","url":"https://pokeapi.co/api/v2/item/213/"},"version_details":[{"rarity":5,"version":{"name":"ruby","url":"https://pokeapi.co/api/v2/version/7/"}},{"rarity":5,"version":{"name":"sapphire","url":"https://pokeapi.co/api/v2/version/8/"}},{"rarity":5,"version":{"name":"emerald","url":"https://pokeapi.co/api/v2/version/9/"}},{"rarity":5,"version":{"name":"diamond","url":"https://pokeapi.co/api/v2/version/12/"}},{"rarity":5,"version":{"name":"pearl","url":"https://pokeapi.co/api/v2/version/13/"}},{"rarity":5,"version":{"name":"platinum","url":"https://pokeapi.co/api/v2/version/14/"}},{"rarity":5,"version":{"name":"heartgold","url":"https://pokeapi.co/api/v2/version/15/"}},{"rarity":5,"version":{"name":"soulsilver","url":"https://pokeapi.co/api/v2/version/16/"}},{"rarity":1,"v ...

# %% [markdown]
# Observe that the content is very similar in both cases, but the data type is what changes.
#
# Usually you will get a JSON object as a response. These JSON objects are usually huge, so make sure you know how to navigate through the JSON object. For example, how can you get all the keys of this JSON object?

# %% [markdown]
# ## We can do more than just `GET` information
#
# API stands for "Application Programmable Interface", so, as the name suggests, it should not only allow us to get information, but also to modify it
#
# ## Resources and methods
#
# In the example above, we used the `requests.get` function to make a "__`GET` request__" request to the `/api/v2/pokemon/pikachu` "__resource__" of the API.
#
# APIs can be programmed to respond to other types of requests too, which should roughly be used as follows:
#
# - `GET` - get some data
# - `POST` - insert some new data
# - `PUT` - update some data
# - `DELETE` - delete some data
#
# These are some examples of the most common HTTP __methods__. Read about them in detail [here](https://developer.mozilla.org/en-US/docs/Web/HTTP/Methods).
#
# Read further and compare GET and POST methods [here](https://www.w3schools.com/tags/ref_httpmethods.asp). One particular thing of interest is that GET request responses can be cached, whereas POST responses cannot.
#
# Below we show how to make different types of requests to the API using Python.

# %%
requests.get('https://pokeapi.co/api/v2/pokemon/pikachu')
requests.post('https://pokeapi.co/api/v2/pokemon/pikachu')
requests.put('https://pokeapi.co/api/v2/pokemon/pikachu')
requests.delete('https://pokeapi.co/api/v2/pokemon/pikachu')
requests.patch('https://pokeapi.co/api/v2/pokemon/pikachu')
# Out:
# <Response [404]>

# %% [markdown]
# Check this [webpage](https://rapidapi.com/blog/put-vs-patch/) to check the difference betwwen PUT and PATCH

# %% [markdown]
# To get information about a different pokemon, we could make a `GET` request to a different resource, such as `/api/v2/pokemon/squirtle`. We need a different resource because an API can only implement 1 method of each type on any given resource.
#
# We commonly use talk about these HTTP methods by saying something like "Make a `DELETE` request to the `/profiles` resource".

# %% [markdown]
# Side note: What is a browser?
#
# > A browser is a program that displays information in a way that is easy for a human to understand.
#
# It doesn't just show you the raw binary data. When you search for a webpage, it will render the HTML. When you open an image in a new tab, it will display the image. When you search for an API endpoint with a `GET` method implemented that returns JSON, it will print the response JSON.
#
# > Did you know that, when you search something in your browser, it makes a `GET` request to that URL?
#
# ![browserGET](images/browserGET.png)

# %% [markdown]
# ## Types of API
#
# There are several different types of API. Here's what you need to know for now:
# - __REST APIs__ are by far the most common type of API. REST is an acronym for REpresentational State Transfer. They expect HTTP requests. Read more [here](https://en.wikipedia.org/wiki/Representational_state_transfer)
# - __HTTP APIs__ are a legacy version of REST APIs.
# - __Websocket APIs__ enable not only the client to be able to initiate requests to the server, but for the server to initiate requests to the client. This is 2-way communication is commonly used in instant messaging applications, where a server sits between two (or more) users listening for messages from one users and then sends the intended recipients the message by initiating a request to them.
#
# Despite how much we have talked about HTTP, but we are actually going to exclusively working with REST APIs. Still, many concepts also apply to other types of API.
#
# ## Response Codes
#
# If we print our API response, we will see that is comes with a number.
#
# We can access the status code using the `.status_code` attribute of the response.
#
# That is the "__status code__".

# %%
import requests

response = requests.get('https://pokeapi.co/api/v2/pokemon/pikachu')
print(response)
print(response.status_code)
# Out:
# <Response [200]>
# 200

# %% [markdown]
# You've probably seen a 404 response on a browser before. That's a status code. Do you recognise any others in the table below?
#
# ![response codes](images/http-codes.png)
#
# ## Headers
#
# Headers are pieces of information sent along with a request
#
# Headers can be sent from the client to the server as part of a request, or from the server to the client as part of a response.
#
# ### What are some common headers?
# - Authentication tokens
# - Media types
# - CORS headers (see below)
#
# Read more about headers [here](https://developer.mozilla.org/en-US/docs/Web/HTTP/Headers)

# %% [markdown]
# ### Authentication tokens

# %% [markdown]
# The APIs we have seen so far are free. However, some other APIs require a token to access them, if we don't provide one, we will get a 403 error. Basically, we need to identify ourselves to the API, otherwise the server will deny us access.
#
# > <font size=+1> An Authorization token is a credential in the form of a string that represents the authorization granted to the app.</font>
#
# Many APIs will ask you to write the token in the header of the request. But other APIs will ask you to write the token in the parameters of the request.

# %% [markdown]
# ### Token in the parameters

# %% [markdown]
# For example, let's take a look at the [Yandex translator API](hhttps://yandex.com/dev/translate/), where you can translate text from one language to another.
#
# <p align=center><img src=images/yandex.png width=800></p>

# %% [markdown]
# So, it's as simple as adding the token to the url of the request as one of the parameters.

# %% [markdown]
# Let's take a look at an example with a request through the browser.

# %% [markdown]
# <p align=center><img src=images/yandex_200.png width=1000></p>

# %% [markdown]
# Notice that the token is in the parameters of the request. If we don't add it, we get an error:

# %% [markdown]
# <p align=center><img src=images/yandex_502.png width=1000></p>

# %% [markdown]
# In this case, the API is asking us to add the token to the parameters of the request.

# %% [markdown]
# ### Token in the header

# %% [markdown]
# Another way you have to identify yourself to the API is to add the token to the header of the request. As mentioned, in the header of the request we add information about the client, so instead of adding the token to the parameters of the request, we add it to this information.
#
# To see an example, let's take a look at the github API. Some requests to this API don't require authentication, for example, the following request returns the list of repositories of the user:

# %%
# !curl https://api.github.com/users/IvanYingX/repos
# Out:
# [
#   {
#     "id": 424088439,
#     "node_id": "R_kgDOGUcTdw",
#     "name": "Actions",
#     "full_name": "IvanYingX/Actions",
#     "private": false,
#     "owner": {
#       "login": "IvanYingX",
#       "id": 58112372,
#       "node_id": "MDQ6VXNlcjU4MTEyMzcy",
#       "avatar_url": "https://avatars.githubusercontent.com/u/58112372?v=4",
#       "gravatar_id": "",
#       "url": "https://api.github.com/users/IvanYingX",
#       "html_url": "https://github.com/IvanYingX",
#       "followers_url": "https://api.github.com/users/IvanYingX/followers",
#       "following_url": "https://api.github.com/users/IvanYingX/following{/other_user}",
#       "gists_url": "https://api.github.com/users/IvanYingX/gists{/gist_id}",
#       "starred_url": "https://api.github.com/users/IvanYingX/starred{/owner}{/repo}",
#       "subscriptions_url": "https://api.github.com/users/IvanYingX/subscriptions",
#       "organizations_url": "https://api.github.com/users/IvanYingX/orgs",
#       "repos_url": "https://api.github.com/users/IvanYingX/repos",
#       "events_url": "https://api.github.com/users/IvanYingX/events{/privacy}",
#       "received_events_url": "https://api.github.com/users/IvanYingX/received_events",
#       "type": "User",
#       "site_admin": false
#     },
#     "html_url": "https://github.com/IvanYingX/Actions",
#     "description": null,
#     "fork": false,
#     "url": "https://api.github.com/repos/IvanYingX/Actions",
#     "forks_url": "https://api.github.com/repos/IvanYingX/Actions/forks",
#     "keys_url": "https://api.github.com/repos/IvanYingX/Actions/keys{/key_id}",
#     "collaborators_url": "https://api.github.com/repos/IvanYingX/Actions/collaborators{/collaborator}",
#     "teams_url": "https://api.github.com/repos/IvanYingX/Actions/teams",
#     "hooks_url": "https://api.github.com/repos/IvanYingX/Actions/hooks",
#     "issue_events_url": "https://api.github.com/repos/IvanYingX/Actions/issues/events{/number}",
#     "events_url": "https://api.github.com/repos/IvanYingX/Actions/events",
#     "assignees_url": "https://api.github.com/repos/IvanYingX/Actions/assignees{/user}",
#     "branches_url": "https://api.github.com/repos/IvanYingX/Actions/branches{/branch}",
#     "tags_url": "https://api.github.com/repos/IvanYingX/Actions/tags",
#     "blobs_url": "https://api.github.com/repos/IvanYingX/Actions/git/blobs{/sha}",
#     "git_tags_url": "https://api.github.com/repos/IvanYingX/Actions/git/tags{/sha}",
#     "git_refs_url": "https://api.github.com/repos/IvanYingX/Actions/git/refs{/sha}",
#     "trees_url": "https://api.github.com/repos/IvanYingX/Actions/git/trees{/sha}",
#     "statuses_url": "https://api.github.com/repos/IvanYingX/Actions/statuses/{sha}",
#     "languages_url": "https://api.github.com/repos/IvanYingX/Actions/languages",
#     "stargazers_url": "https://api.github.com/repos/IvanYingX/Actions/stargazers",
#     "contributors_url": "https://api.github.com/repos/IvanYingX/Actions/contributors",
#     "subscribers_url": "https://api.github.com/repos/IvanYingX/Actions/subscribers",
#     "subscription_url": "https://api.github.com/repos/IvanYingX/Actions/subscription",
#     "commits_url": "https://api.github.com/repos/IvanYingX/Actions/commits{/sha}",
#     "git_commits_url": "https://api.github.com/repos/IvanYingX/Actions/git/commits{/sha}",
#     "comments_url": "https://api.github.com/repos/IvanYingX/Actions/comments{/number}",
#     "issue_comment_url": "https://api.github.com/repos/IvanYingX/Actions/issues/comments{/number}",
#     "contents_url": "https://api.github.com/repos/IvanYingX/Actions/contents/{+path}",
#     "compare_url": "https://api.github.com/repos/IvanYingX/Actions/compare/{base}...{head}",
#     "merges_url": "https://api.github.com/repos/IvanYingX/Actions/merges",
#     "archive_url": "https://api.github.com/repos/IvanYingX/Actions/{archive_format}{/ref}",
#     "downloads_url": "https://api.github.com/repos/IvanYingX/Actions/downloads",
#     "issues_url": "https://api.github.com/repos/IvanYingX/Actions/issues{/number}",
#     "pulls_url": "https://api.github.com/repos/IvanYingX/Actions/pulls{/number}",
#     "milestones_url": "https://api.github.com/repos/IvanYingX/Actions/milestones{/number}",
#     "notifications_url": "https://api.github.com/repos/IvanYingX/Actions/notifications{?since,all,participating}",
#     "labels_url": "https://api.github.com/repos/IvanYingX/Actions/labels{/name}",
#     "releases_url": "https://api.github.com/repos/IvanYingX/Actions/releases{/id}",
#     "deployments_url": "https://api.github.com/repos/IvanYingX/Actions/deployments",
#     "created_at": "2021-11-03T04:12:14Z",
#     "updated_at": "2021-12-06T20:11:34Z",
#     "pushed_at": "2021-12-06T20:11:31Z",
#     "git_url": "git://github.com/IvanYingX/Actions.git",
#     "ssh_url": "git@github.com:IvanYingX/Actions.git",
#     "clone_url": "https://github.com/IvanYingX/Actions.git",
#     "svn_url": "https://github.com/IvanYingX/Actions",
#     "homepage": null,
#     "size": 25,
#     "stargazers_count": 0,
#     "watchers_count": 0,
#     "language": "Python",
#     "has_issues": true,
#     "has_projects": true,
#     "has_downloads": true,
#     "has_wiki": true,
#     "has_pages": false,
#     "forks_count": 0,
#     "mirror_url": null,
#     "archived": false,
#     "disabled": false,
#     "open_issues_count": 0,
#     "license": null,
#     "allow_forking": true,
#     "is_template": false,
#     "topics": [
#
#     ],
#     "visibility": "public",
#     "forks": 0,
#     "open_issues": 0,
#     "watchers": 0,
#     "default_branch": "main"
#   },
#   {
#     "id": 414009302,
#     "node_id": "R_kgDOGK1H1g",
#     "name": "AiBetCore",
#     "full_name": "IvanYingX/AiBetCore",
#     "private": false,
#     "owner": {
#       "login": "IvanYingX",
#       "id": 58112372,
#       "node_id": "MDQ6VXNlcjU4MTEyMzcy",
#       "avatar_url": "https://avatars.githubusercontent.com/u/58112372?v=4",
#       "gravatar_id": "",
#       "url": "https://api.github.com/users/IvanYingX",
#       "html_url": "https://github.com/IvanYingX",
#       "followers_url": "https://api.github.com/users/IvanYingX/followers",
#       "following_url": "https://api.github.com/users/IvanYingX/following{/other_user}",
#       "gists_url": "https://api.github.com/users/IvanYingX/gists{/gist_id}",
#       "starred_url": "https://api.github.com/users/IvanYingX/starred{/owner}{/repo}",
#       "subscriptions_url": "https://api.github.com/users/IvanYingX/subscriptions",
#       "organizations_url": "https://api.github.com/users/IvanYingX/orgs",
#       "repos_url": "https://api.github.com/users/IvanYingX/repos",
#       "events_url": "https://api.github.com/users/IvanYingX/events{/privacy}",
#       "received_events_url": "https://api.github.com/users/IvanYingX/received_events",
#       "type": "User",
#       "site_admin": false
#     },
#     "html_url": "https://github.com/IvanYingX/AiBetCore",
#     "description": null,
#     "fork": false,
#     "url": "https://api.github.com/repos/IvanYingX/AiBetCore",
#     "forks_url": "https://api.github.com/repos/IvanYingX/AiBetCore/forks",
#     "keys_url": "https://api.github.com/repos/IvanYingX/AiBetCore/keys{/key_id}",
#     "collaborators_url": "https://api.github.com/repos/IvanYingX/AiBetCore/collaborators{/collaborator}",
#     "teams_url": "https://api.github.com/repos/IvanYingX/AiBetCore/teams",
#     "hooks_url": "https://api.github.com/repos/IvanYingX/AiBetCore/hooks",
#     "issue_events_url": "https://api.github.com/repos/IvanYingX/AiBetCore/issues/events{/number}",
#     "events_url": "https://api.github.com/repos/IvanYingX/AiBetCore/events",
#     "assignees_url": "https://api.github.com/repos/IvanYingX/AiBetCore/assignees{/user}",
#     "branches_url": "https://api.github.com/repos/IvanYingX/AiBetCore/branches{/branch}",
#     "tags_url": "https://api.github.com/repos/IvanYingX/AiBetCore/tags",
#     "blobs_url": "https://api.github.com/repos/IvanYingX/AiBetCore/git/blobs{/sha}",
#     "git_tags_url": "https://api.github.com/repos/IvanYingX/AiBetCore/git/tags{/sha}",
#     "git_refs_url": "https://api.github.com/repos/IvanYingX/AiBetCore/git/refs{/sha}",
#     "trees_url": "https://api.github.com/repos/IvanYingX/AiBetCore/git/trees{/sha}",
#     "statuses_url": "https://api.github.com/repos/IvanYingX/AiBetCore/statuses/{sha}",
#     "languages_url": "https://api.github.com/repos/IvanYingX/AiBetCore/languages",
#     "stargazers_url": "https://api.github.com/repos/IvanYingX/AiBetCore/stargazers",
#     "contributors_url": "https://api.github.com/repos/IvanYingX/AiBetCore/contributors",
#     "subscribers_url": "https://api.github.com/repos/IvanYingX/AiBetCore/subscribers",
#     "subscription_url": "https://api.github.com/repos/IvanYingX/AiBetCore/subscription",
#     "commits_url": "https://api.github.com/repos/IvanYingX/AiBetCore/commits{/sha}",
#     "git_commits_url": "https://api.github.com/repos/IvanYingX/AiBetCore/git/commits{/sha}",
#     "comments_url": "https://api.github.com/repos/IvanYingX/AiBetCore/comments{/number}",
#     "issue_comment_url": "https://api.github.com/repos/IvanYingX/AiBetCore/issues/comments{/number}",
#     "contents_url": "https://api.github.com/repos/IvanYingX/AiBetCore/contents/{+path}",
#     "compare_url": "https://api.github.com/repos/IvanYingX/AiBetCore/compare/{base}...{head}",
#     "merges_url": "https://api.github.com/repos/IvanYingX/AiBetCore/merges",
#     "archive_url": "https://api.github.com/repos/IvanYingX/AiBetCore/{archive_format}{/ref}",
#     "downloads_url": "https://api.github.com/repos/IvanYingX/AiBetCore/downloads",
#     "issues_url": "https://api.github.com/repos/IvanYingX/AiBetCore/issues{/number}",
#     "pulls_url": "https://api.github.com/repos/IvanYingX/AiBetCore/pulls{/number}",
#     "milestones_url": "https://api.github.com/repos/IvanYingX/AiBetCore/milestones{/number}",
#     "notifications_url": "https://api.github.com/repos/IvanYingX/AiBetCore/notifications{?since,all,participating}",
#     "labels_url": "https://api.github.com/repos/IvanYingX/AiBetCore/labels{/name}",
#     "releases_url": "https://api.github.com/repos/IvanYingX/AiBetCore/releases{/id}",
#     "deployments_url": "https://api.github.com/repos/IvanYingX/AiBetCore/deployments",
#     "created_at": "2021-10-05T23:33:00Z",
#     "updated_at": "2021-11-10T12:36:23Z",
#     "pushed_at": "2021-11-18T22:21:38Z",
#     "git_url": "git://github.com/IvanYingX/AiBetCore.git",
#     "ssh_url": "git@github.com:IvanYingX/AiBetCore.git",
#     "clone_url": "https://github.com/IvanYingX/AiBetCore.git",
#     "svn_url": "https://github.com/IvanYingX/AiBetCore",
#     "homepage": null,
#     "size": 40135,
#     "stargazers_count": 0,
#     "watchers_count": 0,
#     "language": "Python",
#     "has_issues": true,
#     "has_projects": true,
#     "has_downloads": true,
#     "has_wiki": true,
#     "has_pages": false,
#     "forks_count": 0,
#     "mirror_url": null,
#     "archived": false,
#     "disabled": false,
#     "open_issues_count": 15,
#     "license": {
#       "key": "mit",
#       "name": "MIT License",
#       "spdx_id": "MIT",
#       "url": "https://api.github.com/licenses/mit",
#       "node_id": "MDc6TGljZW5zZTEz"
#     },
#     "allow_forking": true,
#     "is_template": false,
#     "topics": [
#
#     ],
#     "visibility": "public",
#     "forks": 0,
#     "open_issues": 15,
#     "watchers": 0,
#     "default_branch": "main"
#   },
#   {
#     "id": 428766103,
#     "node_id": "R_kgDOGY5zlw",
#     "name": "AiCore-Project-Template",
#     "full_name": "IvanYingX/AiCore-Project-Template",
#     "private": false,
#     "owner": {
#       "login": "IvanYingX",
#       "id": 58112372,
#       "node_id": "MDQ6VXNlcjU4MTEyMzcy",
#       "avatar_url": "https://avatars.githubusercontent.com/u/58112372?v=4",
#       "gravatar_id": "",
#       "url": "https://api.github.com/users/IvanYingX",
#       "html_url": "https://github.com/IvanYingX",
#       "followers_url": "https://api.github.com/users/IvanYingX/followers",
#       "following_url": "https://api.github.com/users/IvanYingX/following{/other_user}",
#       "gists_url": "https://api.github.com/users/IvanYingX/gists{/gist_id}",
#       "starred_url": "https://api.github.com/users/IvanYingX/starred{/owner}{/repo}",
#       "subscriptions_url": "https://api.github.com/users/IvanYingX/subscriptions",
#       "organizations_url": "https://api.github.com/users/IvanYingX/orgs",
#       "repos_url": "https://api.github.com/users/IvanYingX/repos",
#       "events_url": "https://api.github.com/users/IvanYingX/events{/privacy}",
#       "received_events_url": "https://api.github.com/users/IvanYingX/received_events",
#       "type": "User",
#       "site_admin": false
#     },
#     "html_url": "https://github.com/IvanYingX/AiCore-Project-Template",
#     "description": null,
#     "fork": false,
#     "url": "https://api.github.com/repos/IvanYingX/AiCore-Project-Template",
#     "forks_url": "https://api.github.com/repos/IvanYingX/AiCore-Project-Template/forks",
#     "keys_url": "https://api.github.com/repos/IvanYingX/AiCore-Project-Template/keys{/key_id}",
#     "collaborators_url": "https://api.github.com/repos/IvanYingX/AiCore-Project-Template/collaborators{/collaborator}",
#     "teams_url": "https://api.github.com/repos/IvanYingX/AiCore-Project-Template/teams",
#     "hooks_url": "https://api.github.com/repos/IvanYingX/AiCore-Project-Template/hooks",
#     "issue_events_url": "https://api.github.com/repos/IvanYingX/AiCore-Project-Template/issues/events{/number}",
#     "events_url": "https://api.github.com/repos/IvanYingX/AiCore-Project-Template/events",
#     "assignees_url": "https://api.github.com/repos/IvanYingX/AiCore-Project-Template/assignees{/user}",
#     "branches_url": "https://api.github.com/repos/IvanYingX/AiCore-Project-Template/branches{/branch}",
#     "tags_url": "https://api.github.com/repos/IvanYingX/AiCore-Project-Template/tags",
#     "blobs_url": "https://api.github.com/repos/IvanYingX/AiCore-Project-Template/git/blobs{/sha}",
#     "git_tags_url": "https://api.github.com/repos/IvanYingX/AiCore-Project-Template/git/tags{/sha}",
#     "git_refs_url": "https://api.github.com/repos/IvanYingX/AiCore-Project-Template/git/refs{/sha}",
#     "trees_url": "https://api.github.com/repos/IvanYingX/AiCore-Project-Template/git/trees{/sha}",
#     "statuses_url": "https://api.github.com/repos/IvanYingX/AiCore-Project-Template/statuses/{sha}",
#     "languages_url": "https://api.github.com/repos/IvanYingX/AiCore-Project-Template/languages",
#     "stargazers_url": "https://api.github.com/repos/IvanYingX/AiCore-Project-Template/stargazers",
#     "contributors_url": "https://api.github.com/repos/IvanYingX/AiCore-Project-Template/contributors",
#     "subscribers_url": "https://api.github.com/repos/IvanYingX/AiCore-Project-Template/subscribers",
#     "subscription_url": "https://api.github.com/repos/IvanYingX/AiCore-Project-Template/subscription",
#     "commits_url": "https://api.github.com/repos/IvanYingX/AiCore-Project-Template/commits{/sha}",
#     "git_commits_url": "https://api.github.com/repos/IvanYingX/AiCore-Project-Template/git/commits{/sha}",
#     "comments_url": "https://api.github.com/repos/IvanYingX/AiCore-Project-Template/comments{/number}",
#     "issue_comment_url": "https://api.github.com/repos/IvanYingX/AiCore-Project-Template/issues/comments{/number}",
#     "contents_url": "https://api.github.com/repos/IvanYingX/AiCore-Project-Template/contents/{+path}",
#     "compare_url": "https://api.github.com/repos/IvanYingX/AiCore-Project-Template/compare/{base}...{head}",
#     "merges_url": "https://api.github.com/repos/IvanYingX/AiCore-Project-Template/merges",
#     "archive_url": "https://api.github.com/repos/IvanYingX/AiCore-Project-Template/{archive_format}{/ref}",
#     "downloads_url": "https://api.github.com/repos/IvanYingX/AiCore-Project-Template/downloads",
#     "issues_url": "https://api.github.com/repos/IvanYingX/AiCore-Project-Template/issues{/number}",
#     "pulls_url": "https://api.github.com/repos/IvanYingX/AiCore-Project-Template/pulls{/number}",
#     "milestones_url": "https://api.github.com/repos/IvanYingX/AiCore-Project-Template/milestones{/number}",
#     "notifications_url": "https://api.github.com/repos/IvanYingX/AiCore-Project-Template/notifications{?since,all,participating}",
#     "labels_url": "https://api.github.com/repos/IvanYingX/AiCore-Project-Template/labels{/name}",
#     "releases_url": "https://api.github.com/repos/IvanYingX/AiCore-Project-Template/releases{/id}",
#     "deployments_url": "https://api.github.com/repos/IvanYingX/AiCore-Project-Template/deployments",
#     "created_at": "2021-11-16T18:13:09Z",
#     "updated_at": "2021-11-17T05:12:45Z",
#     "pushed_at": "2021-11-16T18:28:16Z",
#     "git_url": "git://github.com/IvanYingX/AiCore-Project-Template.git",
#     "ssh_url": "git@github.com:IvanYingX/AiCore-Project-Template.git",
#     "clone_url": "https://github.com/IvanYingX/AiCore-Project-Template.git",
#     "svn_url": "https://github.com/IvanYingX/AiCore-Project-Template",
#     "homepage": null,
#     "size": 4,
#     "stargazers_count": 0,
#     "watchers_count": 0,
#     "language": null,
#     "has_issues": true,
#     "has_projects": true,
#     "has_downloads": true,
#     "has_wiki": true,
#     "has_pages": true,
#     "forks_count": 0,
#     "mirror_url": null,
#     "archived": false,
#     "disabled": false,
#     "open_issues_count": 0,
#     "license": null,
#     "allow_forking": true,
#     "is_template": true,
#     "topics": [
#
#     ],
#     "visibility": "public",
#     "forks": 0,
#     "open_issues": 0,
#     "watchers": 0,
#     "default_branch": "main"
#   },
#   {
#     "id": 436760650,
#     "node_id": "R_kgDOGghwSg",
#     "name": "aicore-teachable-machine",
#     "full_name": "IvanYingX/aicore-teachable-machine",
#     "private": false,
#     "owner": {
#       "login": "IvanYingX",
#       "id": 58112372,
#       "node_id": "MDQ6VXNlcjU4MTEyMzcy",
#       "avatar_url": "https://avatars.githubusercontent.com/u/58112372?v=4",
#       "gravatar_id": "",
#       "url": "https://api.github.com/users/IvanYingX",
#       "html_url": "https://github.com/IvanYingX",
#       "followers_url": "https://api.github.com/users/IvanYingX/followers",
#       "following_url": "https://api.github.com/users/IvanYingX/following{/other_user}",
#       "gists_url": "https://api.github.com/users/IvanYingX/gists{/gist_id}",
#       "starred_url": "https://api.github.com/users/IvanYingX/starred{/owner}{/repo}",
#       "subscriptions_url": "https://api.github.com/users/IvanYingX/subscriptions",
#       "organizations_url": "https://api.github.com/users/IvanYingX/orgs",
#       "repos_url": "https://api.github.com/users/IvanYingX/repos",
#       "events_url": "https://api.github.com/users/IvanYingX/events{/privacy}",
#       "received_events_url": "https://api.github.com/users/IvanYingX/received_events",
#       "type": "User",
#       "site_admin": false
#     },
#     "html_url": "https://github.com/IvanYingX/aicore-teachable-machine",
#     "description": null,
#     "fork": false,
#     "url": "https://api.github.com/repos/IvanYingX/aicore-teachable-machine",
#     "forks_url": "https://api.github.com/repos/IvanYingX/aicore-teachable-machine/forks",
#     "keys_url": "https://api.github.com/repos/IvanYingX/aicore-teachable-machine/keys{/key_id}",
#     "collaborators_url": "https://api.github.com/repos/IvanYingX/aicore-teachable-machine/collaborators{/collaborator}",
#     "teams_url": "https://api.github.com/repos/IvanYingX/aicore-teachable-machine/teams",
#     "hooks_url": "https://api.github.com/repos/IvanYingX/aicore-teachable-machine/hooks",
#     "issue_events_url": "https://api.github.com/repos/IvanYingX/aicore-teachable-machine/issues/events{/number}",
#     "events_url": "https://api.github.com/repos/IvanYingX/aicore-teachable-machine/events",
#     "assignees_url": "https://api.github.com/repos/IvanYingX/aicore-teachable-machine/assignees{/user}",
#     "branches_url": "https://api.github.com/repos/IvanYingX/aicore-teachable-machine/branches{/branch}",
#     "tags_url": "https://api.github.com/repos/IvanYingX/aicore-teachable-machine/tags",
#     "blobs_url": "https://api.github.com/repos/IvanYingX/aicore-teachable-machine/git/blobs{/sha}",
#     "git_tags_url": "https://api.github.com/repos/IvanYingX/aicore-teachable-machine/git/tags{/sha}",
#     "git_refs_url": "https://api.github.com/repos/IvanYingX/aicore-teachable-machine/git/refs{/sha}",
#     "trees_url": "https://api.github.com/repos/IvanYingX/aicore-teachable-machine/git/trees{/sha}",
#     "statuses_url": "https://api.github.com/repos/IvanYingX/aicore-teachable-machine/statuses/{sha}",
#     "languages_url": "https://api.github.com/repos/IvanYingX/aicore-teachable-machine/languages",
#     "stargazers_url": "https://api.github.com/repos/IvanYingX/aicore-teachable-machine/stargazers",
#     "contributors_url": "https://api.github.com/repos/IvanYingX/aicore-teachable-machine/contributors",
#     "subscribers_url": "https://api.github.com/repos/IvanYingX/aicore-teachable-machine/subscribers",
#     "subscription_url": "https://api.github.com/repos/IvanYingX/aicore-teachable-machine/subscription",
#     "commits_url": "https://api.github.com/repos/IvanYingX/aicore-teachable-machine/commits{/sha}",
#     "git_commits_url": "https://api.github.com/repos/IvanYingX/aicore-teachable-machine/git/commits{/sha}",
#     "comments_url": "https://api.github.com/repos/IvanYingX/aicore-teachable-machine/comments{/number}",
#     "issue_comment_url": "https://api.github.com/repos/IvanYingX/aicore-teachable-machine/issues/comments{/number}",
#     "contents_url": "https://api.github.com/repos/IvanYingX/aicore-teachable-machine/contents/{+path}",
#     "compare_url": "https://api.github.com/repos/IvanYingX/aicore-teachable-machine/compare/{base}...{head}",
#     "merges_url": "https://api.github.com/repos/IvanYingX/aicore-teachable-machine/merges",
#     "archive_url": "https://api.github.com/repos/IvanYingX/aicore-teachable-machine/{archive_format}{/ref}",
#     "downloads_url": "https://api.github.com/repos/IvanYingX/aicore-teachable-machine/downloads",
#     "issues_url": "https://api.github.com/repos/IvanYingX/aicore-teachable-machine/issues{/number}",
#     "pulls_url": "https://api.github.com/repos/IvanYingX/aicore-teachable-machine/pulls{/number}",
#     "milestones_url": "https://api.github.com/repos/IvanYingX/aicore-teachable-machine/milestones{/number}",
#     "notifications_url": "https://api.github.com/repos/IvanYingX/aicore-teachable-machine/notifications{?since,all,participating}",
#     "labels_url": "https://api.github.com/repos/IvanYingX/aicore-teachable-machine/labels{/name}",
#     "releases_url": "https://api.github.com/repos/IvanYingX/aicore-teachable-machine/releases{/id}",
#     "deployments_url": "https://api.github.com/repos/IvanYingX/aicore-teachable-machine/deployments",
#     "created_at": "2021-12-09T21:03:26Z",
#     "updated_at": "2021-12-13T14:44:55Z",
#     "pushed_at": "2021-12-13T14:44:52Z",
#     "git_url": "git://github.com/IvanYingX/aicore-teachable-machine.git",
#     "ssh_url": "git@github.com:IvanYingX/aicore-teachable-machine.git",
#     "clone_url": "https://github.com/IvanYingX/aicore-teachable-machine.git",
#     "svn_url": "https://github.com/IvanYingX/aicore-teachable-machine",
#     "homepage": null,
#     "size": 7,
#     "stargazers_count": 0,
#     "watchers_count": 0,
#     "language": "HTML",
#     "has_issues": true,
#     "has_projects": true,
#     "has_downloads": true,
#     "has_wiki": true,
#     "has_pages": true,
#     "forks_count": 0,
#     "mirror_url": null,
#     "archived": false,
#     "disabled": false,
#     "open_issues_count": 0,
#     "license": null,
#     "allow_forking": true,
#     "is_template": false,
#     "topics": [
#
#     ],
#     "visibility": "public",
#     "forks": 0,
#     "open_issues": 0,
#     "watchers": 0,
#     "default_branch": "main"
#   },
#   {
#     "id": 431255908,
#     "node_id": "R_kgDOGbRxZA",
#     "name": "AiCore-Test2",
#     "full_name": "IvanYingX/AiCore-Test2",
#     "private": false,
#     "owner": {
#       "login": "IvanYingX",
#       "id": 58112372,
#       "node_id": "MDQ6VXNlcjU4MTEyMzcy",
#       "avatar_url": "https://avatars.githubusercontent.com/u/58112372?v=4",
#       "gravatar_id": "",
#       "url": "https://api.github.com/users/IvanYingX",
#       "html_url": "https://github.com/IvanYingX",
#       "followers_url": "https://api.github.com/users/IvanYingX/followers",
#       "following_url": "https://api.github.com/users/IvanYingX/following{/other_user}",
#       "gists_url": "https://api.github.com/users/IvanYingX/gists{/gist_id}",
#       "starred_url": "https://api.github.com/users/IvanYingX/starred{/owner}{/repo}",
#       "subscriptions_url": "https://api.github.com/users/IvanYingX/subscriptions",
#       "organizations_url": "https://api.github.com/users/IvanYingX/orgs",
#       "repos_url": "https://api.github.com/users/IvanYingX/repos",
#       "events_url": "https://api.github.com/users/IvanYingX/events{/privacy}",
#       "received_events_url": "https://api.github.com/users/IvanYingX/received_events",
#       "type": "User",
#       "site_admin": false
#     },
#     "html_url": "https://github.com/IvanYingX/AiCore-Test2",
#     "description": null,
#     "fork": false,
#     "url": "https://api.github.com/repos/IvanYingX/AiCore-Test2",
#     "forks_url": "https://api.github.com/repos/IvanYingX/AiCore-Test2/forks",
#     "keys_url": "https://api.github.com/repos/IvanYingX/AiCore-Test2/keys{/key_id}",
#     "collaborators_url": "https://api.github.com/repos/IvanYingX/AiCore-Test2/collaborators{/collaborator}",
#     "teams_url": "https://api.github.com/repos/IvanYingX/AiCore-Test2/teams",
#     "hooks_url": "https://api.github.com/repos/IvanYingX/AiCore-Test2/hooks",
#     "issue_events_url": "https://api.github.com/repos/IvanYingX/AiCore-Test2/issues/events{/number}",
#     "events_url": "https://api.github.com/repos/IvanYingX/AiCore-Test2/events",
#     "assignees_url": "https://api.github.com/repos/IvanYingX/AiCore-Test2/assignees{/user}",
#     "branches_url": "https://api.github.com/repos/IvanYingX/AiCore-Test2/branches{/branch}",
#     "tags_url": "https://api.github.com/repos/IvanYingX/AiCore-Test2/tags",
#     "blobs_url": "https://api.github.com/repos/IvanYingX/AiCore-Test2/git/blobs{/sha}",
#     "git_tags_url": "https://api.github.com/repos/IvanYingX/AiCore-Test2/git/tags{/sha}",
#     "git_refs_url": "https://api.github.com/repos/IvanYingX/AiCore-Test2/git/refs{/sha}",
#     "trees_url": "https://api.github.com/repos/IvanYingX/AiCore-Test2/git/trees{/sha}",
#     "statuses_url": "https://api.github.com/repos/IvanYingX/AiCore-Test2/statuses/{sha}",
#     "languages_url": "https://api.github.com/repos/IvanYingX/AiCore-Test2/languages",
#     "stargazers_url": "https://api.github.com/repos/IvanYingX/AiCore-Test2/stargazers",
#     "contributors_url": "https://api.github.com/repos/IvanYingX/AiCore-Test2/contributors",
#     "subscribers_url": "https://api.github.com/repos/IvanYingX/AiCore-Test2/subscribers",
#     "subscription_url": "https://api.github.com/repos/IvanYingX/AiCore-Test2/subscription",
#     "commits_url": "https://api.github.com/repos/IvanYingX/AiCore-Test2/commits{/sha}",
#     "git_commits_url": "https://api.github.com/repos/IvanYingX/AiCore-Test2/git/commits{/sha}",
#     "comments_url": "https://api.github.com/repos/IvanYingX/AiCore-Test2/comments{/number}",
#     "issue_comment_url": "https://api.github.com/repos/IvanYingX/AiCore-Test2/issues/comments{/number}",
#     "contents_url": "https://api.github.com/repos/IvanYingX/AiCore-Test2/contents/{+path}",
#     "compare_url": "https://api.github.com/repos/IvanYingX/AiCore-Test2/compare/{base}...{head}",
#     "merges_url": "https://api.github.com/repos/IvanYingX/AiCore-Test2/merges",
#     "archive_url": "https://api.github.com/repos/IvanYingX/AiCore-Test2/{archive_format}{/ref}",
#     "downloads_url": "https://api.github.com/repos/IvanYingX/AiCore-Test2/downloads",
#     "issues_url": "https://api.github.com/repos/IvanYingX/AiCore-Test2/issues{/number}",
#     "pulls_url": "https://api.github.com/repos/IvanYingX/AiCore-Test2/pulls{/number}",
#     "milestones_url": "https://api.github.com/repos/IvanYingX/AiCore-Test2/milestones{/number}",
#     "notifications_url": "https://api.github.com/repos/IvanYingX/AiCore-Test2/notifications{?since,all,participating}",
#     "labels_url": "https://api.github.com/repos/IvanYingX/AiCore-Test2/labels{/name}",
#     "releases_url": "https://api.github.com/repos/IvanYingX/AiCore-Test2/releases{/id}",
#     "deployments_url": "https://api.github.com/repos/IvanYingX/AiCore-Test2/deployments",
#     "created_at": "2021-11-23T21:16:43Z",
#     "updated_at": "2021-11-23T23:20:58Z",
#     "pushed_at": "2021-11-23T23:20:56Z",
#     "git_url": "git://github.com/IvanYingX/AiCore-Test2.git",
#     "ssh_url": "git@github.com:IvanYingX/AiCore-Test2.git",
#     "clone_url": "https://github.com/IvanYingX/AiCore-Test2.git",
#     "svn_url": "https://github.com/IvanYingX/AiCore-Test2",
#     "homepage": null,
#     "size": 0,
#     "stargazers_count": 0,
#     "watchers_count": 0,
#     "language": null,
#     "has_issues": true,
#     "has_projects": true,
#     "has_downloads": true,
#     "has_wiki": true,
#     "has_pages": false,
#     "forks_count": 0,
#     "mirror_url": null,
#     "archived": false,
#     "disabled": false,
#     "open_issues_count": 0,
#     "license": null,
#     "allow_forking": true,
#     "is_template": false,
#     "topics": [
#
#     ],
#     "visibility": "public",
#     "forks": 0,
#     "open_issues": 0,
#     "watchers": 0,
#     "default_branch": "main"
#   },
#   {
#     "id": 335749311,
#     "node_id": "MDEwOlJlcG9zaXRvcnkzMzU3NDkzMTE=",
#     "name": "aws-elastic-beanstalk-express-js-sample",
#     "full_name": "IvanYingX/aws-elastic-beanstalk-express-js-sample",
#     "private": false,
#     "owner": {
#       "login": "IvanYingX",
#       "id": 58112372,
#       "node_id": "MDQ6VXNlcjU4MTEyMzcy",
#       "avatar_url": "https://avatars.githubusercontent.com/u/58112372?v=4",
#       "gravatar_id": "",
#       "url": "https://api.github.com/users/IvanYingX",
#       "html_url": "https://github.com/IvanYingX",
#       "followers_url": "https://api.github.com/users/IvanYingX/followers",
#       "following_url": "https://api.github.com/users/IvanYingX/following{/other_user}",
#       "gists_url": "https://api.github.com/users/IvanYingX/gists{/gist_id}",
#       "starred_url": "https://api.github.com/users/IvanYingX/starred{/owner}{/repo}",
#       "subscriptions_url": "https://api.github.com/users/IvanYingX/subscriptions",
#       "organizations_url": "https://api.github.com/users/IvanYingX/orgs",
#       "repos_url": "https://api.github.com/users/IvanYingX/repos",
#       "events_url": "https://api.github.com/users/IvanYingX/events{/privacy}",
#       "received_events_url": "https://api.github.com/users/IvanYingX/received_events",
#       "type": "User",
#       "site_admin": false
#     },
#     "html_url": "https://github.com/IvanYingX/aws-elastic-beanstalk-express-js-sample",
#     "description": "Sample web application for the AWS DevOps Engineer Learning Path.",
#     "fork": true,
#     "url": "https://api.github.com/repos/IvanYingX/aws-elastic-beanstalk-express-js-sample",
#     "forks_url": "https://api.github.com/repos/IvanYingX/aws-elastic-beanstalk-express-js-sample/forks",
#     "keys_url": "https://api.github.com/repos/IvanYingX/aws-elastic-beanstalk-express-js-sample/keys{/key_id}",
#     "collaborators_url": "https://api.github.com/repos/IvanYingX/aws-elastic-beanstalk-express-js-sample/collaborators{/collaborator}",
#     "teams_url": "https://api.github.com/repos/IvanYingX/aws-elastic-beanstalk-express-js-sample/teams",
#     "hooks_url": "https://api.github.com/repos/IvanYingX/aws-elastic-beanstalk-express-js-sample/hooks",
#     "issue_events_url": "https://api.github.com/repos/IvanYingX/aws-elastic-beanstalk-express-js-sample/issues/events{/number}",
#     "events_url": "https://api.github.com/repos/IvanYingX/aws-elastic-beanstalk-express-js-sample/events",
#     "assignees_url": "https://api.github.com/repos/IvanYingX/aws-elastic-beanstalk-express-js-sample/assignees{/user}",
#     "branches_url": "https://api.github.com/repos/IvanYingX/aws-elastic-beanstalk-express-js-sample/branches{/branch}",
#     "tags_url": "https://api.github.com/repos/IvanYingX/aws-elastic-beanstalk-express-js-sample/tags",
#     "blobs_url": "https://api.github.com/repos/IvanYingX/aws-elastic-beanstalk-express-js-sample/git/blobs{/sha}",
#     "git_tags_url": "https://api.github.com/repos/IvanYingX/aws-elastic-beanstalk-express-js-sample/git/tags{/sha}",
#     "git_refs_url": "https://api.github.com/repos/IvanYingX/aws-elastic-beanstalk-express-js-sample/git/refs{/sha}",
#     "trees_url": "https://api.github.com/repos/IvanYingX/aws-elastic-beanstalk-express-js-sample/git/trees{/sha}",
#     "statuses_url": "https://api.github.com/repos/IvanYingX/aws-elastic-beanstalk-express-js-sample/statuses/{sha}",
#     "languages_url": "https://api.github.com/repos/IvanYingX/aws-elastic-beanstalk-express-js-sample/languages",
#     "stargazers_url": "https://api.github.com/repos/IvanYingX/aws-elastic-beanstalk-express-js-sample/stargazers",
#     "contributors_url": "https://api.github.com/repos/IvanYingX/aws-elastic-beanstalk-express-js-sample/contributors",
#     "subscribers_url": "https://api.github.com/repos/IvanYingX/aws-elastic-beanstalk-express-js-sample/subscribers",
#     "subscription_url": "https://api.github.com/repos/IvanYingX/aws-elastic-beanstalk-express-js-sample/subscription",
#     "commits_url": "https://api.github.com/repos/IvanYingX/aws-elastic-beanstalk-express-js-sample/commits{/sha}",
#     "git_commits_url": "https://api.github.com/repos/IvanYingX/aws-elastic-beanstalk-express-js-sample/git/commits{/sha}",
#     "comments_url": "https://api.github.com/repos/IvanYingX/aws-elastic-beanstalk-express-js-sample/comments{/number}",
#     "issue_comment_url": "https://api.github.com/repos/IvanYingX/aws-elastic-beanstalk-express-js-sample/issues/comments{/number}",
#     "contents_url": "https://api.github.com/repos/IvanYingX/aws-elastic-beanstalk-express-js-sample/contents/{+path}",
#     "compare_url": "https://api.github.com/repos/IvanYingX/aws-elastic-beanstalk-express-js-sample/compare/{base}...{head}",
#     "merges_url": "https://api.github.com/repos/IvanYingX/aws-elastic-beanstalk-express-js-sample/merges",
#     "archive_url": "https://api.github.com/repos/IvanYingX/aws-elastic-beanstalk-express-js-sample/{archive_format}{/ref}",
#     "downloads_url": "https://api.github.com/repos/IvanYingX/aws-elastic-beanstalk-express-js-sample/downloads",
#     "issues_url": "https://api.github.com/repos/IvanYingX/aws-elastic-beanstalk-express-js-sample/issues{/number}",
#     "pulls_url": "https://api.github.com/repos/IvanYingX/aws-elastic-beanstalk-express-js-sample/pulls{/number}",
#     "milestones_url": "https://api.github.com/repos/IvanYingX/aws-elastic-beanstalk-express-js-sample/milestones{/number}",
#     "notifications_url": "https://api.github.com/repos/IvanYingX/aws-elastic-beanstalk-express-js-sample/notifications{?since,all,participating}",
#     "labels_url": "https://api.github.com/repos/IvanYingX/aws-elastic-beanstalk-express-js-sample/labels{/name}",
#     "releases_url": "https://api.github.com/repos/IvanYingX/aws-elastic-beanstalk-express-js-sample/releases{/id}",
#     "deployments_url": "https://api.github.com/repos/IvanYingX/aws-elastic-beanstalk-express-js-sample/deployments",
#     "created_at": "2021-02-03T20:42:05Z",
#     "updated_at": "2021-02-03T23:21:25Z",
#     "pushed_at": "2021-02-03T23:21:23Z",
#     "git_url": "git://github.com/IvanYingX/aws-elastic-beanstalk-express-js-sample.git",
#     "ssh_url": "git@github.com:IvanYingX/aws-elastic-beanstalk-express-js-sample.git",
#     "clone_url": "https://github.com/IvanYingX/aws-elastic-beanstalk-express-js-sample.git",
#     "svn_url": "https://github.com/IvanYingX/aws-elastic-beanstalk-express-js-sample",
#     "homepage": "https://aws.amazon.com/getting-started/learning-path-devops-engineer/",
#     "size": 10,
#     "stargazers_count": 0,
#     "watchers_count": 0,
#     "language": "JavaScript",
#     "has_issues": false,
#     "has_projects": true,
#     "has_downloads": true,
#     "has_wiki": true,
#     "has_pages": false,
#     "forks_count": 0,
#     "mirror_url": null,
#     "archived": false,
#     "disabled": false,
#     "open_issues_count": 0,
#     "license": {
#       "key": "other",
#       "name": "Other",
#       "spdx_id": "NOASSERTION",
#       "url": null,
#       "node_id": "MDc6TGljZW5zZTA="
#     },
#     "allow_forking": true,
#     "is_template": false,
#     "topics": [
#
#     ],
#     "visibility": "public",
#     "forks": 0,
#     "open_issues": 0,
#     "watchers": 0,
#     "default_branch": "main"
#   },
#   {
#     "id": 377983518,
#     "node_id": "MDEwOlJlcG9zaXRvcnkzNzc5ODM1MTg=",
#     "name": "cat_scraper",
#     "full_name": "IvanYingX/cat_scraper",
#     "private": false,
#     "owner": {
#       "login": "IvanYingX",
#       "id": 58112372,
#       "node_id": "MDQ6VXNlcjU4MTEyMzcy",
#       "avatar_url": "https://avatars.githubusercontent.com/u/58112372?v=4",
#       "gravatar_id": "",
#       "url": "https://api.github.com/users/IvanYingX",
#       "html_url": "https://github.com/IvanYingX",
#       "followers_url": "https://api.github.com/users/IvanYingX/followers",
#       "following_url": "https://api.github.com/users/IvanYingX/following{/other_user}",
#       "gists_url": "https://api.github.com/users/IvanYingX/gists{/gist_id}",
#       "starred_url": "https://api.github.com/users/IvanYingX/starred{/owner}{/repo}",
#       "subscriptions_url": "https://api.github.com/users/IvanYingX/subscriptions",
#       "organizations_url": "https://api.github.com/users/IvanYingX/orgs",
#       "repos_url": "https://api.github.com/users/IvanYingX/repos",
#       "events_url": "https://api.github.com/users/IvanYingX/events{/privacy}",
#       "received_events_url": "https://api.github.com/users/IvanYingX/received_events",
#       "type": "User",
#       "site_admin": false
#     },
#     "html_url": "https://github.com/IvanYingX/cat_scraper",
#     "description": null,
#     "fork": false,
#     "url": "https://api.github.com/repos/IvanYingX/cat_scraper",
#     "forks_url": "https://api.github.com/repos/IvanYingX/cat_scraper/forks",
#     "keys_url": "https://api.github.com/repos/IvanYingX/cat_scraper/keys{/key_id}",
#     "collaborators_url": "https://api.github.com/repos/IvanYingX/cat_scraper/collaborators{/collaborator}",
#     "teams_url": "https://api.github.com/repos/IvanYingX/cat_scraper/teams",
#     "hooks_url": "https://api.github.com/repos/IvanYingX/cat_scraper/hooks",
#     "issue_events_url": "https://api.github.com/repos/IvanYingX/cat_scraper/issues/events{/number}",
#     "events_url": "https://api.github.com/repos/IvanYingX/cat_scraper/events",
#     "assignees_url": "https://api.github.com/repos/IvanYingX/cat_scraper/assignees{/user}",
#     "branches_url": "https://api.github.com/repos/IvanYingX/cat_scraper/branches{/branch}",
#     "tags_url": "https://api.github.com/repos/IvanYingX/cat_scraper/tags",
#     "blobs_url": "https://api.github.com/repos/IvanYingX/cat_scraper/git/blobs{/sha}",
#     "git_tags_url": "https://api.github.com/repos/IvanYingX/cat_scraper/git/tags{/sha}",
#     "git_refs_url": "https://api.github.com/repos/IvanYingX/cat_scraper/git/refs{/sha}",
#     "trees_url": "https://api.github.com/repos/IvanYingX/cat_scraper/git/trees{/sha}",
#     "statuses_url": "https://api.github.com/repos/IvanYingX/cat_scraper/statuses/{sha}",
#     "languages_url": "https://api.github.com/repos/IvanYingX/cat_scraper/languages",
#     "stargazers_url": "https://api.github.com/repos/IvanYingX/cat_scraper/stargazers",
#     "contributors_url": "https://api.github.com/repos/IvanYingX/cat_scraper/contributors",
#     "subscribers_url": "https://api.github.com/repos/IvanYingX/cat_scraper/subscribers",
#     "subscription_url": "https://api.github.com/repos/IvanYingX/cat_scraper/subscription",
#     "commits_url": "https://api.github.com/repos/IvanYingX/cat_scraper/commits{/sha}",
#     "git_commits_url": "https://api.github.com/repos/IvanYingX/cat_scraper/git/commits{/sha}",
#     "comments_url": "https://api.github.com/repos/IvanYingX/cat_scraper/comments{/number}",
#     "issue_comment_url": "https://api.github.com/repos/IvanYingX/cat_scraper/issues/comments{/number}",
#     "contents_url": "https://api.github.com/repos/IvanYingX/cat_scraper/contents/{+path}",
#     "compare_url": "https://api.github.com/repos/IvanYingX/cat_scraper/compare/{base}...{head}",
#     "merges_url": "https://api.github.com/repos/IvanYingX/cat_scraper/merges",
#     "archive_url": "https://api.github.com/repos/IvanYingX/cat_scraper/{archive_format}{/ref}",
#     "downloads_url": "https://api.github.com/repos/IvanYingX/cat_scraper/downloads",
#     "issues_url": "https://api.github.com/repos/IvanYingX/cat_scraper/issues{/number}",
#     "pulls_url": "https://api.github.com/repos/IvanYingX/cat_scraper/pulls{/number}",
#     "milestones_url": "https://api.github.com/repos/IvanYingX/cat_scraper/milestones{/number}",
#     "notifications_url": "https://api.github.com/repos/IvanYingX/cat_scraper/notifications{?since,all,participating}",
#     "labels_url": "https://api.github.com/repos/IvanYingX/cat_scraper/labels{/name}",
#     "releases_url": "https://api.github.com/repos/IvanYingX/cat_scraper/releases{/id}",
#     "deployments_url": "https://api.github.com/repos/IvanYingX/cat_scraper/deployments",
#     "created_at": "2021-06-17T23:26:56Z",
#     "updated_at": "2021-08-05T08:18:08Z",
#     "pushed_at": "2021-08-05T08:18:06Z",
#     "git_url": "git://github.com/IvanYingX/cat_scraper.git",
#     "ssh_url": "git@github.com:IvanYingX/cat_scraper.git",
#     "clone_url": "https://github.com/IvanYingX/cat_scraper.git",
#     "svn_url": "https://github.com/IvanYingX/cat_scraper",
#     "homepage": null,
#     "size": 16090,
#     "stargazers_count": 0,
#     "watchers_count": 0,
#     "language": "Python",
#     "has_issues": true,
#     "has_projects": true,
#     "has_downloads": true,
#     "has_wiki": true,
#     "has_pages": false,
#     "forks_count": 0,
#     "mirror_url": null,
#     "archived": false,
#     "disabled": false,
#     "open_issues_count": 0,
#     "license": null,
#     "allow_forking": true,
#     "is_template": false,
#     "topics": [
#
#     ],
#     "visibility": "public",
#     "forks": 0,
#     "open_issues": 0,
#     "watchers": 0,
#     "default_branch": "main"
#   },
#   {
#     "id": 381129002,
#     "node_id": "MDEwOlJlcG9zaXRvcnkzODExMjkwMDI=",
#     "name": "Challenges_AiCore",
#     "full_name": "IvanYingX/Challenges_AiCore",
#     "private": false,
#     "owner": {
#       "login": "IvanYingX",
#       "id": 58112372,
#       "node_id": "MDQ6VXNlcjU4MTEyMzcy",
#       "avatar_url": "https://avatars.githubusercontent.com/u/58112372?v=4",
#       "gravatar_id": "",
#       "url": "https://api.github.com/users/IvanYingX",
#       "html_url": "https://github.com/IvanYingX",
#       "followers_url": "https://api.github.com/users/IvanYingX/followers",
#       "following_url": "https://api.github.com/users/IvanYingX/following{/other_user}",
#       "gists_url": "https://api.github.com/users/IvanYingX/gists{/gist_id}",
#       "starred_url": "https://api.github.com/users/IvanYingX/starred{/owner}{/repo}",
#       "subscriptions_url": "https://api.github.com/users/IvanYingX/subscriptions",
#       "organizations_url": "https://api.github.com/users/IvanYingX/orgs",
#       "repos_url": "https://api.github.com/users/IvanYingX/repos",
#       "events_url": "https://api.github.com/users/IvanYingX/events{/privacy}",
#       "received_events_url": "https://api.github.com/users/IvanYingX/received_events",
#       "type": "User",
#       "site_admin": false
#     },
#     "html_url": "https://github.com/IvanYingX/Challenges_AiCore",
#     "description": null,
#     "fork": false,
#     "url": "https://api.github.com/repos/IvanYingX/Challenges_AiCore",
#     "forks_url": "https://api.github.com/repos/IvanYingX/Challenges_AiCore/forks",
#     "keys_url": "https://api.github.com/repos/IvanYingX/Challenges_AiCore/keys{/key_id}",
#     "collaborators_url": "https://api.github.com/repos/IvanYingX/Challenges_AiCore/collaborators{/collaborator}",
#     "teams_url": "https://api.github.com/repos/IvanYingX/Challenges_AiCore/teams",
#     "hooks_url": "https://api.github.com/repos/IvanYingX/Challenges_AiCore/hooks",
#     "issue_events_url": "https://api.github.com/repos/IvanYingX/Challenges_AiCore/issues/events{/number}",
#     "events_url": "https://api.github.com/repos/IvanYingX/Challenges_AiCore/events",
#     "assignees_url": "https://api.github.com/repos/IvanYingX/Challenges_AiCore/assignees{/user}",
#     "branches_url": "https://api.github.com/repos/IvanYingX/Challenges_AiCore/branches{/branch}",
#     "tags_url": "https://api.github.com/repos/IvanYingX/Challenges_AiCore/tags",
#     "blobs_url": "https://api.github.com/repos/IvanYingX/Challenges_AiCore/git/blobs{/sha}",
#     "git_tags_url": "https://api.github.com/repos/IvanYingX/Challenges_AiCore/git/tags{/sha}",
#     "git_refs_url": "https://api.github.com/repos/IvanYingX/Challenges_AiCore/git/refs{/sha}",
#     "trees_url": "https://api.github.com/repos/IvanYingX/Challenges_AiCore/git/trees{/sha}",
#     "statuses_url": "https://api.github.com/repos/IvanYingX/Challenges_AiCore/statuses/{sha}",
#     "languages_url": "https://api.github.com/repos/IvanYingX/Challenges_AiCore/languages",
#     "stargazers_url": "https://api.github.com/repos/IvanYingX/Challenges_AiCore/stargazers",
#     "contributors_url": "https://api.github.com/repos/IvanYingX/Challenges_AiCore/contributors",
#     "subscribers_url": "https://api.github.com/repos/IvanYingX/Challenges_AiCore/subscribers",
#     "subscription_url": "https://api.github.com/repos/IvanYingX/Challenges_AiCore/subscription",
#     "commits_url": "https://api.github.com/repos/IvanYingX/Challenges_AiCore/commits{/sha}",
#     "git_commits_url": "https://api.github.com/repos/IvanYingX/Challenges_AiCore/git/commits{/sha}",
#     "comments_url": "https://api.github.com/repos/IvanYingX/Challenges_AiCore/comments{/number}",
#     "issue_comment_url": "https://api.github.com/repos/IvanYingX/Challenges_AiCore/issues/comments{/number}",
#     "contents_url": "https://api.github.com/repos/IvanYingX/Challenges_AiCore/contents/{+path}",
#     "compare_url": "https://api.github.com/repos/IvanYingX/Challenges_AiCore/compare/{base}...{head}",
#     "merges_url": "https://api.github.com/repos/IvanYingX/Challenges_AiCore/merges",
#     "archive_url": "https://api.github.com/repos/IvanYingX/Challenges_AiCore/{archive_format}{/ref}",
#     "downloads_url": "https://api.github.com/repos/IvanYingX/Challenges_AiCore/downloads",
#     "issues_url": "https://api.github.com/repos/IvanYingX/Challenges_AiCore/issues{/number}",
#     "pulls_url": "https://api.github.com/repos/IvanYingX/Challenges_AiCore/pulls{/number}",
#     "milestones_url": "https://api.github.com/repos/IvanYingX/Challenges_AiCore/milestones{/number}",
#     "notifications_url": "https://api.github.com/repos/IvanYingX/Challenges_AiCore/notifications{?since,all,participating}",
#     "labels_url": "https://api.github.com/repos/IvanYingX/Challenges_AiCore/labels{/name}",
#     "releases_url": "https://api.github.com/repos/IvanYingX/Challenges_AiCore/releases{/id}",
#     "deployments_url": "https://api.github.com/repos/IvanYingX/Challenges_AiCore/deployments",
#     "created_at": "2021-06-28T18:37:55Z",
#     "updated_at": "2021-11-09T14:15:02Z",
#     "pushed_at": "2021-10-28T22:57:11Z",
#     "git_url": "git://github.com/IvanYingX/Challenges_AiCore.git",
#     "ssh_url": "git@github.com:IvanYingX/Challenges_AiCore.git",
#     "clone_url": "https://github.com/IvanYingX/Challenges_AiCore.git",
#     "svn_url": "https://github.com/IvanYingX/Challenges_AiCore",
#     "homepage": null,
#     "size": 90,
#     "stargazers_count": 2,
#     "watchers_count": 2,
#     "language": "Jupyter Notebook",
#     "has_issues": true,
#     "has_projects": true,
#     "has_downloads": true,
#     "has_wiki": true,
#     "has_pages": false,
#     "forks_count": 2,
#     "mirror_url": null,
#     "archived": false,
#     "disabled": false,
#     "open_issues_count": 0,
#     "license": null,
#     "allow_forking": true,
#     "is_template": false,
#     "topics": [
#
#     ],
#     "visibility": "public",
#     "forks": 2,
#     "open_issues": 0,
#     "watchers": 2,
#     "default_branch": "main"
#   },
#   {
#     "id": 257322713,
#     "node_id": "MDEwOlJlcG9zaXRvcnkyNTczMjI3MTM=",
#     "name": "Coursera_Capstone",
#     "full_name": "IvanYingX/Coursera_Capstone",
#     "private": false,
#     "owner": {
#       "login": "IvanYingX",
#       "id": 58112372,
#       "node_id": "MDQ6VXNlcjU4MTEyMzcy",
#       "avatar_url": "https://avatars.githubusercontent.com/u/58112372?v=4",
#       "gravatar_id": "",
#       "url": "https://api.github.com/users/IvanYingX",
#       "html_url": "https://github.com/IvanYingX",
#       "followers_url": "https://api.github.com/users/IvanYingX/followers",
# ...
#     "keys_url": "https://api.github.com/repos/IvanYingX/github-slideshow/keys{/key_id}",
#     "collaborators_url": "https://api.github.com/repos/IvanYingX/github-slideshow/collaborators{/collaborator}",
#     "teams_url": "https://api.github.com/repos/IvanYingX/github-slideshow/teams",
#     "hooks_url": "https://api.github.com/repos/IvanYingX/github-slideshow/hooks",
#     "issue_events_url": "https://api.github.com/repos/IvanYingX/github-slideshow/issues/events{/number}",
#     "events_url": "https://api.github.com/repos/IvanYingX/github-slideshow/events",
#     "assignees_url": "https://api.github.com/repos/IvanYingX/github-slideshow/assignees{/user}",
#     "branches_url": "https://api.github.com/repos/IvanYingX/github-slideshow/branches{/branch}",
#     "tags_url": "https://api.github.com/repos/IvanYingX/github-slideshow/tags",
#     "blobs_url": "https://api.github.com/repos/IvanYingX/github-slideshow/git/blobs{/sha}",
#     "git_tags_url": "https://api.github.com/repos/IvanYingX/github-slideshow/git/tags{/sha}",
#     "git_refs_url": "https://api.github.com/repos/IvanYingX/github-slideshow/git/refs{/sha}",
#     "trees_url": "https://api.github.com/repos/IvanYingX/github-slideshow/git/trees{/sha}",
#     "statuses_url": "https://api.github.com/repos/IvanYingX/github-slideshow/statuses/{sha}",
#     "languages_url": "https://api.github.com/repos/IvanYingX/github-slideshow/languages",
#     "stargazers_url": "https://api.github.com/repos/IvanYingX/github-slideshow/stargazers",
#     "contributors_url": "https://api.github.com/repos/IvanYingX/github-slideshow/contributors",
#     "subscribers_url": "https://api.github.com/repos/IvanYingX/github-slideshow/subscribers",
#     "subscription_url": "https://api.github.com/repos/IvanYingX/github-slideshow/subscription",
#     "commits_url": "https://api.github.com/repos/IvanYingX/github-slideshow/commits{/sha}",
#     "git_commits_url": "https://api.github.com/repos/IvanYingX/github-slideshow/git/commits{/sha}",
#     "comments_url": "https://api.github.com/repos/IvanYingX/github-slideshow/comments{/number}",
#     "issue_comment_url": "https://api.github.com/repos/IvanYingX/github-slideshow/issues/comments{/number}",
#     "contents_url": "https://api.github.com/repos/IvanYingX/github-slideshow/contents/{+path}",
#     "compare_url": "https://api.github.com/repos/IvanYingX/github-slideshow/compare/{base}...{head}",
#     "merges_url": "https://api.github.com/repos/IvanYingX/github-slideshow/merges",
#     "archive_url": "https://api.github.com/repos/IvanYingX/github-slideshow/{archive_format}{/ref}",
#     "downloads_url": "https://api.github.com/repos/IvanYingX/github-slideshow/downloads",
#     "issues_url": "https://api.github.com/repos/IvanYingX/github-slideshow/issues{/number}",
#     "pulls_url": "https://api.github.com/repos/IvanYingX/github-slideshow/pulls{/number}",
#     "milestones_url": "https://api.github.com/repos/IvanYingX/github-slideshow/milestones{/number}",
#     "notifications_url": "https://api.github.com/repos/IvanYingX/github-slideshow/notifications{?since,all,participating}",
#     "labels_url": "https://api.github.com/repos/IvanYingX/github-slideshow/labels{/name}",
#     "releases_url": "https://api.github.com/repos/IvanYingX/github-slideshow/releases{/id}",
#     "deployments_url": "https://api.github.com/repos/IvanYingX/github-slideshow/deployments",
#     "created_at": "2021-02-11T01:18:11Z",
#     "updated_at": "2021-02-11T01:38:12Z",
#     "pushed_at": "2021-02-11T01:38:28Z",
#     "git_url": "git://github.com/IvanYingX/github-slideshow.git",
#     "ssh_url": "git@github.com:IvanYingX/github-slideshow.git",
#     "clone_url": "https://github.com/IvanYingX/github-slideshow.git",
#     "svn_url": "https://github.com/IvanYingX/github-slideshow",
#     "homepage": "https://lab.github.com/githubtraining/introduction-to-github",
#     "size": 3525,
#     "stargazers_count": 0,
#     "watchers_count": 0,
#     "language": "Ruby",
#     "has_issues": true,
#     "has_projects": true,
#     "has_downloads": true,
#     "has_wiki": true,
#     "has_pages": true,
#     "forks_count": 0,
#     "mirror_url": null,
#     "archived": false,
#     "disabled": false,
#     "open_issues_count": 0,
#     "license": {
#       "key": "mit",
#       "name": "MIT License",
#       "spdx_id": "MIT",
#       "url": "https://api.github.com/licenses/mit",
#       "node_id": "MDc6TGljZW5zZTEz"
#     },
#     "allow_forking": true,
#     "is_template": false,
#     "topics": [
#
#     ],
#     "visibility": "public",
#     "forks": 0,
#     "open_issues": 0,
#     "watchers": 0,
#     "default_branch": "main"
#   },
#   {
#     "id": 371554435,
#     "node_id": "MDEwOlJlcG9zaXRvcnkzNzE1NTQ0MzU=",
#     "name": "HandTracking",
#     "full_name": "IvanYingX/HandTracking",
#     "private": false,
#     "owner": {
#       "login": "IvanYingX",
#       "id": 58112372,
#       "node_id": "MDQ6VXNlcjU4MTEyMzcy",
#       "avatar_url": "https://avatars.githubusercontent.com/u/58112372?v=4",
#       "gravatar_id": "",
#       "url": "https://api.github.com/users/IvanYingX",
#       "html_url": "https://github.com/IvanYingX",
#       "followers_url": "https://api.github.com/users/IvanYingX/followers",
#       "following_url": "https://api.github.com/users/IvanYingX/following{/other_user}",
#       "gists_url": "https://api.github.com/users/IvanYingX/gists{/gist_id}",
#       "starred_url": "https://api.github.com/users/IvanYingX/starred{/owner}{/repo}",
#       "subscriptions_url": "https://api.github.com/users/IvanYingX/subscriptions",
#       "organizations_url": "https://api.github.com/users/IvanYingX/orgs",
#       "repos_url": "https://api.github.com/users/IvanYingX/repos",
#       "events_url": "https://api.github.com/users/IvanYingX/events{/privacy}",
#       "received_events_url": "https://api.github.com/users/IvanYingX/received_events",
#       "type": "User",
#       "site_admin": false
#     },
#     "html_url": "https://github.com/IvanYingX/HandTracking",
#     "description": null,
#     "fork": false,
#     "url": "https://api.github.com/repos/IvanYingX/HandTracking",
#     "forks_url": "https://api.github.com/repos/IvanYingX/HandTracking/forks",
#     "keys_url": "https://api.github.com/repos/IvanYingX/HandTracking/keys{/key_id}",
#     "collaborators_url": "https://api.github.com/repos/IvanYingX/HandTracking/collaborators{/collaborator}",
#     "teams_url": "https://api.github.com/repos/IvanYingX/HandTracking/teams",
#     "hooks_url": "https://api.github.com/repos/IvanYingX/HandTracking/hooks",
#     "issue_events_url": "https://api.github.com/repos/IvanYingX/HandTracking/issues/events{/number}",
#     "events_url": "https://api.github.com/repos/IvanYingX/HandTracking/events",
#     "assignees_url": "https://api.github.com/repos/IvanYingX/HandTracking/assignees{/user}",
#     "branches_url": "https://api.github.com/repos/IvanYingX/HandTracking/branches{/branch}",
#     "tags_url": "https://api.github.com/repos/IvanYingX/HandTracking/tags",
#     "blobs_url": "https://api.github.com/repos/IvanYingX/HandTracking/git/blobs{/sha}",
#     "git_tags_url": "https://api.github.com/repos/IvanYingX/HandTracking/git/tags{/sha}",
#     "git_refs_url": "https://api.github.com/repos/IvanYingX/HandTracking/git/refs{/sha}",
#     "trees_url": "https://api.github.com/repos/IvanYingX/HandTracking/git/trees{/sha}",
#     "statuses_url": "https://api.github.com/repos/IvanYingX/HandTracking/statuses/{sha}",
#     "languages_url": "https://api.github.com/repos/IvanYingX/HandTracking/languages",
#     "stargazers_url": "https://api.github.com/repos/IvanYingX/HandTracking/stargazers",
#     "contributors_url": "https://api.github.com/repos/IvanYingX/HandTracking/contributors",
#     "subscribers_url": "https://api.github.com/repos/IvanYingX/HandTracking/subscribers",
#     "subscription_url": "https://api.github.com/repos/IvanYingX/HandTracking/subscription",
#     "commits_url": "https://api.github.com/repos/IvanYingX/HandTracking/commits{/sha}",
#     "git_commits_url": "https://api.github.com/repos/IvanYingX/HandTracking/git/commits{/sha}",
#     "comments_url": "https://api.github.com/repos/IvanYingX/HandTracking/comments{/number}",
#     "issue_comment_url": "https://api.github.com/repos/IvanYingX/HandTracking/issues/comments{/number}",
#     "contents_url": "https://api.github.com/repos/IvanYingX/HandTracking/contents/{+path}",
#     "compare_url": "https://api.github.com/repos/IvanYingX/HandTracking/compare/{base}...{head}",
#     "merges_url": "https://api.github.com/repos/IvanYingX/HandTracking/merges",
#     "archive_url": "https://api.github.com/repos/IvanYingX/HandTracking/{archive_format}{/ref}",
#     "downloads_url": "https://api.github.com/repos/IvanYingX/HandTracking/downloads",
#     "issues_url": "https://api.github.com/repos/IvanYingX/HandTracking/issues{/number}",
#     "pulls_url": "https://api.github.com/repos/IvanYingX/HandTracking/pulls{/number}",
#     "milestones_url": "https://api.github.com/repos/IvanYingX/HandTracking/milestones{/number}",
#     "notifications_url": "https://api.github.com/repos/IvanYingX/HandTracking/notifications{?since,all,participating}",
#     "labels_url": "https://api.github.com/repos/IvanYingX/HandTracking/labels{/name}",
#     "releases_url": "https://api.github.com/repos/IvanYingX/HandTracking/releases{/id}",
#     "deployments_url": "https://api.github.com/repos/IvanYingX/HandTracking/deployments",
#     "created_at": "2021-05-28T02:10:45Z",
#     "updated_at": "2021-06-03T04:37:22Z",
#     "pushed_at": "2021-06-03T04:37:19Z",
#     "git_url": "git://github.com/IvanYingX/HandTracking.git",
#     "ssh_url": "git@github.com:IvanYingX/HandTracking.git",
#     "clone_url": "https://github.com/IvanYingX/HandTracking.git",
#     "svn_url": "https://github.com/IvanYingX/HandTracking",
#     "homepage": null,
#     "size": 12,
#     "stargazers_count": 0,
#     "watchers_count": 0,
#     "language": "Python",
#     "has_issues": true,
#     "has_projects": true,
#     "has_downloads": true,
#     "has_wiki": true,
#     "has_pages": false,
#     "forks_count": 0,
#     "mirror_url": null,
#     "archived": false,
#     "disabled": false,
#     "open_issues_count": 0,
#     "license": null,
#     "allow_forking": true,
#     "is_template": false,
#     "topics": [
#
#     ],
#     "visibility": "public",
#     "forks": 0,
#     "open_issues": 0,
#     "watchers": 0,
#     "default_branch": "main"
#   },
#   {
#     "id": 325084109,
#     "node_id": "MDEwOlJlcG9zaXRvcnkzMjUwODQxMDk=",
#     "name": "House_Prices_AI",
#     "full_name": "IvanYingX/House_Prices_AI",
#     "private": false,
#     "owner": {
#       "login": "IvanYingX",
#       "id": 58112372,
#       "node_id": "MDQ6VXNlcjU4MTEyMzcy",
#       "avatar_url": "https://avatars.githubusercontent.com/u/58112372?v=4",
#       "gravatar_id": "",
#       "url": "https://api.github.com/users/IvanYingX",
#       "html_url": "https://github.com/IvanYingX",
#       "followers_url": "https://api.github.com/users/IvanYingX/followers",
#       "following_url": "https://api.github.com/users/IvanYingX/following{/other_user}",
#       "gists_url": "https://api.github.com/users/IvanYingX/gists{/gist_id}",
#       "starred_url": "https://api.github.com/users/IvanYingX/starred{/owner}{/repo}",
#       "subscriptions_url": "https://api.github.com/users/IvanYingX/subscriptions",
#       "organizations_url": "https://api.github.com/users/IvanYingX/orgs",
#       "repos_url": "https://api.github.com/users/IvanYingX/repos",
#       "events_url": "https://api.github.com/users/IvanYingX/events{/privacy}",
#       "received_events_url": "https://api.github.com/users/IvanYingX/received_events",
#       "type": "User",
#       "site_admin": false
#     },
#     "html_url": "https://github.com/IvanYingX/House_Prices_AI",
#     "description": "Christmas Challenge",
#     "fork": false,
#     "url": "https://api.github.com/repos/IvanYingX/House_Prices_AI",
#     "forks_url": "https://api.github.com/repos/IvanYingX/House_Prices_AI/forks",
#     "keys_url": "https://api.github.com/repos/IvanYingX/House_Prices_AI/keys{/key_id}",
#     "collaborators_url": "https://api.github.com/repos/IvanYingX/House_Prices_AI/collaborators{/collaborator}",
#     "teams_url": "https://api.github.com/repos/IvanYingX/House_Prices_AI/teams",
#     "hooks_url": "https://api.github.com/repos/IvanYingX/House_Prices_AI/hooks",
#     "issue_events_url": "https://api.github.com/repos/IvanYingX/House_Prices_AI/issues/events{/number}",
#     "events_url": "https://api.github.com/repos/IvanYingX/House_Prices_AI/events",
#     "assignees_url": "https://api.github.com/repos/IvanYingX/House_Prices_AI/assignees{/user}",
#     "branches_url": "https://api.github.com/repos/IvanYingX/House_Prices_AI/branches{/branch}",
#     "tags_url": "https://api.github.com/repos/IvanYingX/House_Prices_AI/tags",
#     "blobs_url": "https://api.github.com/repos/IvanYingX/House_Prices_AI/git/blobs{/sha}",
#     "git_tags_url": "https://api.github.com/repos/IvanYingX/House_Prices_AI/git/tags{/sha}",
#     "git_refs_url": "https://api.github.com/repos/IvanYingX/House_Prices_AI/git/refs{/sha}",
#     "trees_url": "https://api.github.com/repos/IvanYingX/House_Prices_AI/git/trees{/sha}",
#     "statuses_url": "https://api.github.com/repos/IvanYingX/House_Prices_AI/statuses/{sha}",
#     "languages_url": "https://api.github.com/repos/IvanYingX/House_Prices_AI/languages",
#     "stargazers_url": "https://api.github.com/repos/IvanYingX/House_Prices_AI/stargazers",
#     "contributors_url": "https://api.github.com/repos/IvanYingX/House_Prices_AI/contributors",
#     "subscribers_url": "https://api.github.com/repos/IvanYingX/House_Prices_AI/subscribers",
#     "subscription_url": "https://api.github.com/repos/IvanYingX/House_Prices_AI/subscription",
#     "commits_url": "https://api.github.com/repos/IvanYingX/House_Prices_AI/commits{/sha}",
#     "git_commits_url": "https://api.github.com/repos/IvanYingX/House_Prices_AI/git/commits{/sha}",
#     "comments_url": "https://api.github.com/repos/IvanYingX/House_Prices_AI/comments{/number}",
#     "issue_comment_url": "https://api.github.com/repos/IvanYingX/House_Prices_AI/issues/comments{/number}",
#     "contents_url": "https://api.github.com/repos/IvanYingX/House_Prices_AI/contents/{+path}",
#     "compare_url": "https://api.github.com/repos/IvanYingX/House_Prices_AI/compare/{base}...{head}",
#     "merges_url": "https://api.github.com/repos/IvanYingX/House_Prices_AI/merges",
#     "archive_url": "https://api.github.com/repos/IvanYingX/House_Prices_AI/{archive_format}{/ref}",
#     "downloads_url": "https://api.github.com/repos/IvanYingX/House_Prices_AI/downloads",
#     "issues_url": "https://api.github.com/repos/IvanYingX/House_Prices_AI/issues{/number}",
#     "pulls_url": "https://api.github.com/repos/IvanYingX/House_Prices_AI/pulls{/number}",
#     "milestones_url": "https://api.github.com/repos/IvanYingX/House_Prices_AI/milestones{/number}",
#     "notifications_url": "https://api.github.com/repos/IvanYingX/House_Prices_AI/notifications{?since,all,participating}",
#     "labels_url": "https://api.github.com/repos/IvanYingX/House_Prices_AI/labels{/name}",
#     "releases_url": "https://api.github.com/repos/IvanYingX/House_Prices_AI/releases{/id}",
#     "deployments_url": "https://api.github.com/repos/IvanYingX/House_Prices_AI/deployments",
#     "created_at": "2020-12-28T18:15:31Z",
#     "updated_at": "2021-01-04T18:25:20Z",
#     "pushed_at": "2021-01-04T18:25:17Z",
#     "git_url": "git://github.com/IvanYingX/House_Prices_AI.git",
#     "ssh_url": "git@github.com:IvanYingX/House_Prices_AI.git",
#     "clone_url": "https://github.com/IvanYingX/House_Prices_AI.git",
#     "svn_url": "https://github.com/IvanYingX/House_Prices_AI",
#     "homepage": null,
#     "size": 10854,
#     "stargazers_count": 0,
#     "watchers_count": 0,
#     "language": "Jupyter Notebook",
#     "has_issues": true,
#     "has_projects": true,
#     "has_downloads": true,
#     "has_wiki": true,
#     "has_pages": false,
#     "forks_count": 0,
#     "mirror_url": null,
#     "archived": false,
#     "disabled": false,
#     "open_issues_count": 0,
#     "license": null,
#     "allow_forking": true,
#     "is_template": false,
#     "topics": [
#
#     ],
#     "visibility": "public",
#     "forks": 0,
#     "open_issues": 0,
#     "watchers": 0,
#     "default_branch": "main"
#   }
# ]

# %% [markdown]
# You can do the same using the requests library from Python

# %%
import requests

r = requests.get('https://api.github.com/users/IvanYingX/repos')
r.text

# %% [markdown]
# However, if you want to create a repository, you need to be authenticated.

# %% [markdown]
# To create a repository we need to post data to the API. Let's see how to do it

# %%
import json
r = requests.post('https://api.github.com/user/repos', data=json.dumps({"name": "Repo-From-Python"}))
r
# Out:
# <Response [401]>

# %% [markdown]
# We can see that we are unauthorized. We need to add the token to the header of the request. We need to use a token from github. You can create a token for yourself in the github developer portal. First, go to your profile setting:

# %% [markdown]
# <p align=center><img src=images/github_setting.png width=300></p>

# %% [markdown]
# Then, click on Developer settings

# %% [markdown]
# <p align=center><img src=images/Dev_setting.png width=600></p>

# %% [markdown]
# And then, in Personal access tokens, click on Create new token:

# %% [markdown]
# <p align=center><img src=images/PAT.png width=600></p>

# %% [markdown]
# Finally, copy the token to use it in your request:

# %% [markdown]
# <p align=center><img src=images/PAT2.png width=600></p>

# %%
r = requests.post('https://api.github.com/user/repos', data=json.dumps({"name": "Repo-From-Python"}), headers={'Authorization': 'token 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', "Accept": "application/vnd.github.v3+json"})
r.status_code

# %% [markdown]
# Good! A status code of 201 means that the request was successful. Let's check the repo:

# %% [markdown]
# <p align=center><img src=images/repo.png width=600></p>

# %% [markdown]
# Success! You can check more information about the github API [here](https://docs.github.com/en/rest). Now you have a greater understanding of how powerful APIs are!

# %% [markdown]
# ### CORS (Cross Origin Resource Sharing)
#
# > CORS is a mechanism for restricting which computers (domains or IP addresses) are allowed to access an API resource
#
# Read more on CORS [here](https://developer.mozilla.org/en-US/docs/Web/HTTP/CORS)

# %% [markdown]
# ## Websites vs APIs & Front-end vs Back-end
#
# You guessed it, most websites these days are simply a pretty user interface wrapped around an API. When you press a button, change your profile picture, or send a message, it probably makes a request to an API.
#
# An API is typically the interface between the __front-end__ (the user interface) and the __back-end__ (the underlying infrastructure like the database). The front-end is what an end user interacts with, and the back end is the software that they don't see running in the background.
